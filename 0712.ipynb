# %%
粉專
貼文
留言
回覆

簡單
分步驟
動手做

feed?message=貼文測試
get 取得資料
post 回覆資料
delete 刪除貼文一樣刪除ＩＤ
/feed?message=   貼文
/comments?messag=   留言
since= 時間搓際
#def 一個對一個（舉例是絞肉機）輸入要是一樣數量。輸出不一定要一樣數量

ngrok
1.打開輸入ngrok http 3000
2.貼上下面的代碼

user{}
jd["data"][0]['id']
in 有。      not in 沒有

user['data'][0]#這邊的0是因為儲存在user裡面的dic所以抓message
==   #這邊是兩個抓取出來的資料做比對
jd['data'][0]['message']  #

#比對出來有一致的話就pass,沒有一致的話就not in

# %%
import requests  #引入外部
import json
import time
import jieba
# curl -i -X GET \
#  "https://graph.facebook.com/v17.0/me?access_token="
host = "https://graph.facebook.com/v17.0/"
page_id = "115447678275957"
token = "EAATaH0MNoVYBAJjWu0EnihjZCl2uPKthtec79YUiIoKF5GWFOAgXj99i9rodtBB6MQ9aTdd69my7Fcg0WN4ZAfJJyLORjscRexKr4pbz8VgZBB0dQZCfIdT5hSRa2Vw8TiBN3UgQxRvoJhmebe30II85i2ugRUPrQ8RZBrF4Y61Nh9tBBBgLCD1D2ZAyJZCPQf6ltvrC31Opoh1x9npZBVS8"
# token=input("請輸入token：")
res = requests.get(host+page_id+"/posts?access_token="+token)
#得到的代碼  https://developers.facebook.com/tools/explorer/?method=GET&path=me%3Ffields%3Dposts&version=v17.0
jd = json.loads(res.text)
print(jd)
# jds = jd["data"][0]
# print(jd["data"][0]["from"]["id"])

# %%
post_id = "115447678275957_100400489799434"
res = requests.get(host+post_id+"/comments?access_token="+token)
#得到的代碼  https://developers.facebook.com/tools/explorer/?method=GET&path=me%3Ffields%3Dposts&version=v17.0
jd = json.loads(res.text)
jd

# %%
com_id = "100400489799434_1015170022811572"
res = requests.get(host+com_id+"/comments?access_token="+token)
#得到的代碼  https://developers.facebook.com/tools/explorer/?method=GET&path=me%3Ffields%3Dposts&version=v17.0
jd = json.loads(res.text)
jd

# %%
jd["data"][0]["message"]

# %%
import random
num_max = 100
num_min = 1
ans = random.randint(num_min,num_max)
print(ans)
print("請輸入%d到%d的數字:"%(num_min,num_max))
while True:
    guess = int(input())
    if ans == guess:
        print("恭喜答對了")
        break
    elif ans > guess :
        num_min = guess
        print("請輸入%d到%d的數字:"%(num_min,num_max))
    else:
        num_max = guess
        print("請輸入%d到%d的數字:"%(num_min,num_max))

# %%
#自己的
import random
import time 
num_max = 100
num_min = 1
ans = random.randint(num_min,num_max)
res = requests.post(host+page_id+"/feed?message=遊戲開始,答案是:%d,請輸入%d到%d的數字:&access_token="%(ans,num_min,num_max)+token)
    #得到的代碼  https://developers.facebook.com/tools/explorer/?method=GET&path=me%3Ffields%3Dposts&version=v17.0
jd = json.loads(res.text)
print(jd["id"])

post_id = jd["id"]
print(post_id)
# print("答案是:%d"%(ans))
# print("請輸入%d到%d的數字:"%(num_min,num_max))
# post_id = "115447678275957_100400489799434"
while True:
    res = requests.get(host+post_id+"/comments?access_token="+token)
    jd=json.loads(res.text)
    if len(jd["data"]) > 0:
        guess = jd["data"][0]["message"]
        if ans == guess:
            res = requests.post(host+jd["data"][0]["id"]+"/comments?message=恭喜答對了！！&access_token="+token)
        elif ans > guess :
            num_min = guess
            print("請輸入%d到%d的數字:"%(num_min,num_max))
            res = requests.post(host+jd["data"][0]["id"]+"/comments?message=請輸入%d到%d的數字&access_token="+token)
        else :
            num_max = guess
            print("請輸入%d到%d的數字:"%(num_min,num_max))
            res = requests.post(host+jd["data"][0]["id"]+"/comments?message=請輸入%d到%d的數字&access_token="+token)
        time.sleep(5)
#     else:
#         print("end")

#     res = requests.post(host+jd["data"][0]["id"]+"/comments?message=恭喜答對了！！&access_token="+token)
#     print(res)
#     #得到的代碼  https://developers.facebook.com/tools/explorer/?method=GET&path=me%3Ffields%3Dposts&version=v17.0
#     jd = json.loads(res.text)
    
#     guess = jd["data"][0]["message"]
#     if ans == guess:
#         print("恭喜答對了")
#         break
#     elif ans > guess :
#         num_min = guess
#         print("請輸入%d到%d的數字:"%(num_min,num_max))
#     else:
#         num_max = guess
#         print("請輸入%d到%d的數字:"%(num_min,num_max))
#     time.sleep(1)

# %%
#老師的
import random
import time
import requests
import json
host="https://graph.facebook.com/v17.0/"
page_id="115447678275957"
token="EAATaH0MNoVYBAIgg26W2bRKW3EsSrBw8vHHkbhtQ82cWAGrZARoTQ5JAWS6bm6MJokiGZCG9b845KkgEpdeElos1r2isqcGsN3P8SZAuOUfU9R4KVZCPcp7dgBXihcITGgROGuh2QaH75PI6XhJ66Jf6PTEOITsLvtYPpnIbaYUNy3eSnttrcku2y6JSsH08lz0sFExYBqdchHRbH432"
num_max=100
num_min=1
ans=random.randint(num_min,num_max)
res=requests.post(host+page_id+"/feed?message=遊戲開始,答案是%d,請輸入%d到%d的數字&access_token="%(ans,num_min,num_max)+token)
# res=requests.post(host+page_id+"/feed?message=遊戲開始,答案是"+str(ans)+
#     ",請輸入"+str(num_min)+"到"+str(num_max)+"的數字&access_token="+token)
jd=json.loads(res.text)
print(jd)
post_id=jd['id']
time.sleep(5)
while True:
    res=requests.get(host+post_id+"/comments?access_token="+token)
    jd=json.loads(res.text)
    if len(jd['data'])>0:
        guess=int(jd['data'][0]['message'])
        if ans==guess:
            print("恭喜猜對")
            res=requests.post(host+jd['data'][0]['id']+"/comments?message=恭喜猜對&access_token="+token)
            break
        elif ans>guess:
            num_min=guess
            print("請輸入%d到%d的數字"%(num_min,num_max))
            res=requests.post(host+jd['data'][0]['id']+"/comments?message=請輸入%d到%d的數字"%(num_min,num_max)+"&access_token="+token)
        else:
            num_max=guess
            print("請輸入%d到%d的數字"%(num_min,num_max))
            res=requests.post(host+jd['data'][0]['id']+"/comments?message=請輸入%d到%d的數字"%(num_min,num_max)+"&access_token="+token)
    time.sleep(20)

# %%
#自己的
import requests  #引入外部
import json
import random
import time 
host = "https://graph.facebook.com/v17.0/"
page_id = "115447678275957"
token = "EAATaH0MNoVYBAJjWu0EnihjZCl2uPKthtec79YUiIoKF5GWFOAgXj99i9rodtBB6MQ9aTdd69my7Fcg0WN4ZAfJJyLORjscRexKr4pbz8VgZBB0dQZCfIdT5hSRa2Vw8TiBN3UgQxRvoJhmebe30II85i2ugRUPrQ8RZBrF4Y61Nh9tBBBgLCD1D2ZAyJZCPQf6ltvrC31Opoh1x9npZBVS8"
# token=input("請輸入token：")
res = requests.get(host+page_id+"/posts?access_token="+token)
#得到的代碼  https://developers.facebook.com/tools/explorer/?method=GET&path=me%3Ffields%3Dposts&version=v17.0
jd = json.loads(res.text)
# print(jd)
# jds = jd["data"][0]
# print(jd["data"][0]["from"]["id"])

num_max = 100
num_min = 1
ans = random.randint(num_min,num_max)
res = requests.post(host+page_id+"/feed?message=遊戲開始,答案是:%d,請輸入%d到%d的數字:&access_token="%(ans,num_min,num_max)+token)
    #得到的代碼  https://developers.facebook.com/tools/explorer/?method=GET&path=me%3Ffields%3Dposts&version=v17.0
jd = json.loads(res.text)
# print(jd["id"])
user={}
post_id = jd["id"]
print(post_id)
# print("答案是:%d"%(ans))
# print("請輸入%d到%d的數字:"%(num_min,num_max))
# post_id = "115447678275957_100400489799434"
while True:
    #讀取貼文的留言
    res = requests.get(host+post_id+"/comments?access_token="+token)
    jd=json.loads(res.text)
    
    if len(jd["data"]) > 0:
        guess = int(jd["data"][0]["message"])
        user[jd["data"][0]["id"]]=[jd["data"][0]["message"]]
        if ans == guess:
            res = requests.post(host+jd["data"][0]["id"]+"/comments?message=恭喜答對了！！&access_token="+token)
        elif ans > guess :
            num_min = guess
            print("請輸入%d到%d的數字:"%(num_min,num_max))
            res = requests.post(host+jd["data"][0]["id"]+"/comments?message=請輸入%d到%d的數字&access_token="%(num_min,num_max)+token)
        else :
            num_max = guess
            print("請輸入%d到%d的數字:"%(num_min,num_max))
            res = requests.post(host+jd["data"][0]["id"]+"/comments?message=請輸入%d到%d的數字&access_token="%(num_min,num_max)+token)
        jd2 = json.loads(res.text)
#         print(jd2)
#         print(user[jd["data"][0]["id"]])
        if len(user[jd["data"][0]["id"]])==1:
            user[jd["data"][0]["id"]].append(jd2["id"])
#             print(user[jd["data"][0]["id"]].append(jd2["id"]))
        else:
            user[jd["data"][0]["id"]]=jd2["id"]
            print(user[jd["data"][0]["id"]])
        time.sleep(3)
#     else:
#         print("end")

#     res = requests.post(host+jd["data"][0]["id"]+"/comments?message=恭喜答對了！！&access_token="+token)
#     print(res)
#     #得到的代碼  https://developers.facebook.com/tools/explorer/?method=GET&path=me%3Ffields%3Dposts&version=v17.0
#     jd = json.loads(res.text)
    
#     guess = jd["data"][0]["message"]
#     if ans == guess:
#         print("恭喜答對了")
#         break
#     elif ans > guess :
#         num_min = guess
#         print("請輸入%d到%d的數字:"%(num_min,num_max))
#     else:
#         num_max = guess
#         print("請輸入%d到%d的數字:"%(num_min,num_max))
#     time.sleep(1)

# %%
#老師做的
import random
import time
import requests
import json
host="https://graph.facebook.com/v17.0/"
page_id="115447678275957"
token="EAATaH0MNoVYBAJjWu0EnihjZCl2uPKthtec79YUiIoKF5GWFOAgXj99i9rodtBB6MQ9aTdd69my7Fcg0WN4ZAfJJyLORjscRexKr4pbz8VgZBB0dQZCfIdT5hSRa2Vw8TiBN3UgQxRvoJhmebe30II85i2ugRUPrQ8RZBrF4Y61Nh9tBBBgLCD1D2ZAyJZCPQf6ltvrC31Opoh1x9npZBVS8"
num_max=100
num_min=1
ans=random.randint(num_min,num_max)
user={}
res=requests.post(host+page_id+"/feed?message=遊戲開始,答案是%d,請輸入%d到%d的數字&access_token="%(ans,num_min,num_max)+token)
# res=requests.post(host+page_id+"/feed?message=遊戲開始,答案是"+str(ans)+
#     ",請輸入"+str(num_min)+"到"+str(num_max)+"的數字&access_token="+token)
jd=json.loads(res.text)
print(jd)
post_id=jd['id']
time.sleep(5)
while True:
    #讀取貼文的留言
    res=requests.get(host+post_id+"/comments?access_token="+token)
    jd=json.loads(res.text)    
    if len(jd['data'])>0:#判斷是否有新留言
        guess=int(jd['data'][0]['message'])#存猜測的答案
        user[jd['data'][0]['id']]=[jd['data'][0]['message']]#開始記錄user={"留言ID":[留言內容,回覆ID]}
        if ans==guess:
            print("恭喜猜對")
            res=requests.post(host+jd['data'][0]['id']+"/comments?message=恭喜猜對&access_token="+token)
            break
        elif ans>guess:
            num_min=guess
            print("請輸入%d到%d的數字"%(num_min,num_max))
            res=requests.post(host+jd['data'][0]['id']+"/comments?message=請輸入%d到%d的數字"%(num_min,num_max)+"&access_token="+token)
        else:
            num_max=guess
            print("請輸入%d到%d的數字"%(num_min,num_max))
            res=requests.post(host+jd['data'][0]['id']+"/comments?message=請輸入%d到%d的數字"%(num_min,num_max)+"&access_token="+token)
        #留下回覆的紀錄
        jd2=json.loads(res.text)
        if len(user[jd['data'][0]['id']])==1:#判斷是否已回覆過
            user[jd['data'][0]['id']].append(jd2['id'])
            print(user[jd['data'][0]['id']].append(jd2['id']))
        else:
            user[jd['data'][0]['id']][1]=jd2['id']
    time.sleep(5)

# %%
#刪除資料。since 時間搓
res=requests.get(host+page_id+"/posts?since=1689114981&access_token="+token)
jd=json.loads(res.text)
for post in jd['data']:
    requests.delete(host+post['id']+"?access_token="+token)

# %%
#自己做的
import random
import time
import requests
import json
host="https://graph.facebook.com/v17.0/"
page_id="115447678275957"
token="EAATaH0MNoVYBAIgg26W2bRKW3EsSrBw8vHHkbhtQ82cWAGrZARoTQ5JAWS6bm6MJokiGZCG9b845KkgEpdeElos1r2isqcGsN3P8SZAuOUfU9R4KVZCPcp7dgBXihcITGgROGuh2QaH75PI6XhJ66Jf6PTEOITsLvtYPpnIbaYUNy3eSnttrcku2y6JSsH08lz0sFExYBqdchHRbH432"
num_max=100
num_min=1
ans=random.randint(num_min,num_max)
user={}
res=requests.post(host+page_id+"/feed?message=遊戲開始,答案是%d,請輸入%d到%d的數字&access_token="%(ans,num_min,num_max)+token)
# res=requests.post(host+page_id+"/feed?message=遊戲開始,答案是"+str(ans)+
#     ",請輸入"+str(num_min)+"到"+str(num_max)+"的數字&access_token="+token)
jd=json.loads(res.text)
print(jd)
post_id=jd['id']
time.sleep(5)
while True:
    #讀取貼文的留言
    res=requests.get(host+post_id+"/comments?access_token="+token)
    jd=json.loads(res.text)    
    if len(jd['data'])>0:#判斷是否有新留言
        guess=int(jd['data'][0]['message'])#存猜測的答案
        if jd["data"][0]["id"] not in user:
            user[jd['data'][0]['id']]=[jd['data'][0]['message']]#開始記錄user={"留言ID":[留言內容,回覆ID]}
            if ans==guess:
                print("恭喜猜對")
                res=requests.post(host+jd['data'][0]['id']+"/comments?message=恭喜猜對&access_token="+token)
                break
            elif ans>guess:
                num_min=guess
                print("請輸入%d到%d的數字"%(num_min,num_max))
                res=requests.post(host+jd['data'][0]['id']+"/comments?message=請輸入%d到%d的數字"%(num_min,num_max)+"&access_token="+token)
            else:
                num_max=guess
                print("請輸入%d到%d的數字"%(num_min,num_max))
                res=requests.post(host+jd['data'][0]['id']+"/comments?message=請輸入%d到%d的數字"%(num_min,num_max)+"&access_token="+token)
            #留下回覆的紀錄
            jd2=json.loads(res.text)
            if len(user[jd['data'][0]['id']])==1:#判斷是否已回覆過
                user[jd['data'][0]['id']].append(jd2['id'])
            else:
                user[jd['data'][0]['id']][1]=jd2['id']
    time.sleep(10)

# %%
import random
import time
import requests
import json
host="https://graph.facebook.com/v17.0/"
page_id="115447678275957"
token="EAATaH0MNoVYBAH263HP1GNGyteEsZCczoa6MvawW15c6ZCsBgk3PW9Af6px6D6ZAVOtmPrkxMANVZB4C6aO4455qon4ZC0lWFEJY4S3XERntU0hZB5XSCj6NEZC74CXwlBl8ZB0HpLbPrMEJzPVB1cfnYW8vL3oEsvyStCWnfDtbZB1z0Eu7AzrowrdbLM6J8giZCOUI6c3XkSIBpAmO1LBZBZBM"
num_max=100
num_min=1
ans=random.randint(num_min,num_max)
user={}
res=requests.post(host+page_id+"/feed?message=遊戲開始,答案是%d,請輸入%d到%d的數字&access_token="%(ans,num_min,num_max)+token)
# res=requests.post(host+page_id+"/feed?message=遊戲開始,答案是"+str(ans)+
#     ",請輸入"+str(num_min)+"到"+str(num_max)+"的數字&access_token="+token)
jd=json.loads(res.text)
# print(jd)
post_id=jd['id']
time.sleep(5)
while True:
    #讀取貼文的留言
    res=requests.get(host+post_id+"/comments?access_token="+token)
    jd=json.loads(res.text)    
    if len(jd['data'])>0:#判斷是否有新留言
        guess=int(jd['data'][0]['message'])#存猜測的答案
        if jd['data'][0]['id'] not in user: #判斷是否有被回覆過（沒存過）
            user[jd['data'][0]['id']]=[jd['data'][0]['message']]#開始記錄user={"留言ID":[留言內容,回覆ID]}
            if ans==guess:
                print("恭喜猜對")
                res=requests.post(host+jd['data'][0]['id']+"/comments?message=恭喜猜對&access_token="+token)
                break
            elif ans>guess:
                num_min=guess
                print("請輸入%d到%d的數字"%(num_min,num_max))
                res=requests.post(host+jd['data'][0]['id']+"/comments?message=請輸入%d到%d的數字"%(num_min,num_max)+"&access_token="+token)
            else:
                num_max=guess
                print("請輸入%d到%d的數字"%(num_min,num_max))
                res=requests.post(host+jd['data'][0]['id']+"/comments?message=請輸入%d到%d的數字"%(num_min,num_max)+"&access_token="+token)
            #留下回覆的紀錄
            jd2=json.loads(res.text)
            print(jd2)
            if len(user[jd['data'][0]['id']])==1:#判斷是否已回覆過
                user[jd['data'][0]['id']].append(jd2['id'])
            else:
                user[jd['data'][0]['id']][1]=jd2['id']
        else: #（已存過）
            if user[jd['data'][0]['id']][0]!=jd['data'][0]['message']:#判斷留言是否有變化
                user[jd['data'][0]['id']][0]=jd['data'][0]['message']#開始記錄user={"留言ID":[留言內容,回覆ID]}
                if ans==guess:
                    print("恭喜猜對")
                    res=requests.post(host+jd['data'][0]['id']+"/comments?message=恭喜猜對&access_token="+token)
                    break
                elif ans>guess:
                    num_min=guess
                    print("請輸入%d到%d的數字"%(num_min,num_max))
                    res=requests.post(host+jd['data'][0]['id']+"/comments?message=請輸入%d到%d的數字"%(num_min,num_max)+"&access_token="+token)
                else:
                    num_max=guess
                    print("請輸入%d到%d的數字"%(num_min,num_max))
                    res=requests.post(host+jd['data'][0]['id']+"/comments?message=請輸入%d到%d的數字"%(num_min,num_max)+"&access_token="+token)
                #留下回覆的紀錄
                jd2=json.loads(res.text)
                print(jd2)
                user[jd['data'][0]['id']][1]=jd2['id']
    time.sleep(20)

# %%
#老師寫的
def comp(user,jd,ans,guess,num_min,num_max):#函數(子程式)
    user[jd['data'][0]['id']]=[jd['data'][0]['message']]#開始記錄user={"留言ID":[留言內容,回覆ID]}
    if ans==guess:
        print("恭喜猜對")
        res=requests.post(host+jd['data'][0]['id']+"/comments?message=恭喜猜對&access_token="+token)
        jd2=json.loads(res.text)
        return user,jd,ans,guess,num_min,num_max,1,jd2
    elif ans>guess:
        num_min=guess
        print("請輸入%d到%d的數字"%(num_min,num_max))
        res=requests.post(host+jd['data'][0]['id']+"/comments?message=請輸入%d到%d的數字"%(num_min,num_max)+"&access_token="+token)
    else:
        num_max=guess
        print("請輸入%d到%d的數字"%(num_min,num_max))
        res=requests.post(host+jd['data'][0]['id']+"/comments?message=請輸入%d到%d的數字"%(num_min,num_max)+"&access_token="+token)
    #留下回覆的紀錄
    jd2=json.loads(res.text)
    return user,jd,ans,guess,num_min,num_max,0,jd2

# %%
import random
import time
import requests
import json
host="https://graph.facebook.com/v17.0/"
page_id="115447678275957"
token="EAATaH0MNoVYBAPGIqwF3itvreri4jdPL9SImXTdlfUtKQ9LGbTS6N6vdcTNuRQfGdl7GUQnCjtctt61U1OOLo2ZAObJQjVJutTopBPWfIt6ySfKKi2WRPMIgtcRRFurC1MaPMbqYAQgRwQhBgzYZBenK4lvzglx6vkhvcRFumRanESTASFkSzxgCEPo5AMS1VtyZANuUrn5cLdHvpOI"
num_max=100
num_min=1
ans=random.randint(num_min,num_max)
user={}
check=0
res=requests.post(host+page_id+"/feed?message=遊戲開始,答案是%d,請輸入%d到%d的數字&access_token="%(ans,num_min,num_max)+token)
# res=requests.post(host+page_id+"/feed?message=遊戲開始,答案是"+str(ans)+
#     ",請輸入"+str(num_min)+"到"+str(num_max)+"的數字&access_token="+token)
jd=json.loads(res.text)
jd2=""
print(jd)
post_id=jd['id']
time.sleep(5)
while check==0:
    #讀取貼文的留言
    res=requests.get(host+post_id+"/comments?access_token="+token)
    jd=json.loads(res.text)    
    if len(jd['data'])>0:#判斷是否有新留言
        guess=int(jd['data'][0]['message'])#存猜測的答案
        if jd['data'][0]['id'] not in user:#判斷是否存檔過(沒存過)
            user,jd,ans,guess,num_min,num_max,check,jd2=comp(user,jd,ans,guess,num_min,num_max)
            print(jd2)
            user[jd['data'][0]['id']].append(jd2['id'])
        else: #存過
            if user[jd['data'][0]['id']][0]!=jd['data'][0]['message']:#判斷留言是否有變化
                user,jd,ans,guess,num_min,num_max,check,jd2=comp(user,jd,ans,guess,num_min,num_max)
                print(jd2)
                user[jd['data'][0]['id']][1]=jd2['id']
    time.sleep(8)
# Out:
# {'id': '115447678275957_100886679750815'}
# 請輸入10到100的數字
# {'id': '100886679750815_3424892287777620'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 36
#      34             print(jd2)
#      35             user[jd['data'][0]['id']][1]=jd2['id']
# ---> 36 time.sleep(8)
#
# KeyboardInterrupt:

# %%
#大量刪除用
res=requests.get(host+page_id+"/posts?since=1689141030&access_token="+token)
jd=json.loads(res.text)
# print(jd)
for post in jd['data']:
    requests.delete(host+post['id']+"?access_token="+token)
