# %%
pip install opencv_python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# pip uninstall opencv_python

# %%
pip list
# Out:
# Package                       Version
# ----------------------------- -----------
# absl-py                       1.4.0
# aenum                         3.1.15
# aiohttp                       3.8.4
# aiosignal                     1.3.1
# alabaster                     0.7.12
# anaconda-client               1.11.2
# anaconda-navigator            2.4.0
# anaconda-project              0.11.1
# anyio                         3.5.0
# appdirs                       1.4.4
# applaunchservices             0.3.0
# appnope                       0.1.2
# appscript                     1.1.2
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.3
# astroid                       2.14.2
# astropy                       5.1
# asttokens                     2.0.5
# astunparse                    1.6.3
# async-timeout                 4.0.2
# atomicwrites                  1.4.0
# attrs                         22.1.0
# ...

# %%
import cv2
print(cv2.__version__)
# Out:
# 4.8.0

# %%
pip install opencv-contrib-python==4.4.0.46
# Out:
# ...
#   Using cached opencv-contrib-python-4.4.0.46.tar.gz (148.8 MB)
#   Installing build dependencies ... -

# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
img = cv2.imread("/Users/lvhongxiang/Documents/photograph/class/IMG_7356.JPG")
cv2.imshow("/Users/lvhongxiang/Documents/photograph/class/IMG_735600.JPG",img)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
img = cv2.imread("/Users/lvhongxiang/Documents/photograph/class/IMG_7356.JPG")
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
cv2.imshow("/Users/lvhongxiang/Documents/photograph/class/IMG_735600.JPG",gray)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
faces = faceCascade.detectMultiScale(gray,scaleFactor=1.12,minNeighbors=3,minSize=(5.5))

for(x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+w),(0,255,0),2)

# %%
import cv2
import numpy as np
img = cv2.imread("/Users/lvhongxiang/Documents/photograph/class/IMG_7356.JPG")
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
faceCasecade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

# cv2.imshow("/Users/lvhongxiang/Documents/photograph/class/IMG_735600.JPG",gray)

faces = faceCasecade.detectMultiScale(
    gray,
    scaleFactor=1.12,
    minNeighbors=3,
    minSize=(5,5)
)
print(faces)
print('發現',len(faces),'個人臉！')
for(x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+w),(0,255,0),2)
cv2.imshow("/Users/lvhongxiang/Documents/photograph/class/IMG_735600.JPG",gray)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
img = []
img.append(cv2.imread("L1.jpg",cv2.IMREAD_GRAYSCALE))
img.append(cv2.imread("L2.jpg",cv2.IMREAD_GRAYSCALE))
img.append(cv2.imread("L3.jpg",cv2.IMREAD_GRAYSCALE))
img.append(cv2.imread("CH1.jpg",cv2.IMREAD_GRAYSCALE))
img.append(cv2.imread("CH2.jpg",cv2.IMREAD_GRAYSCALE))
img.append(cv2.imread("CH3.jpg",cv2.IMREAD_GRAYSCALE))
# 上面是給他學習他的特徵
labels = [0,0,0,1,1,1]
# print(labels)
recongnizer = cv2.face.LBPHFaceRecognizer_create()
recongnizer.train(img,np.array(labels))
# 這裡是判斷這張照片跟上面的照片是否有符合
pradict_image = cv2.imread("L4.jpg",cv2.IMREAD_GRAYSCALE)

label,confidence = recongnizer.pradict(pradict_image)
print('label=',label)

print('confidence=',confidence)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 13
#      11 labels = [0,0,0,1,1,1]
#      12 # print(labels)
# ---> 13 recongnizer = cv2.face.LBPHFaceRecognizer_create()
#      14 recongnizer.train(img,np.array(labels))
#      15 # 這裡是判斷這張照片跟上面的照片是否有符合
#
# AttributeError: module 'cv2' has no attribute 'face'

# %%
import cv2
import numpy as np

img = []
img.append(cv2.imread("/Users/lvhongxiang/Aiot/Aiot/L1.jpg", cv2.IMREAD_GRAYSCALE))
img.append(cv2.imread("/Users/lvhongxiang/Aiot/Aiot/L2.jpg", cv2.IMREAD_GRAYSCALE))
img.append(cv2.imread("/Users/lvhongxiang/Aiot/Aiot/L3.jpg", cv2.IMREAD_GRAYSCALE))
img.append(cv2.imread("/Users/lvhongxiang/Aiot/Aiot/CH1.jpg", cv2.IMREAD_GRAYSCALE))
img.append(cv2.imread("/Users/lvhongxiang/Aiot/Aiot/CH2.jpg", cv2.IMREAD_GRAYSCALE))
img.append(cv2.imread("/Users/lvhongxiang/Aiot/Aiot/CH3.jpg", cv2.IMREAD_GRAYSCALE))

labels = [0, 0, 0, 1, 1, 1]
# print(labels)
recognizer = cv2.face.createLBPHFaceRecognizer()  # 正確的創建 LBPHFaceRecognizer 對象
recognizer.train(img, np.array(labels))

predict_image = cv2.imread("/Users/lvhongxiang/Aiot/Aiot/L4.jpg", cv2.IMREAD_GRAYSCALE)

label, confidence = recognizer.predict(predict_image)

print('label=', label)
print('confidence=', confidence)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 14
#      12 labels = [0, 0, 0, 1, 1, 1]
#      13 # print(labels)
# ---> 14 recognizer = cv2.face.createLBPHFaceRecognizer()  # 正確的創建 LBPHFaceRecognizer 對象
#      15 recognizer.train(img, np.array(labels))
#      17 predict_image = cv2.imread("/Users/lvhongxiang/Aiot/Aiot/L4.jpg", cv2.IMREAD_GRAYSCALE)
#
# AttributeError: module 'cv2' has no attribute 'face'

# %%
pip list
# Out:
# Package                       Version
# ----------------------------- -----------
# absl-py                       1.4.0
# aenum                         3.1.15
# aiohttp                       3.8.4
# aiosignal                     1.3.1
# alabaster                     0.7.12
# anaconda-client               1.11.2
# anaconda-navigator            2.4.0
# anaconda-project              0.11.1
# anyio                         3.5.0
# appdirs                       1.4.4
# applaunchservices             0.3.0
# appnope                       0.1.2
# appscript                     1.1.2
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.3
# astroid                       2.14.2
# astropy                       5.1
# asttokens                     2.0.5
# astunparse                    1.6.3
# async-timeout                 4.0.2
# atomicwrites                  1.4.0
# attrs                         22.1.0
# ...

# %%
import cv2
import numpy as np

img = []
img.append(cv2.imread("/Users/lvhongxiang/Aiot/Aiot/L1.jpg", cv2.IMREAD_GRAYSCALE))
img.append(cv2.imread("/Users/lvhongxiang/Aiot/Aiot/L2.jpg", cv2.IMREAD_GRAYSCALE))
img.append(cv2.imread("/Users/lvhongxiang/Aiot/Aiot/L3.jpg", cv2.IMREAD_GRAYSCALE))
img.append(cv2.imread("/Users/lvhongxiang/Aiot/Aiot/CH1.jpg", cv2.IMREAD_GRAYSCALE))
img.append(cv2.imread("/Users/lvhongxiang/Aiot/Aiot/CH2.jpg", cv2.IMREAD_GRAYSCALE))
img.append(cv2.imread("/Users/lvhongxiang/Aiot/Aiot/CH3.jpg", cv2.IMREAD_GRAYSCALE))

labels = [0, 0, 0, 1, 1, 1]

recognizer = cv2.face.createLBPHFaceRecognizer()  # 正確的創建 LBPHFaceRecognizer 對象
recognizer.train(img, np.array(labels))

predict_image = cv2.imread("/Users/lvhongxiang/Aiot/Aiot/L4.jpg", cv2.IMREAD_GRAYSCALE)

label, confidence = recognizer.predict(predict_image)

print('label=', label)
print('confidence=', confidence)

# %%
print(cv2.__version__)

# %%
# 抓同樣的照片讓他學習
# 範例是抓18張相同的照片 (EX.劉德華)

import cv2
import numpy as np

img = []
labels= []

num = 0
while num<9:
    num+=1
    img.append(cv2.imread("L"+str(num)+".jpg",cv2.IMREAD_GRAYSCALE))
    labels.append(0)
num = 0
while num<9:
    num+=1
    img.append(cv2.imread("CH"+str(num)+".jpg",cv2.IMREAD_GRAYSCALE))
    labels.append(1)
print(len(img))
print(labels)

# %%
import cv2

# 載入預訓練的人臉識別分類器
faceCascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

# 讀取圖像
image = cv2.imread('your_image.jpg')

# 將圖像轉換為灰度
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# 使用 detectMultiScale 函數檢測人臉
faces = faceCascade.detectMultiScale(
    gray,
    scaleFactor=1.12,
    minNeighbors=3,
    minSize=(30, 30)
)

# %%
import cv2
faceCascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")
recon = faceCascade.LBPHFaceRecognizer_create()
recon.train(img,np.array(labels))

# %%
recon = cv2.faceCascade.LBPHFaceRecognizer_create()
recon.train(img,np.array(labels))

predict_img=cv2.imread("CH10.jpg",cv2.IMREAD_GRAYSCALE)

label,confidence = recon.pradict(pradict_image)
print('label=',label)

print("confidence=",confidence)

# %%
name_list = ["劉德華","周杰倫"]

print("此人為",name_list[label])
print("confidence",confidence)

# %%
# 圖片切割與儲存
x = 100
y = 100

# 裁切區域的長度與寬度
w = 250
h = 150

# 裁切圖片
crop_img = img[y:y+h,x:x+w]

cv2.imwrite("crop.jpg",crop_img)

# %%
import cv2
import numpy as np

kings = ['Andy Lau','Aaron Kwok',"Leon Lai","Jacky Cheung"]
kings_en=["L","Q","M","Z"]
img_train=[]
labels=[]

king_num= 0
for king in kings_en:
    
    num=0
    while num <10:
        num+=1
        img_train.append(cv2.imread(king+str(num)+".JPG",cv2.IMREAD_GRAYSCALE))
        labels.append(king_num)
    king_num+=1

# %%
recon = cv2.face.LBPHFaceRecognizer_create()
recon.train(img,np.array(labels))

# %%
img = cv2.imread("4kings.jpg")
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
faceCascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

faces = faceCascade.detectMultiScale(
    gray,
    scaleFactor=1.12,
    minNeighbprs=3,
    minSize=(50,50)
)

print(faces)
print("發現",len(faces),"個人臉！！")

cut_list=[]
face_num = 0
for(x,y,w,h) in faces:
    face_num+=1
    cut_img = img[y:y+h,x:x+w]
    cv2.imwrite("cut"+str(face_num)+".jpg",cut_img)
    print("已儲存","cut"+str(face_num)+".jpg")
    cut_list.append("cut"+str(face_num)+".jpg")
print(cut_list)

# %%
cut_who = []
for cut in cut_list:
    predict_img = cv2.imread(cut,cv2.IMREAD_GRAYSCALE)
    
    label,confidence = rec.predict(predict_img)
    cut_sho.append(kings[label])
    
    print("此人是",kings[label],
          "confidence=",confidence)

# %%
who_num = 0
for (x,y,w,h) in faces :
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)
    cv2.puyText(img,cut_sho[who_num],(w,y),cv2.FONT_HERSHEY_TRIPLEX,1,(0,255,0),1)
    who_num+=1

cv2.imshow("findface",img)
cv2.waitKey()
