# %%
href="/imgres?imgurl=https%3A%2F%2Fugc-media.4gamers.com.tw%2Fpuku-prod-zh%2Fmember%2FgX2PQnQ7FapzgjbbZUWYrzbYmXA%2Fmondou%2F803dbd99-af8d-42e0-984f-0fbe58e834d7.jpg&amp;tbnid=rFIMGhwezeJwtM&amp;vet=12ahUKEwi3suT6zNOAAxUw0DQHHVaWBmYQMygAegUIARD1AQ..i&amp;imgrefurl=https%3A%2F%2Fwww.4gamers.com.tw%2Fsaged%2Fdetail%2Foedr146r71937l&amp;docid=itYsrRt0crXOuM&amp;w=1280&amp;h=1280&amp;q=%E7%8B%97&amp;hl=zh-TW&amp;ved=2ahUKEwi3suT6zNOAAxUw0DQHHVaWBmYQMygAegUIARD1AQ"

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.keys import Keys  #模擬按鍵
from selenium.webdriver.chrome.options import Options  #設定要關掉小鈴鐺
# 抓chromedriver放的路徑
service = Service(executable_path = "/Users/lvhongxiang/Aiot/chromedriver-mac-x64/chromedriver")
driver = webdriver.Chrome(service=service)
#抓網址
driver.get("https://www.google.com/")
name = WebDriverWait(driver,30).until(EC.element_to_be_clickable((By.CSS_SELECTOR,"textarea[title='Google 搜尋']")))
print(name.get_attribute("type"))
name.send_keys("狗狗")
name.send_keys(Keys.ENTER)
driver.find_element(By.XPATH,('//*[text()="圖片"]')).click()
driver.find_element(By.XPATH,('//*[text()="工具"]')).click()
driver.find_element(By.XPATH,('//*[text()="大小"]')).click()
driver.find_element(By.XPATH,('//*[text()="大"]')).click()
# login = WebDriverWait(driver,30).until(EC.element_to_be_clickable((By.CSS_SELECTOR,"img[src='data:image/jpeg;base64,...'")))
# login.click()
# login2 = WebDriverWait(driver,30).until(EC.element_to_be_clickable((By.CSS_SELECTOR,"a[href='https://www.4gamers.com.tw/saged/detail/oedr146r71937l']")))
# login2.click()
anchor = driver.find_elements(By.CLASS_NAME,("wXeWr"))
print (anchor)
anchor_list = []
for img in anchor[:5]:
    try:
#         img.click()
        anchor_list.append(img.get_attribute("href"))  
        
    except:
        pass
print(anchor_list)

# 方法1
# # srclist=[]
# # for i in anchor_list:
# #     driver.get(i)
# #     for j in driver.find_elements(By.CLASS_NAME,("r48jcc")):
# #         srclist.append(j.get_attribute("src"))
# # print(srclist)
# # 方法2
# # pic = []
# # url = []
# # for url in anchor_list:
# #     try:
# #         driver.get(url)
# #         img = WebDriverWait(driver,30).until(EC.element_to_be_clickable((By.CSS_SELECTOR,'img[class="r48jcc pT0Scc iPVvYb"]')))
# #         pic.append(img.get_attribute("src"))
# #         print(img.get_attribute("src"))
# #     except:
# #         print(url)
# # print(pic)
# Out:
# textarea
# []
# []

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.keys import Keys  #模擬按鍵
from selenium.webdriver.chrome.options import Options  #設定要關掉小鈴鐺
# 抓chromedriver放的路徑
service = Service(executable_path = "/Users/lvhongxiang/Aiot/chromedriver-mac-x64/chromedriver")
driver = webdriver.Chrome(service=service)
#抓網址
driver.get("https://www.google.com/")
name = WebDriverWait(driver,30).until(EC.element_to_be_clickable((By.CSS_SELECTOR,"textarea[title='Google 搜尋']")))
print(name.get_attribute("type"))
name.send_keys("張學友")
name.send_keys(Keys.ENTER)
driver.find_element(By.XPATH,('//*[text()="圖片"]')).click()
driver.find_element(By.XPATH,('//*[text()="工具"]')).click()
driver.find_element(By.XPATH,('//*[text()="大小"]')).click()
driver.find_element(By.XPATH,('//*[text()="大"]')).click()
# login = WebDriverWait(driver,30).until(EC.element_to_be_clickable((By.CSS_SELECTOR,"img[src='data:image/jpeg;base64,...'")))
# login.click()
# login2 = WebDriverWait(driver,30).until(EC.element_to_be_clickable((By.CSS_SELECTOR,"a[href='https://www.4gamers.com.tw/saged/detail/oedr146r71937l']")))
# login2.click()
anchor = driver.find_elements(By.CLASS_NAME,("wXeWr"))
print (anchor)
anchor_list = []
for img in anchor[:15]:
    try:
#         img.click()
        anchor_list.append(img.get_attribute("href"))  
        
    except:
        pass
print(anchor_list)
# 方法1
# # srclist=[]
# # for i in anchor_list:
# #     driver.get(i)
# #     for j in driver.find_elements(By.CLASS_NAME,("r48jcc")):
# #         srclist.append(j.get_attribute("src"))
# # print(srclist)
# # 方法2
# # pic = []
# # url = []
# # for url in anchor_list:
# #     try:
# #         driver.get(url)
# #         img = WebDriverWait(driver,30).until(EC.element_to_be_clickable((By.CSS_SELECTOR,'img[class="r48jcc pT0Scc iPVvYb"]')))
# #         pic.append(img.get_attribute("src"))
# #         print(img.get_attribute("src"))
# #     except:
# #         print(url)
# # print(pic)

pic = []
url = []
for url in anchor_list:
    try:
        driver.get(url)
        img = WebDriverWait(driver,30).until(EC.element_to_be_clickable((By.CSS_SELECTOR,'img[class="r48jcc pT0Scc iPVvYb"]')))
        pic.append(img.get_attribute("src"))
        print(img.get_attribute("src"))
    except:
        print(url)
print(pic)
import wget
import os 
path = os.getcwd()
path = os.path.join(path,"張學友")
os.mkdir(path)
print(path)
n=0
for img in pic:
    n += 1
    try:
        file = os.path.join(path,"Z"+str(n)+".jpg")
        if os.path.exists(file):
            os.remove(file)
        wget.download(img,file)
        print(file)
    except:
        print(img)
# Out:
# textarea
# [<selenium.webdriver.remote.webelement.WebElement (session="57af08bd4c9c37d7c8b6a40cff4b8b20", element="B52638B032F3437EA9139EB1C212BF63_element_200")>, <selenium.webdriver.remote.webelement.WebElement (session="57af08bd4c9c37d7c8b6a40cff4b8b20", element="B52638B032F3437EA9139EB1C212BF63_element_201")>, <selenium.webdriver.remote.webelement.WebElement (session="57af08bd4c9c37d7c8b6a40cff4b8b20", element="B52638B032F3437EA9139EB1C212BF63_element_202")>, <selenium.webdriver.remote.webelement.WebElement (session="57af08bd4c9c37d7c8b6a40cff4b8b20", element="B52638B032F3437EA9139EB1C212BF63_element_203")>, <selenium.webdriver.remote.webelement.WebElement (session="57af08bd4c9c37d7c8b6a40cff4b8b20", element="B52638B032F3437EA9139EB1C212BF63_element_204")>, <selenium.webdriver.remote.webelement.WebElement (session="57af08bd4c9c37d7c8b6a40cff4b8b20", element="B52638B032F3437EA9139EB1C212BF63_element_205")>, <selenium.webdriver.remote.webelement.WebElement (session="57af08bd4c9c37d7c8b6a40cff4b8b20", element="B52638B032F3437EA9139EB1C212BF63_element_206")>, <selenium.webdriver.remote.webelement.WebElement (session="57af08bd4c9c37d7c8b6a40cff4b8b20", element="B52638B032F3437EA9139EB1C212BF63_element_207")>, <selenium.webdriver.remote.webelement.WebElement (session="57af08bd4c9c37d7c8b6a40cff4b8b20", element="B52638B032F3437EA9139EB1C212BF63_element_208")>, <selenium.webdriver.remote.webelement.WebElement (session="57af08bd4c9c37d7c8b6a40cff4b8b20", element="B52638B032F3437EA9139EB1C212BF63_element_209")>, <selenium.webdriver.remote.webelement.WebElement (session="57af08bd4c9c37d7c8b6a40cff4b8b20", element="B52638B032F3437EA9139EB1C212BF63_element_210")>, <selenium.webdriver.remote.webelement.WebElement (session="57af08bd4c9c37d7c8b6a40cff4b8b20", element="B52638B032F3437EA9139EB1C212BF63_element_211")>, <selenium.webdriver.remote.webelement.WebElement (session="57af08bd4c9c37d7c8b6a40cff4b8b20", element="B52638B032F3437EA9139EB1C212BF63_element_212")>, <selenium.webdriver.remote.webelement.WebElement (session="57af08bd4c9c37d7c8b6a40cff4b8b20", element="B52638B032F3437EA9139EB1C212BF63_element_213")>, <selenium.webdriver.remote.webelement.WebElement (session="57af08bd4c9c37d7c8b6a40cff4b8b20", element="B52638B032F3437EA9139EB1C212BF63_element_214")>, <selenium.webdriver.remote.webelement.WebElement (session="57af08bd4c9c37d7c8b6a40cff4b8b20", element="B52638B032F3437EA9139EB1C212BF63_element_215")>, <selenium.webdriver.remote.webelement.WebElement (session="57af08bd4c9c37d7c8b6a40cff4b8b20", element="B52638B032F3437EA9139EB1C212BF63_element_216")>, <selenium.webdriver.remote.webelement.WebElement (session="57af08bd4c9c37d7c8b6a40cff4b8b20", element="B52638B032F3437EA9139EB1C212BF63_element_217")>, <selenium.webdriver.remote.webelement.WebElement (session="57af08bd4c9c37d7c8b6a40cff4b8b20", element="B52638B032F3437EA9139EB1C212BF63_element_218")>, <selenium.webdriver.remote.webelement.WebElement (session="57af08bd4c9c37d7c8b6a40cff4b8b20", element="B52638B032F3437EA9139EB1C212BF63_element_219")>, <selenium.webdriver.remote.webelement.WebElement (session="57af08bd4c9c37d7c8b6a40cff4b8b20", element="B52638B032F3437EA9139EB1C212BF63_element_220")>, <selenium.webdriver.remote.webelement.WebElement (session="57af08bd4c9c37d7c8b6a40cff4b8b20", element="B52638B032F3437EA9139EB1C212BF63_element_221")>, <selenium.webdriver.remote.webelement.WebElement (session="57af08bd4c9c37d7c8b6a40cff4b8b20", element="B52638B032F3437EA9139EB1C212BF63_element_222")>, <selenium.webdriver.remote.webelement.WebElement (session="57af08bd4c9c37d7c8b6a40cff4b8b20", element="B52638B032F3437EA9139EB1C212BF63_element_223")>, <selenium.webdriver.remote.webelement.WebElement (session="57af08bd4c9c37d7c8b6a40cff4b8b20", element="B52638B032F3437EA9139EB1C212BF63_element_224")>, <selenium.webdriver.remote.webelement.WebElement (session="57af08bd4c9c37d7c8b6a40cff4b8b20", element="B52638B032F3437EA9139EB1C212BF63_element_225")>, <selenium.webdriver.remote.webelement.WebElemen ...
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# []
# /Users/lvhongxiang/Aiot/Aiot/張學友

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.keys import Keys  #模擬按鍵
from selenium.webdriver.chrome.options import Options  #設定要關掉小鈴鐺
# 抓chromedriver放的路徑
service = Service(executable_path = "/Users/lvhongxiang/Aiot/chromedriver-mac-x64/chromedriver")
driver = webdriver.Chrome(service=service)
#抓網址
driver.get("https://www.google.com/")
name = WebDriverWait(driver,30).until(EC.element_to_be_clickable((By.CSS_SELECTOR,"textarea[title='Google 搜尋']")))
print(name.get_attribute("type"))
name.send_keys("黎明")
name.send_keys(Keys.ENTER)
driver.find_element(By.XPATH,('//*[text()="圖片"]')).click()
driver.find_element(By.XPATH,('//*[text()="工具"]')).click()
driver.find_element(By.XPATH,('//*[text()="大小"]')).click()
driver.find_element(By.XPATH,('//*[text()="大"]')).click()
login = WebDriverWait(driver,30).until(EC.element_to_be_clickable((By.CSS_SELECTOR,"img[src='data:image/jpeg;base64,...'")))
login.click()
login2 = WebDriverWait(driver,30).until(EC.element_to_be_clickable((By.CSS_SELECTOR,"a[href='https://www.4gamers.com.tw/saged/detail/oedr146r71937l']")))
login2.click()
anchor = driver.find_elements(By.CLASS_NAME,("wXeWr"))
print (anchor)
anchor_list = []
for img in anchor[:15]:
    try:
#         img.click()
        anchor_list.append(img.get_attribute("href"))  
        
    except:
        pass
print(anchor_list)
# 方法1
# # srclist=[]
# # for i in anchor_list:
# #     driver.get(i)
# #     for j in driver.find_elements(By.CLASS_NAME,("r48jcc")):
# #         srclist.append(j.get_attribute("src"))
# # print(srclist)
# # 方法2
# # pic = []
# # url = []
# # for url in anchor_list:
# #     try:
# #         driver.get(url)
# #         img = WebDriverWait(driver,30).until(EC.element_to_be_clickable((By.CSS_SELECTOR,'img[class="r48jcc pT0Scc iPVvYb"]')))
# #         pic.append(img.get_attribute("src"))
# #         print(img.get_attribute("src"))
# #     except:
# #         print(url)
# # print(pic)

pic = []
url = []
for url in anchor_list:
    try:
        driver.get(url)
        img = WebDriverWait(driver,30).until(EC.element_to_be_clickable((By.CSS_SELECTOR,'img[class="r48jcc pT0Scc iPVvYb"]')))
        pic.append(img.get_attribute("src"))
        print(img.get_attribute("src"))
    except:
        print(url)
print(pic)
import wget
import os 
path = os.getcwd()
path = os.path.join(path,"黎明")
os.mkdir(path)
print(path)
n=0
for img in pic:
    n += 1
    try:
        file = os.path.join(path,"M"+str(n)+".jpg")
        if os.path.exists(file):
            os.remove(file)
        wget.download(img,file)
        print(file)
    except:
        print(img)

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.keys import Keys  #模擬按鍵
from selenium.webdriver.chrome.options import Options  #設定要關掉小鈴鐺
# 抓chromedriver放的路徑
service = Service(executable_path = "/Users/lvhongxiang/Aiot/chromedriver-mac-x64/chromedriver")
driver = webdriver.Chrome(service=service)
#抓網址
driver.get("https://www.google.com/")
name = WebDriverWait(driver,30).until(EC.element_to_be_clickable((By.CSS_SELECTOR,"textarea[title='Google 搜尋']")))
print(name.get_attribute("type"))
name.send_keys("郭富城")
name.send_keys(Keys.ENTER)
driver.find_element(By.XPATH,('//*[text()="圖片"]')).click()
driver.find_element(By.XPATH,('//*[text()="工具"]')).click()
driver.find_element(By.XPATH,('//*[text()="大小"]')).click()
driver.find_element(By.XPATH,('//*[text()="大"]')).click()
login = WebDriverWait(driver,30).until(EC.element_to_be_clickable((By.CSS_SELECTOR,"img[src='data:image/jpeg;base64,...'")))
login.click()
login2 = WebDriverWait(driver,30).until(EC.element_to_be_clickable((By.CSS_SELECTOR,"a[href='https://www.4gamers.com.tw/saged/detail/oedr146r71937l']")))
login2.click()
anchor = driver.find_elements(By.CLASS_NAME,("wXeWr"))
print (anchor)
anchor_list = []
for img in anchor[:15]:
    try:
#         img.click()
        anchor_list.append(img.get_attribute("href"))  
        
    except:
        pass
print(anchor_list)
# 方法1
# # srclist=[]
# # for i in anchor_list:
# #     driver.get(i)
# #     for j in driver.find_elements(By.CLASS_NAME,("r48jcc")):
# #         srclist.append(j.get_attribute("src"))
# # print(srclist)
# # 方法2
# # pic = []
# # url = []
# # for url in anchor_list:
# #     try:
# #         driver.get(url)
# #         img = WebDriverWait(driver,30).until(EC.element_to_be_clickable((By.CSS_SELECTOR,'img[class="r48jcc pT0Scc iPVvYb"]')))
# #         pic.append(img.get_attribute("src"))
# #         print(img.get_attribute("src"))
# #     except:
# #         print(url)
# # print(pic)

pic = []
url = []
for url in anchor_list:
    try:
        driver.get(url)
        img = WebDriverWait(driver,30).until(EC.element_to_be_clickable((By.CSS_SELECTOR,'img[class="r48jcc pT0Scc iPVvYb"]')))
        pic.append(img.get_attribute("src"))
        print(img.get_attribute("src"))
    except:
        print(url)
print(pic)
import wget
import os 
path = os.getcwd()
path = os.path.join(path,"郭富城")
os.mkdir(path)
print(path)
n=0
for img in pic:
    n += 1
    try:
        file = os.path.join(path,"Q"+str(n)+".jpg")
        if os.path.exists(file):
            os.remove(file)
        wget.download(img,file)
        print(file)
    except:
        print(img)

# %%
pic = []
url = []
for url in anchor_list:
    try:
        driver.get(url)
        img = WebDriverWait(driver,30).until(EC.element_to_be_clickable((By.CSS_SELECTOR,'img[class="r48jcc pT0Scc iPVvYb"]')))
        pic.append(img.get_attribute("src"))
        print(img.get_attribute("src"))
    except:
        print(url)
print(pic)
import wget
import os 
path = os.getcwd()
path = os.path.join(path,"狗狗")
os.mkdir(path)
print(path)
n=0
for img in pic:
    n += 1
    try:
        file = os.path.join(path,"狗狗"+str(n)+".jpg")
        if os.path.exists(file):
            os.remove(file)
        wget.download(img,file)
        print(file)
    except:
        print(img)
# Out:
# None
# None
# None
# None
# None
# []
# /Users/lvhongxiang/Aiot/Aiot/狗狗

# %%
# !pip install wget

# %%
import os 
path = os.getcwd()
path = os.path.join(path,"張學友")
os.mkdir(path)
print(path)

# %%
import wget
import os 
path = os.getcwd()
path = os.path.join(path,"張學友")
os.mkdir(path)
print(path)
n=0
for img in pic:
    n += 1
    try:
        file = os.path.join(path,"Z"+str(n)+".jpg")
        if os.path.exists(file):
            os.remove(file)
        wget.download(img,file)
        print(file)
    except:
        print(img)

# %%
anchor = driver.find_elements(By.CLASS_NAME,("wXeWr"))
anchor_list = []
for img in anchor:
    try:
        img.click()
        anchor_list.append(img.get_attribute("href"))   
#         print(anchor_list)
    except:
        pass
srclist=[]
for i in anchor_list:
    driver.get(i)
    for j in driver.find_elements(By.CLASS_NAME,("r48jcc")):
        srclist.append(j.get_attribute("src"))
print(srclist)

# %%
print(name.get_attribute(""))
anchor = driver.find_elements(By.CLASS_NAME,"wXeWr")
print(anchor)

# %%
from bs4 import BeautifulSoup
# service = Service(executable_path = "/Users/lvhongxiang/chackpoint/chromedriver-mac-x64/chromedriver")
# driver = webdriver.Chrome(service=service)
# driver.get("https://www.google.com/search?q=%E7%8B%97&sca_esv=555729795&source=hp&ei=E5fVZPWSK8Ls1e8PgL2Z4AE&iflsig=AD69kcEAAAAAZNWlI7k_LBWJykj6WIDH6OvRh_J5I2Wz&ved=0ahUKEwi16IGEwtOAAxVCdvUHHYBeBhwQ4dUDCAs&uact=5&oq=%E7%8B%97&gs_lp=Egdnd3Mtd2l6IgPni5cyBRAuGIAEMgsQABiABBixAxiDATILEC4YigUYsQMYgwEyCxAAGIAEGLEDGIMBMggQABiABBixAzILEAAYigUYsQMYgwEyCxAAGIAEGLEDGIMBMgUQABiABDIIEAAYgAQYsQMyCBAuGIAEGLEDSMYKUABYAHAAeACQAQCYAdkCoAHZAqoBAzMtMbgBA8gBAPgBAQ&sclient=gws-wiz")
soup = BeautifulSoup(driver.page_source,"html.parser")
# jobs = soup.find_all("div",class_="iblpc")
# jobs = soup.find_all("textarea",title="Google 搜尋")
print(soup)

# username = WebDriverWait(driver,30).until(EC.element_to_be_clickable((By.CSS_SELECTOR,"textarea[title='Google 搜尋']")))
# username.send_keys("狗")
# # print(jobs)
# login = WebDriverWait(driver,10).until(EC.element_to_be_clickable((By.CSS_SELECTOR,"a[id=searchjobBtn]")))
# # 點擊登入的
# # login.click()
# login.send_keys(Keys.ENTER)

# %%
<a class="wXeWr islib nfEiy" jsname="sTFXNd" tabindex="0" role="button"
jsaction="J9iaEb;mousedown:npT2md; touchstart:npT2md;" 
data-nav="1" style="height: 180px;" 
href="/imgres?imgurl=https%3A%2F%2Fugc-media.4gamers.com.tw%2Fpuku-prod-zh%2Fmember%2FgX2PQnQ7FapzgjbbZUWYrzbYmXA%2Fmondou%2F803dbd99-af8d-42e0-984f-0fbe58e834d7.jpg&amp;tbnid=rFIMGhwezeJwtM&amp;vet=12ahUKEwi3suT6zNOAAxUw0DQHHVaWBmYQMygAegUIARD1AQ..i&amp;imgrefurl=https%3A%2F%2Fwww.4gamers.com.tw%2Fsaged%2Fdetail%2Foedr146r71937l&amp;docid=itYsrRt0crXOuM&amp;w=1280&amp;h=1280&amp;q=%E7%8B%97&amp;hl=zh-TW&amp;ved=2ahUKEwi3suT6zNOAAxUw0DQHHVaWBmYQMygAegUIARD1AQ" 
data-navigation="server"><div class="bRMDJf islir" jsname="DeysSe" style="margin-left: 73px; margin-right: 72px; height: 225px; margin-top: -37px;"><img src="data:image/jpeg;base64,..." data-deferred="1" class="rg_i Q4LuWd" jsname="Q4LuWd" width="225" height="225" alt="如果要養狗，大家會首推哪種品種？ | 4Gamers" data-iml="1398.6000000014901" data-atf="true"></div><div class="c7cjWc mvjhOe"></div></a>

<img src="data:image/jpeg;base64,..." jsaction="VQAsE" class="r48jcc pT0Scc" alt="如果要養狗，大家會首推哪種品種？ | 4Gamers" jsname="JuXqh" style="max-width: 1280px; width: 325px; height: 325px; margin: 0px;" data-iml="467714.5">
<img src="data:image/jpeg;base64,..." data-deferred="1" class="rg_i Q4LuWd" jsname="Q4LuWd" width="180" height="180" alt="如果要養狗，大家會首推哪種品種？ | 4Gamers" data-iml="1313" data-atf="true">



 <a role="link" tabindex="0" rel="noopener" target="_blank" href="https://www.4gamers.com.tw/saged/detail/oedr146r71937l" jsaction="focus:trigger.HTIQtd;mousedown:trigger.HTIQtd;touchstart:trigger.HTIQtd;" aria-label="造訪「4Gamers」" class="Du2c7e" data-ved="0CA4QjRxqFwoTCLivlNXT04ADFQAAAAAdAAAAABAH"><img src="data:image/jpeg;base64,..." jsaction="VQAsE" class="r48jcc pT0Scc" alt="如果要養狗，大家會首推哪種品種？ | 4Gamers" jsname="JuXqh" style="max-width: 1280px; width: 325px; height: 325px; margin: 0px;" data-iml="467714.5"><span class="agI2ne">1,280 × 1,280</span></a>

# %%
import requests
import json

payload = json.loads('{"promotionid":156847592116227,"categoryid":0,"itemids":[14935404262,1717333578,670560873,8903205420,1436760706,158220308,12798224013,10098503987,1396599654,5519328843,16173195396,15082693079,10062670988,5850657759,2350392364,19161601768],"limit":16,"with_dp_items":true}')
res = requests.post('https://shopee.tw/api/v4/flash_sale/flash_sale_batch_get_items',json=payload)

jd = json.loads(res.text)
print(jd)
