# %%
# pip install selenium

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
# 抓chromedriver放的路徑
service = Service(executable_path = "/Users/lvhongxiang/Aiot/chromedriver-mac-x64/chromedriver")
driver = webdriver.Chrome(service=service)
#抓網址
driver.get("https://popcat.click/")
div = driver.find_element(By.ID,"app")
div.click()

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.keys import Keys  #模擬按鍵
from selenium.webdriver.chrome.options import Options  #設定要關掉小鈴鐺

option = webdriver.ChromeOptions()   
prefs = {"profile.default_content_setting_values":{"notifications":2}}
option.add_experimental_option("prefs",prefs)
password = ""

# 抓chromedriver放的路徑
service = Service(executable_path = "/Users/lvhongxiang/Aiot/chromedriver-mac-x64/chromedriver",options=option)
driver = webdriver.Chrome(service=service)
# 讀取網址是否可以輸入
driver.get("https://www.facebook.com/")
# 網頁F12抓取帳號所需要的位置
username = WebDriverWait(driver,10).until(EC.element_to_be_clickable((By.CSS_SELECTOR,"input[name='email']")))
# 輸入帳號的位置
username.send_keys("linjocowbala4@gmail.com")
# 網頁F12抓取密碼所需要的位置
passWord = WebDriverWait(driver,10).until(EC.element_to_be_clickable((By.CSS_SELECTOR,"input[name='pass']")))
# 輸入密碼的位置
passWord.send_keys(password)
# 網頁F12抓取登入所需要的位置
login = WebDriverWait(driver,10).until(EC.element_to_be_clickable((By.CSS_SELECTOR,"button[name='login']")))
# 點擊登入的
# username.click()
login.send_keys(Keys.ENTER)

# %%
import json
cookie = driver.get_cookies()
print(cookie)
jsoncookie = json.dumps(cookie)
with open("facebook.json","w") as f:
#     寫入jsoncookie
    f.write(jsoncookie)    
    f.close()

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.keys import Keys  #模擬按鍵
from selenium.webdriver.chrome.options import Options  #設定要關掉小鈴鐺

option = webdriver.ChromeOptions()   
prefs = {"profile.default_content_setting_values":{"notifications":2}}
option.add_experimental_option("prefs",prefs)

password = ""

# 抓chromedriver放的路徑
service = Service(executable_path = "/Users/lvhongxiang/Aiot/chromedriver-mac-x64/chromedriver",options=option)
driver = webdriver.Chrome(service=service)
driver.get("https://www.facebook.com/")

f1 = open("facebook.json")
cookies = json.loads(f1.read())
for i in cookies:
    driver.add_cookie(i)
f.close

driver.refresh()

# %%
# -----------------------------------------------------------------------

# 1111人力銀行練習

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.keys import Keys  #模擬按鍵
from selenium.webdriver.chrome.options import Options  #設定要關掉小鈴鐺
# 抓chromedriver放的路徑
service = Service(executable_path = "/Users/lvhongxiang/Aiot/chromedriver-mac-x64/chromedriver")
driver = webdriver.Chrome(service=service)
#抓網址
driver.get("https://www.1111.com.tw/")
username = WebDriverWait(driver,30).until(EC.element_to_be_clickable((By.CSS_SELECTOR,"input[name='ks']")))
username.send_keys("大數據")

# location = WebDriverWait(driver,10).until(EC.element_to_be_clickable((By.LINK_TEXT,"地點")))
# print(test.get_attribute("outerHTML"))
# # 點擊登入的
# location.click()

login = WebDriverWait(driver,10).until(EC.element_to_be_clickable((By.CSS_SELECTOR,"a[id=searchjobBtn]")))
# 點擊登入的
login.click()
# login.send_keys(Keys.ENTER)

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(driver.page_source,"html.parser")
jobs = soup.find_all("div")
# "h6",class_="job_item_company mb-1 digit_5 body_3")[0].text
print(jobs)
# [calss_='job_item_info']
# print(soup)
# jobs = []
# for job in soup:
#     print (job.find("h6",class_="job_item_company mb-1 digit_5 body_3").text)
# #     jobs.append(job)
# #     print(job)
# Out:
# [<div class="container">
# <!-- logo -->
# <a class="navbar-brand" href="https://www.1111.com.tw"></a>
# <!-- nav左 -->
# <ul class="nav_right_left navbar-nav mr-auto d-none d-md-flex">
# <li class="nav-item dropdown">
# <a class="nav-link nav_link_category dropdown-toggle" data-toggle="dropdown" href="#">
# <span>類別找工作</span>
# </a>
# <div class="dropdown-menu dropdown_category">
# <div class="row">
# <div class="col">
# <h3>地區</h3>
# <ul class="UI_list_link">
# <li><a ad_id="310465" href="https://www.1111tc.com.tw/" onclick="setHref(310465)" target="_blank">中部找工作</a></li>
# <li><a ad_id="310466" href="https://www.1111job.com.tw/" onclick="setHref(310466)" target="_blank">南部找工作</a></li>
# </ul>
# </div>
# <div class="col">
# <h3>工作型態</h3>
# <ul class="UI_list_link">
# <li><a ad_id="310558" href="https://www.1111transfer.com.tw/" onclick="setHref(310558)" target="_blank">轉職專區</a></li>
# ...

# %%
import time 
for a in range(20):
    driver.execute_script("window.scrollTo(0,document.documentElement.scrollHeight)-1800")
    time.sleep(1)
    driver.execute_script("window.scrollTo(0,document.documentElement.scrollHeight)-2000")
    time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Cell In[28], line 3
#       1 import time
#       2 for a in range(20):
# ----> 3     driver.execute_script("window.scrollTo(0,document.documentElement.scrollHeight)-1800")
#       4     time.sleep(1)
#       5     driver.execute_script("window.scrollTo(0,document.documentElement.scrollHeight)-2000")
#
# File ~/anaconda3/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:405, in WebDriver.execute_script(self, script, *args)
#     402 converted_args = list(args)
#     403 command = Command.W3C_EXECUTE_SCRIPT
# --> 405 return self.execute(command, {"script": script, "args": converted_args})["value"]
#
# File ~/anaconda3/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:345, in WebDriver.execute(self, driver_command, params)
#     343 response = self.command_executor.execute(driver_command, params)
# ...

# %%
#到最下面
driver.execute_script("window.scrollTo(0,document.documentElement.scrollHeight)")
