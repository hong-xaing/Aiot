# %%
def gcd(a,b):
    while b!=0 :
        a,b =b, a%b
    return a

num1 = int(input("請輸入第一個數字"))
num2 = int(input("請輸入第二個數字"))

result = gcd(num1,num2)
print (result)
# Out:
# 請輸入數字11
# 請輸入數字22
# 1

# %%
def gcd(a,b):
    if b == 0 :
        return a
    return(gcd(b, a %b))
num1 = int(input("請輸入第一個數字"))
num2 = int(input("請輸入第二個數字"))

result = gcd(num1,num2)
print (result)
# Out:
# 請輸入第一個數字2
# 請輸入第二個數字4
# 2

# %%
# !pip install cifar10
# Out:
# Collecting cifar10
#   Downloading cifar10-1.0.0-py3-none-any.whl (7.9 kB)
# Requirement already satisfied: tqdm in /Users/lvhongxiang/anaconda3/lib/python3.10/site-packages (from cifar10) (4.64.1)
# Requirement already satisfied: numpy in /Users/lvhongxiang/anaconda3/lib/python3.10/site-packages (from cifar10) (1.23.5)
# Requirement already satisfied: requests in /Users/lvhongxiang/anaconda3/lib/python3.10/site-packages (from cifar10) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/lvhongxiang/anaconda3/lib/python3.10/site-packages (from requests->cifar10) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/lvhongxiang/anaconda3/lib/python3.10/site-packages (from requests->cifar10) (2022.12.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/lvhongxiang/anaconda3/lib/python3.10/site-packages (from requests->cifar10) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in /Users/lvhongxiang/anaconda3/lib/python3.10/site-packages (from requests->cifar10) (3.4)
# Installing collected packages: cifar10
# Successfully installed cifar10-1.0.0

# %%
# 3.分類cifar10讓ACC盡量高
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical

# 處理資料
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255
num_classes = 10
y_train = to_categorical(y_train, num_classes = num_classes)
y_test = to_categorical(y_test, num_classes = num_classes)

# 建立模型

model = tf.keras.

# 編譯模型








# 訓練模型



print('val_loss: {:.3f}nval_acc: {:.3f}'.format(test_loss, test_acc ))

cifar10.load_data()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 11
#       9 y_train = to_categorical(y_train, num_classes = num_classes)
#      10 y_test = to_categorical(y_test, num_classes = num_classes)
# ---> 11 print('val_loss: {:.3f}nval_acc: {:.3f}'.format(test_loss, test_acc ))
#      13 cifar10.load_data()
#
# NameError: name 'test_loss' is not defined

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical

# 載入並預處理數據集
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255
num_classes = 10
y_train = to_categorical(y_train, num_classes=num_classes)
y_test = to_categorical(y_test, num_classes=num_classes)

# 建立模型
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(num_classes, activation='softmax')
])

# 編譯模型
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# 訓練模型
model.fit(X_train, y_train, batch_size=32, epochs=100, validation_split=0.1)

# 評估模型
test_loss, test_acc = model.evaluate(X_test, y_test)
print('test_loss: {:.3f}\ntest_acc: {:.3f}'.format(test_loss, test_acc))
# Out:
# Epoch 1/100
# 1407/1407 [==============================] - 15s 10ms/step - loss: 1.4938 - accuracy: 0.4579 - val_loss: 1.2376 - val_accuracy: 0.5600
# Epoch 2/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 1.1073 - accuracy: 0.6117 - val_loss: 1.0215 - val_accuracy: 0.6462
# Epoch 3/100
# 1407/1407 [==============================] - 16s 12ms/step - loss: 0.9383 - accuracy: 0.6700 - val_loss: 0.9006 - val_accuracy: 0.6858
# Epoch 4/100
# 1407/1407 [==============================] - 16s 11ms/step - loss: 0.8225 - accuracy: 0.7130 - val_loss: 0.8262 - val_accuracy: 0.7144
# Epoch 5/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.7397 - accuracy: 0.7421 - val_loss: 0.8198 - val_accuracy: 0.7076
# Epoch 6/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.6569 - accuracy: 0.7705 - val_loss: 0.7833 - val_accuracy: 0.7242
# Epoch 7/100
# 1407/1407 [==============================] - 16s 12ms/step - loss: 0.5927 - accuracy: 0.7947 - val_loss: 0.8127 - val_accuracy: 0.7236
# Epoch 8/100
# 1407/1407 [==============================] - 17s 12ms/step - loss: 0.5262 - accuracy: 0.8154 - val_loss: 0.8372 - val_accuracy: 0.7280
# Epoch 9/100
# 1407/1407 [==============================] - 16s 11ms/step - loss: 0.4640 - accuracy: 0.8369 - val_loss: 0.8586 - val_accuracy: 0.7278
# Epoch 10/100
# 1407/1407 [==============================] - 15s 10ms/step - loss: 0.4078 - accuracy: 0.8571 - val_loss: 0.9236 - val_accuracy: 0.7204
# Epoch 11/100
# 1407/1407 [==============================] - 15s 10ms/step - loss: 0.3544 - accuracy: 0.8762 - val_loss: 0.9987 - val_accuracy: 0.7258
# Epoch 12/100
# 1407/1407 [==============================] - 16s 11ms/step - loss: 0.3141 - accuracy: 0.8884 - val_loss: 1.0563 - val_accuracy: 0.7178
# Epoch 13/100
# 1407/1407 [==============================] - 16s 11ms/step - loss: 0.2625 - accuracy: 0.9059 - val_loss: 1.1729 - val_accuracy: 0.7168
# Epoch 14/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.2421 - accuracy: 0.9132 - val_loss: 1.3133 - val_accuracy: 0.7102
# Epoch 15/100
# 1407/1407 [==============================] - 14s 10ms/step - loss: 0.2073 - accuracy: 0.9265 - val_loss: 1.3805 - val_accuracy: 0.6990
# Epoch 16/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.1816 - accuracy: 0.9351 - val_loss: 1.4259 - val_accuracy: 0.7114
# Epoch 17/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.1645 - accuracy: 0.9411 - val_loss: 1.5078 - val_accuracy: 0.7174
# Epoch 18/100
# 1407/1407 [==============================] - 16s 11ms/step - loss: 0.1610 - accuracy: 0.9435 - val_loss: 1.6473 - val_accuracy: 0.6966
# Epoch 19/100
# 1407/1407 [==============================] - 17s 12ms/step - loss: 0.1441 - accuracy: 0.9499 - val_loss: 1.6530 - val_accuracy: 0.7000
# Epoch 20/100
# 1407/1407 [==============================] - 19s 14ms/step - loss: 0.1396 - accuracy: 0.9517 - val_loss: 1.8244 - val_accuracy: 0.7058
# Epoch 21/100
# 1407/1407 [==============================] - 19s 14ms/step - loss: 0.1279 - accuracy: 0.9550 - val_loss: 1.8396 - val_accuracy: 0.7064
# Epoch 22/100
# 1407/1407 [==============================] - 19s 14ms/step - loss: 0.1238 - accuracy: 0.9560 - val_loss: 1.8358 - val_accuracy: 0.7088
# Epoch 23/100
# 1407/1407 [==============================] - 20s 14ms/step - loss: 0.1053 - accuracy: 0.9623 - val_loss: 1.9537 - val_accuracy: 0.7040
# Epoch 24/100
# 1407/1407 [==============================] - 19s 14ms/step - loss: 0.1205 - accuracy: 0.9588 - val_loss: 1.9889 - val_accuracy: 0.6952
# Epoch 25/100
# 1407/1407 [==============================] - 20s 14ms/step - loss: 0.1057 - accuracy: 0.9638 - val_loss: 2.0774 - val_accuracy: 0.7010
# Epoch 26/100
# 1407/1407 [==============================] - 21s 15ms/step - loss: 0.1093 - accuracy: 0.9625 - val_loss: 2.0972 - val_accuracy: 0.6986
# Epoch 27/100
# 1407/1407 [==============================] - 18s 13ms/step - loss: 0.0942 - accuracy: 0.9675 - val_loss: 2.1645 - val_accuracy: 0.7006
# Epoch 28/100
# 1407/1407 [==============================] - 19s 13ms/step - loss: 0.1024 - accuracy: 0.9658 - val_loss: 2.2961 - val_accuracy: 0.7026
# Epoch 29/100
# 1407/1407 [==============================] - 19s 14ms/step - loss: 0.0958 - accuracy: 0.9677 - val_loss: 2.2500 - val_accuracy: 0.7004
# Epoch 30/100
# 1407/1407 [==============================] - 19s 14ms/step - loss: 0.0943 - accuracy: 0.9690 - val_loss: 2.2152 - val_accuracy: 0.7030
# Epoch 31/100
# 1407/1407 [==============================] - 18s 13ms/step - loss: 0.0895 - accuracy: 0.9696 - val_loss: 2.2631 - val_accuracy: 0.7068
# Epoch 32/100
# 1407/1407 [==============================] - 19s 14ms/step - loss: 0.1001 - accuracy: 0.9671 - val_loss: 2.3052 - val_accuracy: 0.6998
# Epoch 33/100
# 1407/1407 [==============================] - 20s 14ms/step - loss: 0.0853 - accuracy: 0.9720 - val_loss: 2.3451 - val_accuracy: 0.7012
# Epoch 34/100
# 1407/1407 [==============================] - 20s 14ms/step - loss: 0.0842 - accuracy: 0.9730 - val_loss: 2.5472 - val_accuracy: 0.6990
# Epoch 35/100
# 1407/1407 [==============================] - 22s 16ms/step - loss: 0.0813 - accuracy: 0.9731 - val_loss: 2.6088 - val_accuracy: 0.7008
# Epoch 36/100
# 1407/1407 [==============================] - 19s 14ms/step - loss: 0.0887 - accuracy: 0.9709 - val_loss: 2.4831 - val_accuracy: 0.7088
# Epoch 37/100
# 1407/1407 [==============================] - 20s 14ms/step - loss: 0.0824 - accuracy: 0.9727 - val_loss: 2.5582 - val_accuracy: 0.7012
# Epoch 38/100
# 1407/1407 [==============================] - 20s 14ms/step - loss: 0.0796 - accuracy: 0.9743 - val_loss: 2.7778 - val_accuracy: 0.7038
# Epoch 39/100
# 1407/1407 [==============================] - 21s 15ms/step - loss: 0.0859 - accuracy: 0.9727 - val_loss: 2.5025 - val_accuracy: 0.7006
# Epoch 40/100
# 1407/1407 [==============================] - 20s 14ms/step - loss: 0.0713 - accuracy: 0.9765 - val_loss: 2.8454 - val_accuracy: 0.6990
# Epoch 41/100
# 1407/1407 [==============================] - 20s 14ms/step - loss: 0.0824 - accuracy: 0.9736 - val_loss: 2.6002 - val_accuracy: 0.6958
# Epoch 42/100
# 1407/1407 [==============================] - 19s 13ms/step - loss: 0.0769 - accuracy: 0.9756 - val_loss: 2.6331 - val_accuracy: 0.6978
# Epoch 43/100
# 1407/1407 [==============================] - 19s 14ms/step - loss: 0.0760 - accuracy: 0.9753 - val_loss: 2.7055 - val_accuracy: 0.6918
# Epoch 44/100
# 1407/1407 [==============================] - 19s 13ms/step - loss: 0.0683 - accuracy: 0.9783 - val_loss: 2.9705 - val_accuracy: 0.6786
# Epoch 45/100
# 1407/1407 [==============================] - 19s 14ms/step - loss: 0.0802 - accuracy: 0.9755 - val_loss: 2.8481 - val_accuracy: 0.6932
# Epoch 46/100
# 1407/1407 [==============================] - 19s 13ms/step - loss: 0.0711 - accuracy: 0.9781 - val_loss: 2.8494 - val_accuracy: 0.6978
# Epoch 47/100
# 1407/1407 [==============================] - 19s 13ms/step - loss: 0.0652 - accuracy: 0.9795 - val_loss: 2.9210 - val_accuracy: 0.6986
# Epoch 48/100
# 1407/1407 [==============================] - 19s 14ms/step - loss: 0.0778 - accuracy: 0.9762 - val_loss: 2.9535 - val_accuracy: 0.6996
# Epoch 49/100
# 1407/1407 [==============================] - 19s 14ms/step - loss: 0.0654 - accuracy: 0.9796 - val_loss: 2.9916 - val_accuracy: 0.6906
# Epoch 50/100
# 1407/1407 [==============================] - 19s 13ms/step - loss: 0.0615 - accuracy: 0.9803 - val_loss: 3.0627 - val_accuracy: 0.6950
# Epoch 51/100
# 1407/1407 [==============================] - 20s 14ms/step - loss: 0.0794 - accuracy: 0.9753 - val_loss: 2.9268 - val_accuracy: 0.7006
# Epoch 52/100
# 1407/1407 [==============================] - 19s 14ms/step - loss: 0.0624 - accuracy: 0.9799 - val_loss: 3.1512 - val_accuracy: 0.7038
# Epoch 53/100
# 1407/1407 [==============================] - 15s 11ms/step - loss: 0.0663 - accuracy: 0.9802 - val_loss: 3.0868 - val_accuracy: 0.6960
# Epoch 54/100
# 1407/1407 [==============================] - 416s 296ms/step - loss: 0.0629 - accuracy: 0.9816 - val_loss: 3.1892 - val_accuracy: 0.6984
# Epoch 55/100
# 1407/1407 [==============================] - 13s 10ms/step - loss: 0.0644 - accuracy: 0.9802 - val_loss: 3.0155 - val_accuracy: 0.6976
# Epoch 56/100
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.0674 - accuracy: 0.9798 - val_loss: 3.2034 - val_accuracy: 0.6866
# Epoch 57/100
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.0668 - accuracy: 0.9802 - val_loss: 3.0855 - val_accuracy: 0.6910
# Epoch 58/100
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.0635 - accuracy: 0.9810 - val_loss: 3.2248 - val_accuracy: 0.6966
# Epoch 59/100
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.0569 - accuracy: 0.9824 - val_loss: 3.2459 - val_accuracy: 0.6964
# Epoch 60/100
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.0675 - accuracy: 0.9798 - val_loss: 3.2112 - val_accuracy: 0.6984
# Epoch 61/100
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.0593 - accuracy: 0.9818 - val_loss: 3.1693 - val_accuracy: 0.7036
# Epoch 62/100
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.0656 - accuracy: 0.9810 - val_loss: 3.2327 - val_accuracy: 0.6932
# Epoch 63/100
# 1407/1407 [==============================] - 14s 10ms/step - loss: 0.0600 - accuracy: 0.9820 - val_loss: 3.0666 - val_accuracy: 0.7090
# Epoch 64/100
# 1407/1407 [==============================] - 13s 10ms/step - loss: 0.0636 - accuracy: 0.9815 - val_loss: 3.4108 - val_accuracy: 0.6980
# Epoch 65/100
# 1407/1407 [==============================] - 14s 10ms/step - loss: 0.0698 - accuracy: 0.9803 - val_loss: 3.4185 - val_accuracy: 0.6950
# Epoch 66/100
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.0590 - accuracy: 0.9831 - val_loss: 3.4895 - val_accuracy: 0.6934
# Epoch 67/100
# 1407/1407 [==============================] - 14s 10ms/step - loss: 0.0520 - accuracy: 0.9848 - val_loss: 3.4890 - val_accuracy: 0.7030
# Epoch 68/100
# 1407/1407 [==============================] - 13s 10ms/step - loss: 0.0601 - accuracy: 0.9824 - val_loss: 3.4937 - val_accuracy: 0.6954
# Epoch 69/100
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.0619 - accuracy: 0.9825 - val_loss: 3.8903 - val_accuracy: 0.6920
# Epoch 70/100
# 1407/1407 [==============================] - 14s 10ms/step - loss: 0.0474 - accuracy: 0.9858 - val_loss: 3.4897 - val_accuracy: 0.6962
# Epoch 71/100
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.0721 - accuracy: 0.9801 - val_loss: 3.6034 - val_accuracy: 0.6998
# Epoch 72/100
# 1407/1407 [==============================] - 13s 10ms/step - loss: 0.0531 - accuracy: 0.9842 - val_loss: 3.6564 - val_accuracy: 0.6954
# Epoch 73/100
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.0549 - accuracy: 0.9842 - val_loss: 3.6965 - val_accuracy: 0.6860
# Epoch 74/100
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.0570 - accuracy: 0.9836 - val_loss: 3.5795 - val_accuracy: 0.7012
# Epoch 75/100
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.0625 - accuracy: 0.9824 - val_loss: 3.5403 - val_accuracy: 0.7010
# Epoch 76/100
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.0530 - accuracy: 0.9850 - val_loss: 3.6096 - val_accuracy: 0.6954
# Epoch 77/100
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.0600 - accuracy: 0.9828 - val_loss: 3.8343 - val_accuracy: 0.6938
# Epoch 78/100
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.0513 - accuracy: 0.9856 - val_loss: 3.6217 - val_accuracy: 0.6944
# Epoch 79/100
# 1407/1407 [==============================] - 14s 10ms/step - loss: 0.0568 - accuracy: 0.9841 - val_loss: 3.7050 - val_accuracy: 0.7014
# Epoch 80/100
# 1407/1407 [==============================] - 13s 10ms/step - loss: 0.0599 - accuracy: 0.9834 - val_loss: 3.9571 - val_accuracy: 0.6950
# Epoch 81/100
# 1407/1407 [==============================] - 14s 10ms/step - loss: 0.0543 - accuracy: 0.9845 - val_loss: 3.7431 - val_accuracy: 0.7048
# Epoch 82/100
# 1407/1407 [==============================] - 14s 10ms/step - loss: 0.0590 - accuracy: 0.9836 - val_loss: 3.8162 - val_accuracy: 0.6844
# Epoch 83/100
# 1407/1407 [==============================] - 14s 10ms/step - loss: 0.0501 - accuracy: 0.9849 - val_loss: 4.0081 - val_accuracy: 0.6934
# Epoch 84/100
# 1407/1407 [==============================] - 14s 10ms/step - loss: 0.0609 - accuracy: 0.9832 - val_loss: 3.9636 - val_accuracy: 0.6944
# Epoch 85/100
# 1407/1407 [==============================] - 13s 10ms/step - loss: 0.0518 - accuracy: 0.9857 - val_loss: 3.8441 - val_accuracy: 0.7006
# Epoch 86/100
# 1407/1407 [==============================] - 14s 10ms/step - loss: 0.0598 - accuracy: 0.9846 - val_loss: 4.0256 - val_accuracy: 0.6954
# Epoch 87/100
# 1407/1407 [==============================] - 14s 10ms/step - loss: 0.0485 - accuracy: 0.9872 - val_loss: 4.0744 - val_accuracy: 0.6882
# Epoch 88/100
# 1407/1407 [==============================] - 14s 10ms/step - loss: 0.0544 - accuracy: 0.9848 - val_loss: 4.0940 - val_accuracy: 0.6962
# Epoch 89/100
# 1407/1407 [==============================] - 14s 10ms/step - loss: 0.0515 - accuracy: 0.9853 - val_loss: 4.0777 - val_accuracy: 0.6934
# Epoch 90/100
# 1407/1407 [==============================] - 14s 10ms/step - loss: 0.0680 - accuracy: 0.9830 - val_loss: 3.9710 - val_accuracy: 0.6826
# Epoch 91/100
# 1407/1407 [==============================] - 13s 10ms/step - loss: 0.0454 - accuracy: 0.9867 - val_loss: 4.1482 - val_accuracy: 0.6966
# Epoch 92/100
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.0512 - accuracy: 0.9857 - val_loss: 4.0110 - val_accuracy: 0.6974
# Epoch 93/100
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.0442 - accuracy: 0.9876 - val_loss: 4.2865 - val_accuracy: 0.6992
# Epoch 94/100
# 1407/1407 [==============================] - 14s 10ms/step - loss: 0.0634 - accuracy: 0.9838 - val_loss: 4.2427 - val_accuracy: 0.6976
# Epoch 95/100
# 1407/1407 [==============================] - 14s 10ms/step - loss: 0.0513 - accuracy: 0.9864 - val_loss: 4.3991 - val_accuracy: 0.6942
# Epoch 96/100
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.0553 - accuracy: 0.9852 - val_loss: 4.4423 - val_accuracy: 0.6892
# Epoch 97/100
# 1407/1407 [==============================] - 13s 9ms/step - loss: 0.0556 - accuracy: 0.9857 - val_loss: 4.3530 - val_accuracy: 0.6922
# Epoch 98/100
# 1407/1407 [==============================] - 14s 10ms/step - loss: 0.0621 - accuracy: 0.9848 - val_loss: 4.3645 - val_accuracy: 0.6912
# Epoch 99/100
# 1407/1407 [==============================] - 14s 10ms/step - loss: 0.0427 - accuracy: 0.9881 - val_loss: 4.5581 - val_accuracy: 0.6834
# Epoch 100/100
# 1407/1407 [==============================] - 14s 10ms/step - loss: 0.0526 - accuracy: 0.9864 - val_loss: 4.2776 - val_accuracy: 0.6906
# 313/313 [==============================] - 1s 3ms/step - loss: 4.4361 - accuracy: 0.6796
# test_loss: 4.436
# test_acc: 0.680

# %%
import os

# 獲取當前工作目錄
current_directory = os.getcwd()
print("當前工作目錄：", current_directory)
# Out:
# 當前工作目錄： /Users/lvhongxiang/Aiot/Aiot

# %%
訂位系統
