# %%
pip install selenium

# %%
# 目的分析從舊遊戲到新遊戲的銷售情況分析出大眾玩家在購買的時間區間,購買的價格,
# 購買的種類類型,判斷就遊戲在退流行時候的定價,以及剛上市的定價會不會因為遊戲的ＧＢ容量大小影響
# 回傳年份(點進去可以看到他的發行日),回傳價格(定價),回傳購買人氣（最暢銷亦或是下載最多次數),
# 回傳遊戲種類(冒險類還是戰略類型),回傳購買年齡(如果有就用沒有就算了),回傳需要的最建議遊戲配備（ps4 or ps5)
# https://store.playstation.com/zh-hant-tw/category/05a2d027-cedc-4ac0-abeb-8fc26fec7180/1?ACTION=productGenres&ADVENTURE=productGenres&ROLE_PLAYING_GAMES=productGenres

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.keys import Keys  #模擬按鍵
from selenium.webdriver.chrome.options import Options  #設定要關掉小鈴鐺
# 抓chromedriver放的路徑
service = Service(executable_path = "C:\\Users\\User\\Desktop\\Aiot\\chromedriver-win64\\chromedriver.exe")
driver = webdriver.Chrome(service=service)
#抓網址
driver.get("https://store.playstation.com/zh-hant-tw/category/5f3aa730-1c8e-4a18-84da-030bb91558c0/1")
anchor = driver.find_elements(By.CLASS_NAME,("psw-l-w-1/1"))
print(anchor)
# anchor_list = []
# for a in anchor[:5]:
#     try:
# #         a.click()
#         anchor_list.append(a.get_attribute("href"))   
#     except:
#         pass
# print(anchor_list)
# pic = []
# url = []
# for url in anchor_list:
#     try:
#         driver.get(url)
#         img = WebDriverWait(driver,30).until(EC.element_to_be_clickable((By.CSS_SELECTOR,'img[class="r48jcc pT0Scc iPVvYb"]')))
#         pic.append(img.get_attribute("src"))
#         print(img.get_attribute("src"))
#     except:
#         print(url)
# print(pic)

# %%
[<selenium.webdriver.remote.webelement.WebElement (session="9686530846633518f65beccf7fc0d341", element="684AF907A7D5ECB9C91AA5ED773CD730_element_15")>, <selenium.webdriver.remote.webelement.WebElement (session="9686530846633518f65beccf7fc0d341", element="684AF907A7D5ECB9C91AA5ED773CD730_element_18")>, <selenium.webdriver.remote.webelement.WebElement (session="9686530846633518f65beccf7fc0d341", element="684AF907A7D5ECB9C91AA5ED773CD730_element_19")>, <selenium.webdriver.remote.webelement.WebElement (session="9686530846633518f65beccf7fc0d341", element="684AF907A7D5ECB9C91AA5ED773CD730_element_17")>, <selenium.webdriver.remote.webelement.WebElement (session="9686530846633518f65beccf7fc0d341", element="684AF907A7D5ECB9C91AA5ED773CD730_element_20")>, <selenium.webdriver.remote.webelement.WebElement (session="9686530846633518f65beccf7fc0d341", element="684AF907A7D5ECB9C91AA5ED773CD730_element_21")>, <selenium.webdriver.remote.webelement.WebElement (session="9686530846633518f65beccf7fc0d341", element="684AF907A7D5ECB9C91AA5ED773CD730_element_22")>, <selenium.webdriver.remote.webelement.WebElement (session="9686530846633518f65beccf7fc0d341", element="684AF907A7D5ECB9C91AA5ED773CD730_element_16")>, <selenium.webdriver.remote.webelement.WebElement (session="9686530846633518f65beccf7fc0d341", element="684AF907A7D5ECB9C91AA5ED773CD730_element_23")>, <selenium.webdriver.remote.webelement.WebElement (session="9686530846633518f65beccf7fc0d341", element="684AF907A7D5ECB9C91AA5ED773CD730_element_24")>, <selenium.webdriver.remote.webelement.WebElement (session="9686530846633518f65beccf7fc0d341", element="684AF907A7D5ECB9C91AA5ED773CD730_element_25")>, <selenium.webdriver.remote.webelement.WebElement (session="9686530846633518f65beccf7fc0d341", element="684AF907A7D5ECB9C91AA5ED773CD730_element_26")>, <selenium.webdriver.remote.webelement.WebElement (session="9686530846633518f65beccf7fc0d341", element="684AF907A7D5ECB9C91AA5ED773CD730_element_27")>, <selenium.webdriver.remote.webelement.WebElement (session="9686530846633518f65beccf7fc0d341", element="684AF907A7D5ECB9C91AA5ED773CD730_element_28")>, <selenium.webdriver.remote.webelement.WebElement (session="9686530846633518f65beccf7fc0d341", element="684AF907A7D5ECB9C91AA5ED773CD730_element_29")>, <selenium.webdriver.remote.webelement.WebElement (session="9686530846633518f65beccf7fc0d341", element="684AF907A7D5ECB9C91AA5ED773CD730_element_30")>, <selenium.webdriver.remote.webelement.WebElement (session="9686530846633518f65beccf7fc0d341", element="684AF907A7D5ECB9C91AA5ED773CD730_element_31")>, <selenium.webdriver.remote.webelement.WebElement (session="9686530846633518f65beccf7fc0d341", element="684AF907A7D5ECB9C91AA5ED773CD730_element_32")>, <selenium.webdriver.remote.webelement.WebElement (session="9686530846633518f65beccf7fc0d341", element="684AF907A7D5ECB9C91AA5ED773CD730_element_33")>, <selenium.webdriver.remote.webelement.WebElement (session="9686530846633518f65beccf7fc0d341", element="684AF907A7D5ECB9C91AA5ED773CD730_element_34")>, <selenium.webdriver.remote.webelement.WebElement (session="9686530846633518f65beccf7fc0d341", element="684AF907A7D5ECB9C91AA5ED773CD730_element_35")>, <selenium.webdriver.remote.webelement.WebElement (session="9686530846633518f65beccf7fc0d341", element="684AF907A7D5ECB9C91AA5ED773CD730_element_36")>, <selenium.webdriver.remote.webelement.WebElement (session="9686530846633518f65beccf7fc0d341", element="684AF907A7D5ECB9C91AA5ED773CD730_element_37")>, <selenium.webdriver.remote.webelement.WebElement (session="9686530846633518f65beccf7fc0d341", element="684AF907A7D5ECB9C91AA5ED773CD730_element_38")>]
​

# %%
<img loading="lazy" data-qa="ems-sdk-grid#productTile3#game-art#image#image" alt="" class="psw-fade-in psw-top-left psw-l-fit-cover" src="https://image.api.playstation.com/vulcan/ap/rnd/202206/0216/5M7ooS8SwsIcIODL5KS1s7gG.png?w=440" srcset="https://image.api.playstation.com/vulcan/ap/rnd/202206/0216/5M7ooS8SwsIcIODL5KS1s7gG.png?w=440&amp;thumb=false, https://image.api.playstation.com/vulcan/ap/rnd/202206/0216/5M7ooS8SwsIcIODL5KS1s7gG.png?w=440&amp;thumb=false 1.5x, https://image.api.playstation.com/vulcan/ap/rnd/202206/0216/5M7ooS8SwsIcIODL5KS1s7gG.png?w=620&amp;thumb=false 2x">



<ul data-qa="" class="psw-grid-list psw-l-grid"><li class="psw-l-w-1/2@mobile-s psw-l-w-1/2@mobile-l psw-l-w-1/6@tablet-l psw-l-w-1/4@tablet-s psw-l-w-1/6@laptop psw-l-w-1/8@desktop psw-l-w-1/8@max"><div data-qa="ems-sdk-grid#productTile0" data-qa-index="0"><a data-qa="" data-track="web:store:product-tile" data-track-click="web:store:product-tile" data-track-content="web:store:product-tile" data-telemetry-meta="{&quot;id&quot;:&quot;HP6238-PPSA02428_00-0087645165886036&quot;,&quot;index&quot;:0,&quot;name&quot;:&quot;Farming Simulator 22 - Premium Edition (簡體中文, 韓文, 英文, 繁體中文, 日文)&quot;,&quot;price&quot;:&quot;NT$1,790&quot;,&quot;titleId&quot;:&quot;PPSA02428_00&quot;}" id="" class="psw-link psw-content-link" aria-label="" type="" href="/zh-hant-tw/product/HP6238-PPSA02428_00-0087645165886036" rel="noopener noreferrer" data-track-id="1"><div class="psw-product-tile psw-interactive-root" data-qa="ems-sdk-grid#productTile0"><div data-qa="ems-sdk-grid#productTile0#game-art" class="psw-ally-indicator psw-ally-indicator-gap-1 psw-show-on-hover psw-b-0 psw-game-art psw-fill psw-l-anchor"><div class="psw-game-art__container psw-l-anchor-top-left psw-l-top-left psw-fill psw-r-2 psw-clip"><span data-qa="" class="psw-illustration psw-illustration--default-product-image default-product-img"><svg aria-hidden="true" focusable="false"><title></title><use href="#ps-illustration:default-product-image"></use></svg></span><span data-qa="ems-sdk-grid#productTile0#game-art#image" style="width:100%;min-width:100%" class="psw-media-frame psw-fill-x psw-image psw-media psw-media-interactive psw-aspect-1-1"><img aria-hidden="true" loading="lazy" data-qa="ems-sdk-grid#productTile0#game-art#image#preview" alt="" class="psw-fade-out psw-top-left psw-l-fit-cover" src="https://image.api.playstation.com/vulcan/ap/rnd/202306/2708/a1a0128776db06edce921d96ecea54271a1f00d6560fee95.png?w=54&amp;thumb=true"><img loading="lazy" data-qa="ems-sdk-grid#productTile0#game-art#image#image" alt="" class="psw-fade-in psw-top-left psw-l-fit-cover" src="https://image.api.playstation.com/vulcan/ap/rnd/202306/2708/a1a0128776db06edce921d96ecea54271a1f00d6560fee95.png?w=440" srcset="https://image.api.playstation.com/vulcan/ap/rnd/202306/2708/a1a0128776db06edce921d96ecea54271a1f00d6560fee95.png?w=440&amp;thumb=false, https://image.api.playstation.com/vulcan/ap/rnd/202306/2708/a1a0128776db06edce921d96ecea54271a1f00d6560fee95.png?w=440&amp;thumb=false 1.5x, https://image.api.playstation.com/vulcan/ap/rnd/202306/2708/a1a0128776db06edce921d96ecea54271a1f00d6560fee95.png?w=620&amp;thumb=false 2x"><noscript class="psw-layer"><img class="psw-top-left psw-l-fit-cover" loading="lazy" data-qa="ems-sdk-grid#productTile0#game-art#image#image-no-js" alt="" src="https://image.api.playstation.com/vulcan/ap/rnd/202306/2708/a1a0128776db06edce921d96ecea54271a1f00d6560fee95.png"/></noscript></span></div><div class="psw-l-anchor-bottom-left psw-l-bottom-left psw-m-l-3 psw-m-sub-t-3"><div class="psw-l-cluster psw-l-gap-2" data-qa="ems-sdk-grid#productTile0#game-art"><span data-qa="ems-sdk-grid#productTile0#game-art#tag0" class="psw-platform-tag psw-p-x-2 psw-l-line-left psw-t-tag psw-on-graphic">PS5</span><span data-qa="ems-sdk-grid#productTile0#game-art#tag1" class="psw-platform-tag psw-p-x-2 psw-l-line-left psw-t-tag psw-on-graphic">PS4</span></div></div></div><section data-qa="ems-sdk-grid#productTile0#details" class="psw-product-tile__details psw-m-t-2"><span data-qa="ems-sdk-grid#productTile0#product-type" class="psw-product-tile__product-type psw-t-bold psw-t-size-1 psw-t-truncate-1 psw-c-t-2 psw-t-uppercase psw-m-b-1">Pre-Order</span><span data-qa="ems-sdk-grid#productTile0#product-name" class="psw-t-body psw-c-t-1 psw-t-truncate-2 psw-m-b-2">
game-art#tag0" class="psw-platform-tag psw-p-x-2 psw-l-line-left psw-t-tag psw-on-graphic">PS4</span></div></div></div><section data-qa="ems-sdk-grid#productTile5#details" class="psw-product-tile__details psw-m-t-2"><span data-qa="ems-sdk-grid#productTile5#product-type" class="psw-product-tile__product-type psw-t-bold psw-t-size-1 psw-t-truncate-1 psw-c-t-2 psw-t-uppercase psw-m-b-1">Pre-Order</span><span data-qa="ems-sdk-grid#productTile5#product-name" class="psw-t-body psw-c-t-1 psw-t-truncate-2 psw-m-b-2">Chants of Sennaar (簡體中文, 韓文, 英文, 繁體中文, 日文)</span><div data-qa="ems-sdk-grid#productTile5#service-upsell" class="psw-m-t-2 psw-service-upsell"><div class="psw-service-upsell__contents psw-t-align-c psw-l-line-left psw-t-overline"><div class="psw-l-anchor"><div aria-hidden="true" class="psw-l-h-overline psw-l-line-left psw-hidden psw-clip"><span data-qa="ems-sdk-grid#productTile5#service-upsell#service-icon" class="psw-icon psw-icon--ps-plus psw-icon psw-icon-size-1 psw-icon--ps-plus psw-m-r-1"><svg aria-hidden="true" focusable="false" viewBox="0 0 64 64"><title></title><use href="#ps-icon:ps-plus"></use></svg></span></div><div class="psw-l-anchor-center-right psw-l-center-right psw-l-inline"><span data-qa="ems-sdk-grid#productTile5#service-upsell#service-icon" class="psw-icon psw-icon--ps-plus psw-icon psw-icon-size-1 psw-icon--ps-plus psw-m-r-1"><svg aria-hidden="true" focusable="false" viewBox="0 0 64 64"><title></title><use href="#ps-icon:ps-plus"></use></svg></span></div></div><span data-qa="ems-sdk-grid#productTile5#service-upsell#descriptorText" class="psw-truncate-text-1 psw-c-t-ps-plus">省下10%</span></div></div><div data-qa="ems-sdk-grid#productTile5#price" class="psw-fill-x psw-price psw-l-inline psw-l-line-left-top"><div class="psw-l-line-left-top psw-l-line-wrap psw-clip psw-t-h-body-1"><span data-qa="ems-sdk-grid#productTile5#price#display-price" aria-hidden="false" class="psw-m-r-3">NT$590</span></div></div></section></div></a></div></li><li class="psw-l-w-1/2@mobile-s psw-l-w-1/2@mobile-l psw-l-w-1/6@tablet-l psw-l-w-1/4@tablet-s psw-l-w-1/6@laptop psw-l-w-1/8@desktop psw-l-w-1/8@max"><div data-qa="ems-sdk-grid#productTile6" data-qa-index="6"><a data-qa="" data-track="web:store:product-tile" data-track-click="web:store:product-tile" data-track-content="web:store:product-tile" data-telemetry-meta="{&quot;id&quot;:&quot;EP4389-PPSA14276_00-TRINE50000000000&quot;,&quot;index&quot;:6,&quot;name&quot;:&quot;Trine 5: A Clockwork Conspiracy (簡體中文, 韓文, 英文, 繁體中文, 日文)&quot;,&quot;price&quot;:&quot;NT$890&quot;,&quot;titleId&quot;:&quot;PPSA14276_00&quot;}" id="" class="psw-link psw-content-link" aria-label="" type="" href="/zh-hant-tw/product/EP4389-PPSA14276_00-TRINE50000000000" rel="noopener noreferrer" data-track-id="7"><div class="psw-product-tile psw-interactive-root" data-qa="ems-sdk-grid#productTile6"><div data-qa="ems-sdk-grid#productTile6#game-art" class="psw-ally-indicator psw-ally-indicator-gap-1 psw-show-on-hover psw-b-0 psw-game-art psw-fill psw-l-anchor"><div class="psw-game-art__container psw-l-anchor-top-left psw-l-top-left psw-fill psw-r-2 psw-clip"><span data-qa="" class="psw-illustration psw-illustration--default-product-image default-product-img"><svg aria-hidden="true" focusable="false"><title></title><use href="#ps-illustration:default-product-image"></use></svg></span><span data-qa="ems-sdk-grid#productTile6#game-art#image" style="width:100%;min-width:100%" class="psw-media-frame psw-fill-x psw-image psw-media psw-media-interactive psw-aspect-1-1"><img aria-hidden="true" loading="lazy" data-qa="ems-sdk-grid#productTile6#game-art#image#preview" alt="" class="psw-fade-out psw-top-left psw-l-fit-cover" src="https://image.api.playstation.com/vulcan/ap/rnd/202303/1716/36e004d85d7ba025807907eda6884899dc848583fcede6b9.png?w=54&amp;thumb=true"><img loading="lazy" data-qa="ems-sdk-grid#productTile6#game-art#image#image" alt="" class="psw-fade-in psw-top-left psw-l-fit-cover" src="https://image.api.playstation.com/vulcan/ap/rnd/202303/1716/36e004d85d7ba025807907eda6884899dc848583fcede6b9.png?w=440" srcset="https://image.api.playstation.com/vulcan/ap/rnd/202303/1716/36e004d85d7ba025807907eda6884899dc848583fcede6b9.png?w=440&amp;thumb=false, https://image.api.playstation.com/vulcan/ap/rnd/202303/1716/36e004d85d7ba025807907eda6884899dc848583fcede6b9.png?w=440&amp;thumb=false 1.5x, https://image.api.playstation.com/vulcan/ap/rnd/202303/1716/36e004d85d7ba025807907eda6884899dc848583fcede6b9.png?w=620&amp;thumb=false 2x"><noscript class="psw-layer"><img class="psw-top-left psw-l-fit-cover" loading="lazy" data-qa="ems-sdk-grid#productTile6#game-art#image#image-no-js" alt="" src="https://image.api.playstation.com/vulcan/ap/rnd/202303/1716/36e004d85d7ba025807907eda6884899dc848583fcede6b9.png"/></noscript></span></div><div class="psw-l-anchor-bottom-left psw-l-bottom-left psw-m-l-3 psw-m-sub-t-3"><div class="psw-l-cluster psw-l-gap-2" data-qa="ems-sdk-grid#productTile6#game-art"><span data-qa="ems-sdk-grid#productTile6#game-art#tag0" class="psw-platform-tag psw-p-x-2 psw-l-line-left psw-t-tag psw-on-graphic">PS5</span></div></div></div><section data-qa="ems-sdk-grid#productTile6#details" class="psw-product-tile__details psw-m-t-2"><span data-qa="ems-sdk-grid#productTile6#product-type" class="psw-product-tile__product-type psw-t-bold psw-t-size-1 psw-t-truncate-1 psw-c-t-2 psw-t-uppercase psw-m-b-1">Pre-Order</span><span data-qa="ems-sdk-grid#productTile6#product-name" class="psw-t-body psw-c-t-1 psw-t-truncate-2 psw-m-b-2">Trine 5: A Clockwork Conspiracy (簡體中文, 韓文, 英文, 繁體中文, 日文)</span><div data-qa="ems-sdk-grid#productTile6#service-upsell" class="psw-m-t-2 psw-service-upsell"><div class="psw-service-upsell__contents psw-t-align-c psw-l-line-left psw-t-overline"><div class="psw-l-anchor"><div aria-hidden="true" class="psw-l-h-overline psw-l-line-left psw-hidden psw-clip"><span data-qa="ems-sdk-grid#productTile6#service-upsell#service-icon" class="psw-icon psw-icon--ps-plus psw-icon psw-icon-size-1 psw-icon--ps-plus psw-m-r-1"><svg aria-hidden="true" focusable="false" viewBox="0 0 64 64"><title></title><use href="#ps-icon:ps-plus"></use></svg></span></div><div class="psw-l-anchor-center-right psw-l-center-right psw-l-inline"><span data-qa="ems-sdk-grid#productTile6#service-upsell#service-icon" class="psw-icon psw-icon--ps-plus psw-icon psw-icon-size-1 psw-icon--ps-plus psw-m-r-1"><svg aria-hidden="true" focusable="false" viewBox="0 0 64 64"><title></title><use href="#ps-icon:ps-plus"></use></svg></span></div></div><span data-qa="ems-sdk-grid#productTile6#service-upsell#descriptorText" class="psw-truncate-text-1 psw-c-t-ps-plus">省下10%</span></div></div><div data-qa="ems-sdk-grid#productTile6#price" class="psw-fill-x psw-price psw-l-inline psw-l-line-left-top"><div class="psw-l-line-left-top psw-l-line-wrap psw-clip psw-t-h-body-1"><span data-qa="ems-sdk-grid#productTile6#price#display-price" aria-hidden="false" class="psw-m-r-3">NT$890</span></div></div></section></div></a></div></li><li class="psw-l-w-1/2@mobile-s psw-l-w-1/2@mobile-l psw-l-w-1/6@tablet-l psw-l-w-1/4@tablet-s psw-l-w-1/6@laptop psw-l-w-1/8@desktop psw-l-w-1/8@max"><div data-qa="ems-sdk-grid#productTile7" data-qa-index="7"><a data-qa="" data-track="web:store:product-tile" data-track-click="web:store:product-tile" data-track-content="web:store:product-tile" data-telemetry-meta="{&quot;id&quot;:&quot
w-top-left psw-l-fit-cover" src="https://image.api.playstation.com/vulcan/ap/rnd/202307/2616/47025cb4f628c5ef323212b5eb09c47e404777110b3ac0b2.png?w=54&amp;thumb=true"><img loading="lazy" data-qa="ems-sdk-grid#productTile23#game-art#image#image" alt="" class="psw-fade-in psw-top-left psw-l-fit-cover" src="https://image.api.playstation.com/vulcan/ap/rnd/202307/2616/47025cb4f628c5ef323212b5eb09c47e404777110b3ac0b2.png?w=440" srcset="https://image.api.playstation.com/vulcan/ap/rnd/202307/2616/47025cb4f628c5ef323212b5eb09c47e404777110b3ac0b2.png?w=440&amp;thumb=false, https://image.api.playstation.com/vulcan/ap/rnd/202307/2616/47025cb4f628c5ef323212b5eb09c47e404777110b3ac0b2.png?w=440&amp;thumb=false 1.5x, https://image.api.playstation.com/vulcan/ap/rnd/202307/2616/47025cb4f628c5ef323212b5eb09c47e404777110b3ac0b2.png?w=620&amp;thumb=false 2x"><noscript class="psw-layer"><img class="psw-top-left psw-l-fit-cover" loading="lazy" data-qa="ems-sdk-grid#productTile23#game-art#image#image-no-js" alt="" src="https://image.api.playstation.com/vulcan/ap/rnd/202307/2616/47025cb4f628c5ef323212b5eb09c47e404777110b3ac0b2.png"/></noscript></span></div><div class="psw-l-anchor-bottom-left psw-l-bottom-left psw-m-l-3 psw-m-sub-t-3"><div class="psw-l-cluster psw-l-gap-2" data-qa="ems-sdk-grid#productTile23#game-art"><span data-qa="ems-sdk-grid#productTile23#game-art#tag0" class="psw-platform-tag psw-p-x-2 psw-l-line-left psw-t-tag psw-on-graphic">PS4</span></div></div></div><section data-qa="ems-sdk-grid#productTile23#details" class="psw-product-tile__details psw-m-t-2"><span data-qa="ems-sdk-grid#productTile23#product-name" class="psw-t-body psw-c-t-1 psw-t-truncate-2 psw-m-b-2">The Voices Stories (英文)</span><div data-qa="ems-sdk-grid#productTile23#price" class="psw-fill-x psw-price psw-l-inline psw-l-line-left-top"><div class="psw-l-line-left-top psw-l-line-wrap psw-clip psw-t-h-body-1"><span data-qa="ems-sdk-grid#productTile23#price#display-price" aria-hidden="false" class="psw-m-r-3">NT$30</span></div></div></section></div></a></div></li></ul>

# %%
from bs4 import BeautifulSoup
import requests  #引入外部

url = "https://store.playstation.com/zh-hant-tw/pages/browse"

res = requests.get(url)
# soup = BeautifulSoup(f.read(),"html")
soup = BeautifulSoup(res.text,"lxml")
# soup
class_1="psw-l-w-1/2@mobile-s psw-l-w-1/2@mobile-l psw-l-w-1/6@tablet-l psw-l-w-1/4@tablet-s psw-l-w-1/6@laptop psw-l-w-1/8@desktop psw-l-w-1/8@max"
jobs = soup.find_all("li",class_=class_1)
# ("span")[3].text
for job in jobs :
    print(job("span")[3].text)
# print(jobs)

# games()

# %%
from bs4 import BeautifulSoup
import requests  #引入外部
import json

base_url = "https://store.playstation.com/zh-hant-tw/category/5f3aa730-1c8e-4a18-84da-030bb91558c0/"
page_numbers=list(range(1,11))
name = []
price = []
for page_number in page_numbers:
    url = base_url+str(page_number)
    res = requests.get(url)
    # soup = BeautifulSoup(f.read(),"html")
    soup = BeautifulSoup(res.text,"lxml")
    # soup
    class_1="psw-l-w-1/2@mobile-s psw-l-w-1/2@mobile-l psw-l-w-1/6@tablet-l psw-l-w-1/4@tablet-s psw-l-w-1/6@laptop psw-l-w-1/8@desktop psw-l-w-1/8@max"
    jobs = soup.find_all("li",class_=class_1)
    # print(jobs)
    for job in jobs:
        if jobs != []:
            data_telemetry_meta = job.find("a").get("data-telemetry-meta")
            meta_data = json.loads(data_telemetry_meta)
        #     print(data_telemetry_meta)
    #         print(meta_data)
            product_name = meta_data['name']
            product_price = meta_data['price']
            name.append(product_name)
            price.append(product_price)
            print("Product Name:", product_name)
            print("Product Price:", product_price)
            print("----------------------------------------------------------------------------")
        else:
            print("end")

# 完成的數據儲存起來

# %%
import pandas as pd
df = pd.DataFrame({"Name":name,"Price":price})
df.to_csv("/Users/lvhongxiang/ps4.csv")

# %%
print (name)
print (price)

# %%
from bs4 import BeautifulSoup
import requests
import json

url = "https://store.playstation.com/zh-hant-tw/category/5f3aa730-1c8e-4a18-84da-030bb91558c0/1"

res = requests.get(url)
soup = BeautifulSoup(res.text, "lxml")

class_1 = "psw-l-w-1/2@mobile-s psw-l-w-1/2@mobile-l psw-l-w-1/6@tablet-l psw-l-w-1/4@tablet-s psw-l-w-1/6@laptop psw-l-w-1/8@desktop psw-l-w-1/8@max"
jobs = soup.find_all("li", class_=class_1)

for job in jobs:
    data_telemetry_meta = job.find("a").get("data-telemetry-meta")
    meta_data = json.loads(data_telemetry_meta)

    product_name = meta_data['name']
    product_price = meta_data['price']

    print("Product Name:", product_name)
    print("Product Price:", product_price)
    print("---")

# %%
page_numbers=list(range(1,11))
print(page_numbers)

# %%
from bs4 import BeautifulSoup
import requests
import json

url = "https://store.playstation.com/zh-hant-tw/category/5f3aa730-1c8e-4a18-84da-030bb91558c0/1"
res = requests.get(url)
soup = BeautifulSoup(res.text, "lxml")
class_1 = "psw-l-w-1/2@mobile-s psw-l-w-1/2@mobile-l psw-l-w-1/6@tablet-l psw-l-w-1/4@tablet-s psw-l-w-1/6@laptop psw-l-w-1/8@desktop psw-l-w-1/8@max"
jobs = soup.find_all("li", class_=class_1)


class_="psw-grid-list psw-l-grid"
print(jobs)

# %%
<a aria-label="" class="psw-link psw-content-link" data-qa="" data-telemetry-meta='{"id":"UP0097-PPSA13857_00-0517472901544469","index":10,"name":"Black Skylands: 創始版 (簡體中文, 英文)","price":"NT$590","titleId":"PPSA13857_00"}' data-track="web:store:product-tile" data-track-click="web:store:product-tile" data-track-content="web:store:product-tile" href="/zh-hant-tw/product/UP0097-PPSA13857_00-0517472901544469" id="" rel="noopener noreferrer" type="">

# %%
from bs4 import BeautifulSoup
import requests

url = "https://store.playstation.com/zh-hant-tw/category/5f3aa730-1c8e-4a18-84da-030bb91558c0/1"
res = requests.get(url)
soup = BeautifulSoup(res.text, "html.parser")

# 找到包含 href 的元素，這個範例使用 <a> 標籤
links = soup.find_all("a", href=True)

# 建立一個空的清單，用於存儲所有的 href
href_list = []

# 迭代所有找到的連結，並將 href 加入清單
for link in links:
    href = link["href"]
    href_list.append(href)

# 印出所有的 href
for href in href_list:
    print(href)

# %%
from bs4 import BeautifulSoup
import requests
from urllib.parse import urljoin  # 用於處理相對 URL 的模組

url = "https://store.playstation.com/zh-hant-tw/category/5f3aa730-1c8e-4a18-84da-030bb91558c0/1"
res = requests.get(url)
soup = BeautifulSoup(res.text, "html.parser")

# 找到包含 href 的元素，這個範例使用 <a> 標籤
links = soup.find_all("a", href=True)

# 建立一個空的清單，用於存儲所有的 href
href_list = []

# 基本的 URL，用於拼接相對 URL
base_url = "https://store.playstation.com/zh-hant-tw/"

# 迭代所有找到的連結，並將處理過的 href 加入清單
for link in links:
    href = link["href"]
    # 使用 urljoin 來處理相對 URL，如果已經是完整的 URL，則不會被修改
    full_url = urljoin(base_url, href)
    href_list.append(full_url)

# 印出所有的 href
for href in href_list:
    print(href)

# %%
from bs4 import BeautifulSoup
import requests
from urllib.parse import urljoin  

url = "https://store.playstation.com/zh-hant-tw/category/5f3aa730-1c8e-4a18-84da-030bb91558c0/1"
res = requests.get(url)
soup = BeautifulSoup(res.text, "html.parser")

links = soup.find_all("a", href=True)
href_list = []
base_url = "https://store.playstation.com/zh-hant-tw/"
for link in links:
    href = link["href"]
    full_url = urljoin(base_url, href)
    href_list.append(full_url)

for href in href_list:
    print(href)

# %%
from bs4 import BeautifulSoup
import requests
from urllib.parse import urljoin

url = "https://store.playstation.com/zh-hant-tw/category/5f3aa730-1c8e-4a18-84da-030bb91558c0/1"
res = requests.get(url)
soup = BeautifulSoup(res.text, "html.parser")

# 找到包含 href 的元素，這個範例使用 <a> 標籤
links = soup.find_all("a", href=True)

# 基本的 URL，用於拼接相對 URL
base_url = "https://store.playstation.com/zh-hant-tw/"

# 建立一個空的清單，用於存儲所有的 href
href_list = []

# 迭代所有找到的連結，並將處理過的 href 加入清單
for link in links:
    href = link["href"]
    full_url = urljoin(base_url, href)
    if "/zh-hant-tw/product/" in full_url:
        href_list.append(full_url)
    print("Opening:", href)
# # 依次訪問連結
# for href in href_list:
#     print("Opening:", href)
#     res_product = requests.get(href)
#     # 在這裡你可以進行你希望的處理，例如分析商品頁面的內容
#     print("Processing:", href)
#     # 這裡模擬處理，實際應用中需要根據需要進行處理

#     print("Closing:", href)

# %%
from bs4 import BeautifulSoup
import requests
from urllib.parse import urljoin

url = "https://store.playstation.com/zh-hant-tw/category/5f3aa730-1c8e-4a18-84da-030bb91558c0/1"
res = requests.get(url)
soup = BeautifulSoup(res.text, "html.parser")

links = soup.find_all("a", href=True)

base_url = "https://store.playstation.com/zh-hant-tw/"

full_url_list = []

for link in links:
    href = link["href"]
    full_url = urljoin(base_url, href)
    if "/zh-hant-tw/product/" in full_url:
        full_url_list.append(full_url)
# print(full_url_list)
for full_url in full_url_list:
    print(full_url)

# %%
from bs4 import BeautifulSoup
import requests
from urllib.parse import urljoin

url = "https://store.playstation.com/zh-hant-tw/product/HP6238-PPSA02428_00-0087645165886036"
res = requests.get(url)
soup = BeautifulSoup(res.text, "html")
# print(soup)
meger = []
# for i in url :
# Name = soup.find('div',class_="psw-c-bg-0").h1.text
# print(Name)
# Gold = soup.find("span",class_="psw-l-line-left psw-l-line-wrap").text
# print(Gold)
# Platform = soup.find("dl",data-qa="gameInfo#releaseInformation")
Platform = soup.find("dl", {"data-qa": "gameInfo#releaseInformation"}).text

# data-qa="gameInfo#releaseInformation#releaseDate-value".dd.text

print(Platform)



# meger=[Name,Gold,Platform]

# print(meger)


# meger=[Name,Gold,Platform,Date,Publisher]
# links = soup.find_all("a", href=True)

# base_url = "https://store.playstation.com/zh-hant-tw/"

# full_url_list = []

# for link in links:
#     href = link["href"]
#     full_url = urljoin(base_url, href)
#     if "/zh-hant-tw/product/" in full_url:
#         full_url_list.append(full_url)
# # print(full_url_list)
# for full_url in full_url_list:
#     print(full_url)

# %%
from bs4 import BeautifulSoup
import requests
import re

url = "https://store.playstation.com/zh-hant-tw/product/HP6238-PPSA02428_00-0087645165886036"
res = requests.get(url)
soup = BeautifulSoup(res.text, "html.parser")

Name = soup.find('div', class_="psw-c-bg-0").h1.text
print("遊戲名稱:", Name)

Gold = soup.find("span", class_="psw-l-line-left psw-l-line-wrap").text
print("價格:", Gold)

Platform_info = soup.find("dl", {"data-qa": "gameInfo#releaseInformation"})

if Platform_info:
    Platform_text = Platform_info.text
    
    # 使用正規表達式來提取所需信息
    platform_match = re.search(r"平台:(.*?)推出日:(.*?)發行商:(.*?)類型:(.*?)$", Platform_text)
    if platform_match:
        platform = platform_match.group(1).strip()
        release_date = platform_match.group(2).strip()
        publisher = platform_match.group(3).strip()
        type_of_game = platform_match.group(4).strip()
        
        print("平台:", platform)
        print("推出日:", release_date)
        print("發行商:", publisher)
        print("類型:", type_of_game)
    else:
        print("無法正確提取平台、推出日、發行商和類型信息")
else:
    print("未找到平台信息")

# %%
from bs4 import BeautifulSoup
import requests
import re

url = "https://store.playstation.com/zh-hant-tw/product/HP6238-PPSA02428_00-0087645165886036"
res = requests.get(url)
soup = BeautifulSoup(res.text, "html.parser")

Name = soup.find('div', class_="psw-c-bg-0").h1.text
print("遊戲名稱:", Name)

Gold = soup.find("span", class_="psw-l-line-left psw-l-line-wrap").text
print("價格:", Gold)

Platform_info = soup.find("dl", {"data-qa": "gameInfo#releaseInformation"})

if Platform_info:
    Platform_text = Platform_info.text
    
    # 使用正規表達式來提取所需信息
    platform_match = re.search(r"平台:(.*?)推出日:(.*?)發行商:(.*?)類型:(.*?)$", Platform_text)
    if platform_match:
        platform = platform_match.group(1).strip()
        release_date = platform_match.group(2).strip()
        publisher = platform_match.group(3).strip()
        type_of_game = platform_match.group(4).strip()
        
        print("平台:", platform)
        print("推出日:", release_date)
        print("發行商:", publisher)
        print("類型:", type_of_game)
    else:
        print("無法正確提取平台、推出日、發行商和類型信息")
else:
    print("未找到平台信息")

links = soup.find_all("a", href=True)

base_url = "https://store.playstation.com/zh-hant-tw/"

full_url_list = []

for link in links:
    href = link["href"]
    full_url = urljoin(base_url, href)
    if "/zh-hant-tw/product/" in full_url:
        full_url_list.append(full_url)
# print(full_url_list)
for full_url in full_url_list:
    print(full_url)

# %%
from bs4 import BeautifulSoup
import requests
from urllib.parse import urljoin
import re

url = "https://store.playstation.com/zh-hant-tw/product/HP6238-PPSA02428_00-0087645165886036"
res = requests.get(url)
soup = BeautifulSoup(res.text, "html.parser")

def extract_platform_info(soup):
    Platform_info = soup.find("dl", {"data-qa": "gameInfo#releaseInformation"})

    if Platform_info:
        Platform_text = Platform_info.text

        platform_match = re.search(r"平台:(.*?)推出日:(.*?)發行商:(.*?)類型:(.*?)$", Platform_text)
        if platform_match:
            platform = platform_match.group(1).strip()
            release_date = platform_match.group(2).strip()
            publisher = platform_match.group(3).strip()
            type_of_game = platform_match.group(4).strip()

            print("平台:", platform)
            print("推出日:", release_date)
            print("發行商:", publisher)
            print("類型:", type_of_game)
        else:
            print("無法正確提取平台、推出日、發行商和類型信息")
    else:
        print("未找到平台信息")

def extract_product_links(soup):
    links = soup.find_all("a", href=True)
    base_url = "https://store.playstation.com/zh-hant-tw/"
    full_url_list = []

    for link in links:
        href = link["href"]
        full_url = urljoin(base_url, href)
        if "/zh-hant-tw/product/" in full_url:
            full_url_list.append(full_url)

    return full_url_list

# 提取遊戲信息
Name = soup.find('div', class_="psw-c-bg-0").h1.text
print("遊戲名稱:", Name)

Gold = soup.find("span", class_="psw-l-line-left psw-l-line-wrap").text
print("價格:", Gold)

extract_platform_info(soup)

# 提取相關連結
product_links = extract_product_links(soup)
for link in product_links:
    print(link)

# %%
from bs4 import BeautifulSoup
import requests
import re
from urllib.parse import urljoin

def extract_game_data(url):
    res = requests.get(url)
    soup = BeautifulSoup(res.text, "html.parser")

    Name = soup.find('div', class_="psw-c-bg-0").h1.text
    print("遊戲名稱:", Name)

    Gold = soup.find("span", class_="psw-l-line-left psw-l-line-wrap").text
    print("價格:", Gold)

    Platform_info = soup.find("dl", {"data-qa": "gameInfo#releaseInformation"})

    if Platform_info:
        Platform_text = Platform_info.text

        platform_match = re.search(r"平台:(.*?)推出日:(.*?)發行商:(.*?)類型:(.*?)$", Platform_text)
        if platform_match:
            platform = platform_match.group(1).strip()
            release_date = platform_match.group(2).strip()
            publisher = platform_match.group(3).strip()
            type_of_game = platform_match.group(4).strip()

            print("平台:", platform)
            print("推出日:", release_date)
            print("發行商:", publisher)
            print("類型:", type_of_game)
        else:
            print("無法正確提取平台、推出日、發行商和類型信息")
    else:
        print("未找到平台信息")
    
    print("----------------------")

url = "https://store.playstation.com/zh-hant-tw/product/HP6238-PPSA02428_00-0087645165886036"
extract_game_data(url)

base_url = "https://store.playstation.com/zh-hant-tw/"
links = [
    "相關連結1",
    "相關連結2",
    # 在這裡添加更多相關連結
]

for link in links:
    full_url = urljoin(base_url, link)
    extract_game_data(full_url)

# %%
from bs4 import BeautifulSoup
import requests
from urllib.parse import urljoin
import re

def extract_info(url):
    res = requests.get(url)
    soup = BeautifulSoup(res.text, "html.parser")

    Name = soup.find('div', class_="psw-c-bg-0").h1.text
    print("遊戲名稱:", Name)

    Gold = soup.find("span", class_="psw-l-line-left psw-l-line-wrap").text
    print("價格:", Gold)

    Platform_info = soup.find("dl", {"data-qa": "gameInfo#releaseInformation"})

    if Platform_info:
        Platform_text = Platform_info.text

        platform_match = re.search(r"平台:(.*?)推出日:(.*?)發行商:(.*?)類型:(.*?)$", Platform_text)
        if platform_match:
            platform = platform_match.group(1).strip()
            release_date = platform_match.group(2).strip()
            publisher = platform_match.group(3).strip()
            type_of_game = platform_match.group(4).strip()

            print("平台:", platform)
            print("推出日:", release_date)
            print("發行商:", publisher)
            print("類型:", type_of_game)
        else:
            print("無法正確提取平台、推出日、發行商和類型信息")
    else:
        print("未找到平台信息")

        
# -----------------------------------------------------------------------------------------------------------   

url = "https://store.playstation.com/zh-hant-tw/product/HP6238-PPSA02428_00-0087645165886036"
extract_info(url)
base_url = "https://store.playstation.com/zh-hant-tw/"



url1 = "https://store.playstation.com/zh-hant-tw/category/5f3aa730-1c8e-4a18-84da-030bb91558c0/1"
res = requests.get(url1)
soup = BeautifulSoup(res.text, "html")

links = soup.find_all("a", href=True)
full_url_list = []
for link in links:
    href = link["href"]
    full_url = urljoin(base_url, href)
    if "/zh-hant-tw/product/" in full_url:
        full_url_list.append(full_url)

for partial_url in full_url_list:
    full_url = urljoin(base_url, partial_url)
    extract_info(full_url)

# %%
base_url = "https://store.playstation.com/zh-hant-tw/category/5f3aa730-1c8e-4a18-84da-030bb91558c0/"
res = requests.get(url)
soup = BeautifulSoup(res.text, "html")
page_numbers=list(range(1,11))
name = []
price = []
for page_number in page_numbers:
    url = base_url+str(page_number)
    links = soup.find_all("a", href=True)
    soup = BeautifulSoup(res.text,"lxml")
    # soup
    class_1="psw-l-w-1/2@mobile-s psw-l-w-1/2@mobile-l psw-l-w-1/6@tablet-l psw-l-w-1/4@tablet-s psw-l-w-1/6@laptop psw-l-w-1/8@desktop psw-l-w-1/8@max"
    jobs = soup.find_all("li",class_=class_1)
    for job in jobs:
        if jobs != []:
            data_telemetry_meta = job.find("a").get("data-telemetry-meta")
            meta_data = json.loads(data_telemetry_meta)
        #     print(data_telemetry_meta)
    #         print(meta_data)
            product_name = meta_data['name']
            product_price = meta_data['price']
            name.append(product_name)
            price.append(product_price)
            print("Product Name:", product_name)
            print("Product Price:", product_price)
            print("----------------------------------------------------------------------------")
        else:
            print("end")

    
base_url = "https://store.playstation.com/zh-hant-tw/"

full_url_list = []

for link in links:
    href = link["href"]
    full_url = urljoin(base_url, href)
    if "/zh-hant-tw/product/" in full_url:
        full_url_list.append(full_url)
# print(full_url_list)
for full_url in full_url_list:
    print(full_url)

# %%
from bs4 import BeautifulSoup
import requests  #引入外部
import json

base_url = "https://store.playstation.com/zh-hant-tw/category/5f3aa730-1c8e-4a18-84da-030bb91558c0/"
page_numbers=list(range(1,11))
name = []
price = []
for page_number in page_numbers:
    url = base_url+str(page_number)
    res = requests.get(url)
    # soup = BeautifulSoup(f.read(),"html")
    soup = BeautifulSoup(res.text,"lxml")
    # soup
    class_1="psw-l-w-1/2@mobile-s psw-l-w-1/2@mobile-l psw-l-w-1/6@tablet-l psw-l-w-1/4@tablet-s psw-l-w-1/6@laptop psw-l-w-1/8@desktop psw-l-w-1/8@max"
    jobs = soup.find_all("li",class_=class_1)
    # print(jobs)
    for job in jobs:
        if jobs != []:
            data_telemetry_meta = job.find("a").get("data-telemetry-meta")
            meta_data = json.loads(data_telemetry_meta)
        #     print(data_telemetry_meta)
    #         print(meta_data)
            product_name = meta_data['name']
            product_price = meta_data['price']
            name.append(product_name)
            price.append(product_price)
            print("Product Name:", product_name)
            print("Product Price:", product_price)
            print("----------------------------------------------------------------------------")
        else:
            print("end")

# %%
from bs4 import BeautifulSoup
import requests
from urllib.parse import urljoin
import re
import time

def extract_info(url):
    res = requests.get(url)
    soup = BeautifulSoup(res.text, "html.parser")

    Name = soup.find('div', class_="psw-c-bg-0").h1.text
    print("遊戲名稱:", Name)

    Gold = soup.find("span", class_="psw-l-line-left psw-l-line-wrap").text
    print("價格:", Gold)

    Platform_info = soup.find("dl", {"data-qa": "gameInfo#releaseInformation"})

    if Platform_info:
        Platform_text = Platform_info.text

        platform_match = re.search(r"平台:(.*?)推出日:(.*?)發行商:(.*?)類型:(.*?)$", Platform_text)
        if platform_match:
            platform = platform_match.group(1).strip()
            release_date = platform_match.group(2).strip()
            publisher = platform_match.group(3).strip()
            type_of_game = platform_match.group(4).strip()

            print("平台:", platform)
            print("推出日:", release_date)
            print("發行商:", publisher)
            print("類型:", type_of_game)
        else:
            print("無法正確提取平台、推出日、發行商和類型信息")
    else:
        print("未找到平台信息")

        
# -----------------------------------------------------------------------------------------------------------   

into_url = "https://store.playstation.com/zh-hant-tw/product/HP6238-PPSA02428_00-0087645165886036"
extract_info(into_url)

  
base_url = "https://store.playstation.com/zh-hant-tw/category/5f3aa730-1c8e-4a18-84da-030bb91558c0/"
page_numbers=list(range(1,3))

for page_number in page_numbers:
    url = base_url+str(page_number)
    res = requests.get(url)
    soup = BeautifulSoup(res.text,"lxml")
    class_1="psw-l-w-1/2@mobile-s psw-l-w-1/2@mobile-l psw-l-w-1/6@tablet-l psw-l-w-1/4@tablet-s psw-l-w-1/6@laptop psw-l-w-1/8@desktop psw-l-w-1/8@max"
    jobs = soup.find_all("li",class_=class_1)
    links = soup.find_all("a", href=True)
    base_url1 = "https://store.playstation.com/zh-hant-tw/"  
    
    full_url_list = []
    for link in links:
        href = link["href"]
        full_url = urljoin(base_url1, href)
        if "/zh-hant-tw/product/" in full_url:
            full_url_list.append(full_url)

        for partial_url in full_url_list:
            extract_info(partial_url)
#             print("----------------------------------------------------------------------------------------------------------")
    time.sleep(10)

# %%
from bs4 import BeautifulSoup
import requests
from urllib.parse import urljoin
import re
import time
import openpyxl

def extract_info(url):
    res = requests.get(url)
    soup = BeautifulSoup(res.text, "html.parser")

    Name = soup.find('div', class_="psw-c-bg-0").h1.text
    print("遊戲名稱:", Name)

    Gold = soup.find("span", class_="psw-l-line-left psw-l-line-wrap").text
    print("價格:", Gold)

    Platform_info = soup.find("dl", {"data-qa": "gameInfo#releaseInformation"})

    if Platform_info:
        Platform_text = Platform_info.text

        platform_match = re.search(r"平台:(.*?)推出日:(.*?)發行商:(.*?)類型:(.*?)$", Platform_text)
        meger = []
        if platform_match:
            platform = platform_match.group(1).strip()
            release_date = platform_match.group(2).strip()
            publisher = platform_match.group(3).strip()
            type_of_game = platform_match.group(4).strip()

            print("平台:", platform)
            print("推出日:", release_date)
            print("發行商:", publisher)
            print("類型:", type_of_game)
            meger.append([Name,Gold,platform,release_date,publisher,type_of_game])
        else:
            print("無法正確提取平台、推出日、發行商和類型信息")
            
    else:
        print("未找到平台信息")

        
# -----------------------------------------------------------------------------------------------------------   
# wb = openpyxl.Workbook()
# ws = wb.active

# ws["A1"]="遊戲名稱"
# ws["B1"]="販賣價格"
# ws["C1"]="遊戲平台"
# ws["D1"]="發行日期"
# ws["E1"]="發行廠商"
  
base_url = "https://store.playstation.com/zh-hant-tw/category/5f3aa730-1c8e-4a18-84da-030bb91558c0/"
page_numbers=list(range(1,1))

for page_number in page_numbers:
    url = base_url+str(page_number)
    res = requests.get(url)
    soup = BeautifulSoup(res.text,"lxml")
    class_1="psw-l-w-1/2@mobile-s psw-l-w-1/2@mobile-l psw-l-w-1/6@tablet-l psw-l-w-1/4@tablet-s psw-l-w-1/6@laptop psw-l-w-1/8@desktop psw-l-w-1/8@max"
    jobs = soup.find_all("li",class_=class_1)
    links = soup.find_all("a", href=True)
    base_url1 = "https://store.playstation.com/zh-hant-tw/"  
    
    full_url_list = []
    for link in links:
        href = link["href"]
        full_url = urljoin(base_url1, href)
        if "/zh-hant-tw/product/" in full_url:
            full_url_list.append(full_url)

        for partial_url in full_url_list:
#             meger = []

            extract_info(partial_url)
#             meger.append([Name,Gold,platform,release_date,publisher,type_of_game])
#             print("----------------------------------------------------------------------------------------------------------")
#         time.sleep(10)
#         ws.append(extract_info(partial_url))
#         wb.save("PS4.xlsx")

# %%
from bs4 import BeautifulSoup
import requests
from urllib.parse import urljoin
import re
import time
import openpyxl

def extract_info(url):
    res = requests.get(url)
    soup = BeautifulSoup(res.text, "html.parser")

    Name = soup.find('div', class_="psw-c-bg-0").h1.text
    print("遊戲名稱:", Name)

    Gold = soup.find("span", class_="psw-l-line-left psw-l-line-wrap").text
    print("價格:", Gold)

    Platform_info = soup.find("dl", {"data-qa": "gameInfo#releaseInformation"})
    meger = []
    if Platform_info:
        Platform_text = Platform_info.text

        platform_match = re.search(r"平台:(.*?)推出日:(.*?)發行商:(.*?)類型:(.*?)$", Platform_text)
        
        if platform_match:
            platform = platform_match.group(1).strip()
            release_date = platform_match.group(2).strip()
            publisher = platform_match.group(3).strip()
            type_of_game = platform_match.group(4).strip()

            print("平台:", platform)
            print("推出日:", release_date)
            print("發行商:", publisher)
            print("類型:", type_of_game)
            meger.append([Name,Gold,platform,release_date,publisher,type_of_game])
        else:
            print("無法正確提取平台、推出日、發行商和類型信息")
    else:
        print("未找到平台信息")
    return meger
# -----------------------------------------------------------------------------------------------------------   
wb = openpyxl.Workbook()
ws = wb.active

ws["A1"]="遊戲名稱"
ws["B1"]="販賣價格"
ws["C1"]="遊戲平台"
ws["D1"]="發行日期"
ws["E1"]="發行廠商"

into_url = "https://store.playstation.com/zh-hant-tw/product/HP6238-PPSA02428_00-0087645165886036"
extract_info(into_url)
base_url = "https://store.playstation.com/zh-hant-tw/category/5f3aa730-1c8e-4a18-84da-030bb91558c0/"
page_numbers=list(range(1,1))

for page_number in page_numbers:
    url = base_url+str(page_number)
    res = requests.get(url)
    soup = BeautifulSoup(res.text,"lxml")
    class_1="psw-l-w-1/2@mobile-s psw-l-w-1/2@mobile-l psw-l-w-1/6@tablet-l psw-l-w-1/4@tablet-s psw-l-w-1/6@laptop psw-l-w-1/8@desktop psw-l-w-1/8@max"
    jobs = soup.find_all("li",class_=class_1)
    links = soup.find_all("a", href=True)
    base_url1 = "https://store.playstation.com/zh-hant-tw/"  
    
    full_url_list = []
    for link in links:
        href = link["href"]
        full_url = urljoin(base_url1, href)
        if "/zh-hant-tw/product/" in full_url:
            full_url_list.append(full_url)
    meger = []
    for partial_url in full_url_list:
        data = extract_info(partial_url)
        if data:
            meger.extend(data)  # 將提取的資料添加到 meger 列表
        elif data == "":
            pass
    # 將 meger 列表中的資料逐一添加到 Excel 工作表中
    for data in meger:
        ws.append(data)

    wb.save("PS4.xlsx")

#         for partial_url in full_url_list:
#             data = extract_info(partial_url)
#             if data:
#                 ws.append(data[0])
                
# # print("----------------------------------------------------------------------------------------------------------")
# #         time.sleep(10)
# wb.save("PS4.xlsx")

# %%
from bs4 import BeautifulSoup
import requests
from urllib.parse import urljoin
import re
import time
import openpyxl

def extract_info(url):
    res = requests.get(url)
    soup = BeautifulSoup(res.text, "html.parser")

    Name_element = soup.find('div', class_="psw-c-bg-0")
    if Name_element:
        Name = Name_element.h1.text
        print("遊戲名稱:", Name)
    else:
        print("找不到遊戲名稱")

    Gold_element = soup.find("span", class_="psw-l-line-left psw-l-line-wrap")
    if Gold_element:
        Gold = Gold_element.text
        print("價格:", Gold)
    else:
        print("找不到價格")
        
    Platform_info = soup.find("dl", {"data-qa": "gameInfo#releaseInformation"})
    meger = []
    if Platform_info:
        Platform_text = Platform_info.text
        platform_match = re.search(r"平台:(.*?)推出日:(.*?)發行商:(.*?)類型:(.*?)$", Platform_text)
        
        if platform_match:
            platform = platform_match.group(1).strip()
            release_date = platform_match.group(2).strip()
            publisher = platform_match.group(3).strip()
            type_of_game = platform_match.group(4).strip()

            print("平台:", platform)
            print("推出日:", release_date)
            print("發行商:", publisher)
            print("類型:", type_of_game)
            meger.append([Name, Gold, platform, release_date, publisher, type_of_game])
        else:
            print("無法正確提取平台、推出日、發行商和類型信息")
    else:
        print("未找到平台信息")
    return meger

# -----------------------------------------------------------------------------------------------------------   
wb = openpyxl.Workbook()
ws = wb.active

ws["A1"]="遊戲名稱"
ws["B1"]="販賣價格"
ws["C1"]="遊戲平台"
ws["D1"]="發行日期"
ws["E1"]="發行廠商"

# into_url = "https://store.playstation.com/zh-hant-tw/product/HP6238-PPSA02428_00-0087645165886036"
# extract_info(into_url)
base_url = "https://store.playstation.com/zh-hant-tw/category/5f3aa730-1c8e-4a18-84da-030bb91558c0/"
page_numbers=list(range(1,253))

for page_number in page_numbers:
    print("--------------------------------------------------------------------------------------------------")  
    print("處理第", page_number, "頁")
    url = base_url+str(page_number)
    res = requests.get(url)
    soup = BeautifulSoup(res.text,"lxml")
    class_1="psw-l-w-1/2@mobile-s psw-l-w-1/2@mobile-l psw-l-w-1/6@tablet-l psw-l-w-1/4@tablet-s psw-l-w-1/6@laptop psw-l-w-1/8@desktop psw-l-w-1/8@max"
    jobs = soup.find_all("li",class_=class_1)
    links = soup.find_all("a", href=True)
    base_url1 = "https://store.playstation.com/zh-hant-tw/"  
    
    full_url_list = []
    for link in links:
        href = link["href"]
        full_url = urljoin(base_url1, href)
        if "/zh-hant-tw/product/" in full_url:
            full_url_list.append(full_url)

    # 創建 meger 列表
    meger = []
    for partial_url in full_url_list:
        data = extract_info(partial_url)
        if data:
            meger.extend(data)  # 將提取的資料添加到 meger 列表

    # 將 meger 列表中的資料逐一添加到 Excel 工作表中
    for data in meger:
        ws.append(data)
    wb.save("PS4.xlsx")
    
wb.save("PS4.xlsx")
# Out:
# 遊戲名稱: Farming Simulator 22 - Premium Edition (簡體中文, 韓文, 英文, 繁體中文, 日文)
# 價格: NT$1,790
# 平台: PS4, PS5
# 推出日: 13/11/2023
# 發行商: Giants Software GmbH
# 類型: 模擬器
# --------------------------------------------------------------------------------------------------
# 處理第 1 頁
# 遊戲名稱: Farming Simulator 22 - Premium Edition (簡體中文, 韓文, 英文, 繁體中文, 日文)
# 價格: NT$1,790
# 平台: PS4, PS5
# 推出日: 13/11/2023
# 發行商: Giants Software GmbH
# 類型: 模擬器
# 遊戲名稱: HOT WHEELS UNLEASHED™ 2 - Turbocharged PS4 & PS5 (簡體中文, 英文, 繁體中文, 日文)
# 價格: NT$1,490
# 平台: PS5
# 推出日: 18/10/2023
# 發行商: MILESTONE
# 類型: 駕車／賽車
# 遊戲名稱: 《飆酷車神：動力慶典》標準版 (簡體中文, 韓文, 英文, 繁體中文, 日文)
# 價格: NT$1,790
# 平台: PS4
# 推出日: 13/9/2023
# 發行商: UBISOFT
# 類型: 駕車／賽車
# 遊戲名稱: Eternights (PS4 & PS5) (簡體中文, 韓文, 英文, 繁體中文, 日文)
# 價格: NT$889
# 平台: PS5
# 推出日: 11/9/2023
# 發行商: Studio Sai
# 類型: 動作, 特殊遊戲
# 遊戲名稱: PS4™《NBA 2K24》Kobe Bryant版 (簡體中文, 韓文, 英文, 繁體中文, 日文)
# 價格: NT$1,790
# 平台: PS4
# 推出日: 7/9/2023
# 發行商: Take-Two
# 類型: 運動
# 遊戲名稱: Chants of Sennaar (簡體中文, 韓文, 英文, 繁體中文, 日文)
# ...

# %%
from bs4 import BeautifulSoup
import requests
from urllib.parse import urljoin
import re
import time
import openpyxl

def extract_info(url):
    res = requests.get(url)
    soup = BeautifulSoup(res.text, "html.parser")

    Name_element = soup.find('div', class_="psw-c-bg-0")
    Gold_element = soup.find("span", class_="psw-l-line-left psw-l-line-wrap")
    Platform_info = soup.find("dl", {"data-qa": "gameInfo#releaseInformation"}) 
    meger = []   
    if Name_element and Gold_element and Platform_info:
        Name = Name_element.h1.text
        Gold = Gold_element.text
        Platform_text = Platform_info.text
        platform_match = re.search(r"平台:(.*?)推出日:(.*?)發行商:(.*?)類型:(.*?)$", Platform_text)
        if platform_match:
            platform = platform_match.group(1).strip()
            release_date = platform_match.group(2).strip()
            publisher = platform_match.group(3).strip()
            type_of_game = platform_match.group(4).strip()
            meger.append([Name, Gold, platform, release_date, publisher, type_of_game])
        else:
            print("無法正確提取平台、推出日、發行商和類型信息")
    else:
        print("無法找到遊戲名稱、價格或平台信息")
        
    return meger

# -----------------------------------------------------------------------------------------------------------   
wb = openpyxl.Workbook()
ws = wb.active

ws["A1"]="遊戲名稱"
ws["B1"]="販賣價格"
ws["C1"]="遊戲平台"
ws["D1"]="發行日期"
ws["E1"]="發行廠商"

base_url = "https://store.playstation.com/zh-hant-tw/category/5f3aa730-1c8e-4a18-84da-030bb91558c0/"
page_numbers = list(range(1, 253))

for page_number in page_numbers:
    url = base_url + str(page_number)
    res = requests.get(url)
    soup = BeautifulSoup(res.text, "lxml")
    class_1 = "psw-l-w-1/2@mobile-s psw-l-w-1/2@mobile-l psw-l-w-1/6@tablet-l psw-l-w-1/4@tablet-s psw-l-w-1/6@laptop psw-l-w-1/8@desktop psw-l-w-1/8@max"
    links = soup.find_all("a", href=True)
    base_url1 = "https://store.playstation.com/zh-hant-tw/"  
    
    full_url_list = []
    for link in links:
        href = link["href"]
        full_url = urljoin(base_url1, href)
        if "/zh-hant-tw/product/" in full_url:
            full_url_list.append(full_url)
    # 創建 meger 列表
    meger = []
    for partial_url in full_url_list:
        data = extract_info(partial_url)
        if data:
            meger.extend(data)  # 將提取的資料添加到 meger 列表
    # 將 meger 列表中的資料逐一添加到 Excel 工作表中
    for data in meger:
        ws.append(data)
    # 存檔
    print(f"第 {page_number} 頁已完成")
    wb.save("PS4.xlsx")
# Out:
# 第 1 頁已完成
# 第 2 頁已完成
# 第 3 頁已完成
# 第 4 頁已完成
# 第 5 頁已完成
# 第 6 頁已完成
# 第 7 頁已完成
# 第 8 頁已完成
# 第 9 頁已完成
# 第 10 頁已完成
# 第 11 頁已完成
# 第 12 頁已完成
# 第 13 頁已完成
# 第 14 頁已完成
# 第 15 頁已完成
# 第 16 頁已完成
# 第 17 頁已完成
# 第 18 頁已完成
# 第 19 頁已完成
# 第 20 頁已完成
# 第 21 頁已完成
# 第 22 頁已完成
# 第 23 頁已完成
# 第 24 頁已完成
# 第 25 頁已完成
# 第 26 頁已完成
# 第 27 頁已完成
# 第 28 頁已完成
# 無法找到遊戲名稱、價格或平台信息
# 第 29 頁已完成
# 第 30 頁已完成
# 第 31 頁已完成
# 第 32 頁已完成
# 第 33 頁已完成
# 第 34 頁已完成
# 第 35 頁已完成
# 第 36 頁已完成
# 第 37 頁已完成
# 第 38 頁已完成
# 第 39 頁已完成
# 第 40 頁已完成
# 第 41 頁已完成
# 第 42 頁已完成
# 第 43 頁已完成
# 第 44 頁已完成
# 第 45 頁已完成
# 第 46 頁已完成
# 第 47 頁已完成
# 第 48 頁已完成
# 第 49 頁已完成
# 第 50 頁已完成
# 第 51 頁已完成
# 第 52 頁已完成
# 第 53 頁已完成
# 第 54 頁已完成
# 第 55 頁已完成
# 第 56 頁已完成
# 第 57 頁已完成
# 第 58 頁已完成
# 第 59 頁已完成
# 無法找到遊戲名稱、價格或平台信息
# 第 60 頁已完成
# 無法找到遊戲名稱、價格或平台信息
# 無法找到遊戲名稱、價格或平台信息
# 第 61 頁已完成
# 無法找到遊戲名稱、價格或平台信息
# 無法找到遊戲名稱、價格或平台信息
# 無法找到遊戲名稱、價格或平台信息
# 無法找到遊戲名稱、價格或平台信息
# 第 62 頁已完成
# 第 63 頁已完成
# 第 64 頁已完成
# 第 65 頁已完成
# 第 66 頁已完成
# 第 67 頁已完成
# 第 68 頁已完成
# 第 69 頁已完成
# 第 70 頁已完成
# 第 71 頁已完成
# ...
