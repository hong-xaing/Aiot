# %%
import requests
from bs4 import BeautifulSoup
from time import sleep
import openpyxl
import datetime

url = "https://www.104.com.tw/jobs/search/?keyword=%E5%A4%A7%E6%95%B8%E6%93%9A&order=1&jobsource=2018indexpoc&ro=0"
res = requests.get(url)
soup = BeautifulSoup(res.text,"lxml")
wb = openpyxl.Workbook()
ws = wb.active

ws["A1"]="刊登日期"
ws["B1"]="工作名稱"
ws["C1"]="職缺連結"
ws["D1"]="公司名稱"
ws["E1"]="工作地區"
ws["F1"]="薪資待遇"
ws["G1"]="薪資模式"
ws["H1"]="最低下限"
ws["I1"]="最高上限"
ws["J1"]="應徵人數"

# print(html1[0])
# for soup in 
# print(html1[0]("a")[0]["href"])
# print(soup.find_all('article')[0],"a")
# for 自訂統稱 in 每一物件 :
# meger = [workname,internet,company,area,bouns]
# meger = []
page = 1
while page < 5:
# while soup.find_all("article",class_="b-block--top-bord job-list-item b-clearfix js-job-item")!=[]:
    print("======================")
    print("現在正在讀取第",page,"頁")
    print("======================")
    meger = []
    for job in soup.find_all("article",class_="b-block--top-bord job-list-item b-clearfix js-job-item"):
        date = job.h2.span.text
        workname = job.a.text        
        internet = "http:"+job.a['href']        
        company = job.ul.a.text.strip()        
        location = job.select("ul")[1].li.text
        human = job.find("a",class_="b-link--gray gtm-list-apply").text        
        if job.find('div',class_="job-list-tag b-content").select("span")!=[] and job.find('div',class_="job-list-tag b-content").span.text=="待遇面議":
            e = job.find('div',class_="job-list-tag b-content").span.text
            print(salary)
            f = ""
            low_price = ""
            high_price = ""
        else :
            e = job.find('div',class_="job-list-tag b-content").a.text
#             print(salary)

            f = e [:2]
            print(f)
            salary = ""
            for char in e:
                if char == "~" or char.isdigit():
                    salary += char 
            print (f)
            if "~" in salary:
                low_price = salary[:salary.find("~")]
                high_price = salary[salary.find("~")+1:]
            else :
                low_price = salary
                high_price = salary
            low_price =int(low_price)
            high_price= int(high_price)


#             if "~" in salary:
#                 low_price = salary[:salary.find("~")]
#                 high_price = salary[salary.find("~")+1:]
#             else :
#                 low_price = salary
#                 high_price = salary
#             f = salary[:2]
#             for char in salary:
#                 if char == "~" or char.isdigit():
#                     salary += char 
                
#                 print (f)

#         print(date)    
#         print(workname)
#         print(internet)
#         print(company)
#         print(location)
#         print(human)
#         print("--------------------------------------------------------------------")
        ws.append([date,workname,internet,company,location,e,f,low_price,high_price,human])
        
    page += 1 
    url = "https://www.104.com.tw/jobs/search/?ro=0&kwop=7&keyword=%E5%A4%A7%E6%95%B8%E6%93%9A&expansionType=area%2Cspec%2Ccom%2Cjob%2Cwf%2Cwktm&order=14&asc=0&page="+str(page)+"&mode=s&jobsource=2018indexpoc&langFlag=0&langStatus=0&recommendJob=1&hotJob=1"
    res = requests.get(url)
    soup = BeautifulSoup(res.text,"lxml")
    sleep(2)
    wb.save("104人力銀行"+str(datetime.date.today())+".xlsx")
# Out:
# ======================
# 現在正在讀取第 1 頁
# ======================
# 月薪35,000元以上
# 月薪
# 月薪
# 月薪
# 月薪
# 35000
# 月薪
# 月薪
# 月薪
# 月薪
# 月薪
# 月薪
# 月薪
# 月薪
# 月薪
# 月薪
# 30000~40000
# 時薪
# 時薪
# 月薪
# 月薪
# 月薪
# 月薪
# 年薪
# 年薪
# 800000~1200000
# 時薪
# 時薪
# 176
# 176
# 176
# 月薪
# 月薪
# ======================
# 現在正在讀取第 2 頁
# ======================
# 年薪
# 年薪
# 時薪
# 時薪
# 176
# 月薪
# 月薪
# 月薪
# 月薪
# 40000~45000
# 月薪
# 月薪
# 34000~53000
# 34000~53000
# 34000~53000
# 34000~53000
# 月薪
# 月薪
# 34000
# 月薪
# 月薪
# 36000~42000
# 月薪
# 月薪
# 32000~40000
# 32000~40000
# 32000~40000
# 月薪
# 月薪
# ======================
# 現在正在讀取第 3 頁
# ======================
# 月薪
# 月薪
# 36000~42000
# 月薪
# 月薪
# 32000~40000
# 32000~40000
# 32000~40000
# 時薪
# 時薪
# 月薪
# 月薪
# 45000
# 月薪
# 月薪
# 時薪
# 時薪
# 月薪
# 月薪
# 45000~50000
# 45000~50000
# 月薪
# 月薪
# 時薪
# 時薪
# 月薪
# 月薪
# 38000
# 月薪
# 月薪
# 月薪
# 月薪
# ======================
# 現在正在讀取第 4 頁
# ======================
# 月薪
# 月薪
# 時薪
# 時薪
# 月薪
# 月薪
# 時薪
# 時薪
# 176
# 月薪
# 月薪
# 月薪
# 月薪
# 月薪
# 月薪
# 月薪
# 月薪
# 36000
# 月薪
# 月薪
# 30000~50000
# 30000~50000
# 時薪
# 時薪
# 時薪
# 時薪
# 月薪
# 月薪
# 月薪
# 月薪
# 月薪
# 月薪
# 50000
# 50000

# %%
# e = '月薪35,000元以上'
# e = '月薪38,000~45,000元'
# e = '時薪176元以上'
# e = '時薪176~190元'
# e = '年薪1,000,000元以上'
# e = '年薪3,000,000~4,000,000元'
e = '論件計酬10,000~2,000,000元'

# isdigit 只找有數字的字元

f = e [:2]
print(f)
salary = ""
for char in e:
    if char == "~" or char.isdigit():
        salary += char 
print (f)
if "~" in salary:
    low_price = salary[:salary.find("~")]
    high_price = salary[salary.find("~")+1:]
else :
    low_price = salary
    high_price = salary
low_price =int(low_price)
high_price= int(high_price)


print (low_price,high_price)
# Out:
# 論件
# 論件
# 10000 2000000

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 7
#       5 low_price = salary
#       6 high_price = salary
# ----> 7 low_price =int(low_price)
#       8 high_price= int(high_price)
#       9 print (low_price)
#
# ValueError: invalid literal for int() with base 10: '待遇面議'

# %%
a = "abcde"

b = a.find("c")

print (b)
# Out:
# 2

# %%
import requests
from bs4 import BeautifulSoup
from time import sleep
import openpyxl
import datetime

url = "https://www.104.com.tw/jobs/search/?keyword=%E5%A4%A7%E6%95%B8%E6%93%9A&order=1&jobsource=2018indexpoc&ro=0"
res = requests.get(url)
soup = BeautifulSoup(res.text,"lxml")
wb = openpyxl.Workbook()
ws = wb.active

ws["A1"]="刊登日期"
ws["B1"]="工作名稱"
ws["C1"]="職缺連結"
ws["D1"]="公司名稱"
ws["E1"]="工作地區"
ws["F1"]="薪資待遇"
ws["G1"]="薪資模式"
ws["H1"]="最低下限"
ws["I1"]="最高上限"
ws["J1"]="應徵人數"

# print(html1[0])
# for soup in 
# print(html1[0]("a")[0]["href"])
# print(soup.find_all('article')[0],"a")
# for 自訂統稱 in 每一物件 :
# meger = [workname,internet,company,area,bouns]
# meger = []
page = 1
# while page < 5:
while soup.find_all("article",class_="b-block--top-bord job-list-item b-clearfix js-job-item")!=[]:
    print("======================")
    print("現在正在讀取第",page,"頁")
    print("======================")
    meger = []
    for job in soup.find_all("article",class_="b-block--top-bord job-list-item b-clearfix js-job-item"):
        date = job.h2.span.text
        workname = job.a.text        
        internet = "http:"+job.a['href']        
        company = job.ul.a.text.strip()        
        location = job.select("ul")[1].li.text
        human = job.find("a",class_="b-link--gray gtm-list-apply").text        
        if job.find('div',class_="job-list-tag b-content").select("span")!=[] and job.find('div',class_="job-list-tag b-content").span.text=="待遇面議":
            salary = job.find('div',class_="job-list-tag b-content").span.text
            print(salary)
            bouns = ""
            low_price = ""
            high_price = ""
        else :
            salary = job.find('div',class_="job-list-tag b-content").a.text
#             print(salary)

            bouns = salary[:2]
            print()
            salary1 = ""
            for char in salary:
                if char == "~" or char.isdigit():
                    salary1 += char 
            print (bouns)
            if "~" in salary1:
                low_price = salary1[:salary1.find("~")]
                high_price = salary1[salary1.find("~")+1:]
            else :
                low_price = salary1
                high_price = salary1
            low_price =int(low_price)
            high_price= int(high_price)


#             if "~" in salary:
#                 low_price = salary[:salary.find("~")]
#                 high_price = salary[salary.find("~")+1:]
#             else :
#                 low_price = salary
#                 high_price = salary
#             f = salary[:2]
#             for char in salary:
#                 if char == "~" or char.isdigit():
#                     salary += char 
                
#                 print (f)

#         print(date)    
#         print(workname)
#         print(internet)
#         print(company)
#         print(location)
#         print(human)
#         print("--------------------------------------------------------------------")
        ws.append([date,workname,internet,company,location,salary,bouns,low_price,high_price,human])
        
    page += 1 
    url = "https://www.104.com.tw/jobs/search/?ro=0&kwop=7&keyword=%E5%A4%A7%E6%95%B8%E6%93%9A&expansionType=area%2Cspec%2Ccom%2Cjob%2Cwf%2Cwktm&order=14&asc=0&page="+str(page)+"&mode=s&jobsource=2018indexpoc&langFlag=0&langStatus=0&recommendJob=1&hotJob=1"
    res = requests.get(url)
    soup = BeautifulSoup(res.text,"lxml")
    sleep(2)
    wb.save("104人力銀行"+str(datetime.date.today())+".xlsx")
# Out:
# ======================
# 現在正在讀取第 1 頁
# ======================
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
#
# 時薪
#
# 月薪
# 待遇面議
# ======================
# 現在正在讀取第 2 頁
# ======================
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
# ======================
# 現在正在讀取第 3 頁
# ======================
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
#
# 時薪
#
# 月薪
# 待遇面議
#
# 月薪
#
# 時薪
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
#
# 時薪
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
# ======================
# 現在正在讀取第 4 頁
# ======================
#
# 月薪
#
# 時薪
#
# 月薪
#
# 時薪
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
#
# 時薪
#
# 時薪
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
# ======================
# 現在正在讀取第 5 頁
# ======================
# 待遇面議
#
# 時薪
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
# ======================
# 現在正在讀取第 6 頁
# ======================
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# ======================
# 現在正在讀取第 7 頁
# ======================
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
# ======================
# 現在正在讀取第 8 頁
# ======================
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# ======================
# 現在正在讀取第 9 頁
# ======================
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 論件
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 時薪
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
#
# 年薪
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
# ======================
# 現在正在讀取第 10 頁
# ======================
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
# ======================
# 現在正在讀取第 11 頁
# ======================
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
#
# 月薪
#
# 月薪
#
# 年薪
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# ======================
# 現在正在讀取第 12 頁
# ======================
#
# 月薪
#
# 月薪
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
#
# 年薪
# ======================
# 現在正在讀取第 13 頁
# ======================
#
# 年薪
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 年薪
#
# 月薪
# 待遇面議
#
# 月薪
# ======================
# 現在正在讀取第 14 頁
# ======================
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 年薪
#
# 月薪
# 待遇面議
#
# 月薪
#
# 年薪
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# ======================
# 現在正在讀取第 15 頁
# ======================
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
# ======================
# 現在正在讀取第 16 頁
# ======================
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
#
# 年薪
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
#
# 年薪
# ======================
# 現在正在讀取第 17 頁
# ======================
#
# 月薪
#
# 年薪
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
#
# 年薪
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
# ======================
# 現在正在讀取第 18 頁
# ======================
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
#
# 時薪
# 待遇面議
# 待遇面議
#
# 時薪
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 年薪
# 待遇面議
# ======================
# 現在正在讀取第 19 頁
# ======================
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
#
# 時薪
# 待遇面議
#
# 月薪
# ======================
# 現在正在讀取第 20 頁
# ======================
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 論件
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
#
# 時薪
#
# 月薪
#
# 月薪
# 待遇面議
#
# 時薪
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
#
# 年薪
# ======================
# 現在正在讀取第 21 頁
# ======================
#
# 年薪
#
# 時薪
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
# ======================
# 現在正在讀取第 22 頁
# ======================
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
#
# 論件
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
# ======================
# 現在正在讀取第 23 頁
# ======================
#
# 月薪
#
# 月薪
#
# 年薪
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# ======================
# 現在正在讀取第 24 頁
# ======================
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
#
# 時薪
# 待遇面議
#
# 月薪
#
# 年薪
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
# ======================
# 現在正在讀取第 25 頁
# ======================
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# ======================
# 現在正在讀取第 26 頁
# ======================
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
#
# 論件
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
#
# 年薪
#
# 月薪
# ======================
# 現在正在讀取第 27 頁
# ======================
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# ======================
# 現在正在讀取第 28 頁
# ======================
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
#
# 年薪
#
# 月薪
#
# 月薪
#
# 時薪
#
# 月薪
# 待遇面議
# ======================
# 現在正在讀取第 29 頁
# ======================
# 待遇面議
# 待遇面議
#
# 月薪
#
# 時薪
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
#
# 月薪
#
# 月薪
#
# 時薪
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
# ======================
# 現在正在讀取第 30 頁
# ======================
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
#
# 時薪
#
# 月薪
# 待遇面議
# 待遇面議
# ======================
# 現在正在讀取第 31 頁
# ======================
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
#
# 時薪
# 待遇面議
#
# 年薪
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
# ======================
# 現在正在讀取第 32 頁
# ======================
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
#
# 時薪
# 待遇面議
# ======================
# 現在正在讀取第 33 頁
# ======================
# 待遇面議
#
# 月薪
#
# 時薪
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
#
# 年薪
#
# 月薪
# 待遇面議
# 待遇面議
#
# 時薪
#
# 年薪
# 待遇面議
# 待遇面議
# ======================
# 現在正在讀取第 34 頁
# ======================
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
#
# 年薪
# ======================
# 現在正在讀取第 35 頁
# ======================
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
#
# 年薪
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
#
# 時薪
# 待遇面議
# 待遇面議
# 待遇面議
# ======================
# 現在正在讀取第 36 頁
# ======================
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
#
# 時薪
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# ======================
# 現在正在讀取第 37 頁
# ======================
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
#
# 月薪
# ======================
# 現在正在讀取第 38 頁
# ======================
# 待遇面議
#
# 時薪
# 待遇面議
# 待遇面議
#
# 時薪
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 年薪
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
#
# 時薪
# ======================
# 現在正在讀取第 39 頁
# ======================
# 待遇面議
#
# 時薪
#
# 月薪
#
# 月薪
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
#
# 時薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# ======================
# 現在正在讀取第 40 頁
# ======================
# 待遇面議
#
# 時薪
# 待遇面議
#
# 時薪
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
#
# 時薪
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
#
# 時薪
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# ======================
# 現在正在讀取第 41 頁
# ======================
# 待遇面議
# 待遇面議
# 待遇面議
#
# 時薪
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
#
# 時薪
#
# 時薪
#
# 月薪
# 待遇面議
#
# 年薪
#
# 月薪
#
# 時薪
# 待遇面議
# 待遇面議
# ======================
# 現在正在讀取第 42 頁
# ======================
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
#
# 時薪
# 待遇面議
# 待遇面議
# ======================
# 現在正在讀取第 43 頁
# ======================
# 待遇面議
#
# 月薪
# 待遇面議
#
# 年薪
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
#
# 時薪
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
#
# 論件
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# ======================
# 現在正在讀取第 44 頁
# ======================
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# ======================
# 現在正在讀取第 45 頁
# ======================
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 年薪
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# ======================
# 現在正在讀取第 46 頁
# ======================
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 年薪
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
# ======================
# 現在正在讀取第 47 頁
# ======================
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 時薪
#
# 時薪
# 待遇面議
#
# 年薪
# ======================
# 現在正在讀取第 48 頁
# ======================
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
#
# 年薪
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
#
# 時薪
# 待遇面議
# 待遇面議
# 待遇面議
#
# 年薪
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
#
# 時薪
#
# 月薪
# ======================
# 現在正在讀取第 49 頁
# ======================
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
#
# 時薪
#
# 時薪
# ======================
# 現在正在讀取第 50 頁
# ======================
# 待遇面議
#
# 月薪
#
# 時薪
#
# 月薪
#
# 年薪
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
#
# 論件
# 待遇面議
# 待遇面議
#
# 論件
#
# 月薪
#
# 月薪
#
# 月薪
#
# 月薪
#
# 月薪
# ======================
# 現在正在讀取第 51 頁
# ======================
#
# 月薪
#
# 月薪
#
# 時薪
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
#
# 時薪
#
# 論件
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# ======================
# 現在正在讀取第 52 頁
# ======================
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
# ======================
# 現在正在讀取第 53 頁
# ======================
# 待遇面議
#
# 論件
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
#
# 論件
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
#
# 時薪
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# ======================
# 現在正在讀取第 54 頁
# ======================
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 年薪
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
#
# 時薪
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# ======================
# 現在正在讀取第 55 頁
# ======================
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
#
# 年薪
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# ======================
# 現在正在讀取第 56 頁
# ======================
# 待遇面議
#
# 年薪
#
# 月薪
#
# 月薪
#
# 日薪
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
# ======================
# 現在正在讀取第 57 頁
# ======================
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 年薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
# ======================
# 現在正在讀取第 58 頁
# ======================
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
#
# 日薪
#
# 月薪
# 待遇面議
# ======================
# 現在正在讀取第 59 頁
# ======================
# 待遇面議
# 待遇面議
#
# 年薪
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 年薪
#
# 月薪
#
# 月薪
#
# 年薪
#
# 月薪
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# ======================
# 現在正在讀取第 60 頁
# ======================
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
#
# 時薪
# 待遇面議
#
# 月薪
# 待遇面議
# ======================
# 現在正在讀取第 61 頁
# ======================
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
#
# 日薪
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
# ======================
# 現在正在讀取第 62 頁
# ======================
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# ======================
# 現在正在讀取第 63 頁
# ======================
#
# 日薪
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
# ======================
# 現在正在讀取第 64 頁
# ======================
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
#
# 日薪
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# ======================
# 現在正在讀取第 65 頁
# ======================
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
#
# 日薪
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
# ======================
# 現在正在讀取第 66 頁
# ======================
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
#
# 時薪
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
#
# 時薪
# 待遇面議
# 待遇面議
# ======================
# 現在正在讀取第 67 頁
# ======================
# 待遇面議
#
# 年薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
#
# 年薪
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
# ======================
# 現在正在讀取第 68 頁
# ======================
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
#
# 論件
# 待遇面議
#
# 年薪
#
# 時薪
# 待遇面議
#
# 月薪
#
# 月薪
#
# 時薪
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
#
# 時薪
#
# 月薪
# 待遇面議
# ======================
# 現在正在讀取第 69 頁
# ======================
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 年薪
# 待遇面議
#
# 年薪
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
#
# 年薪
#
# 月薪
#
# 月薪
# ======================
# 現在正在讀取第 70 頁
# ======================
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
#
# 年薪
#
# 時薪
#
# 月薪
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
#
# 月薪
#
# 月薪
# ======================
# 現在正在讀取第 71 頁
# ======================
#
# 月薪
#
# 月薪
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
#
# 年薪
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# ======================
# 現在正在讀取第 72 頁
# ======================
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
#
# 時薪
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
# ======================
# 現在正在讀取第 73 頁
# ======================
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
#
# 年薪
# 待遇面議
# 待遇面議
# ======================
# 現在正在讀取第 74 頁
# ======================
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
#
# 時薪
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# ======================
# 現在正在讀取第 75 頁
# ======================
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
# ======================
# 現在正在讀取第 76 頁
# ======================
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
# ======================
# 現在正在讀取第 77 頁
# ======================
#
# 年薪
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
#
# 時薪
# 待遇面議
# ======================
# 現在正在讀取第 78 頁
# ======================
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 時薪
#
# 月薪
# ======================
# 現在正在讀取第 79 頁
# ======================
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# ======================
# 現在正在讀取第 80 頁
# ======================
# 待遇面議
# 待遇面議
#
# 年薪
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
# ======================
# 現在正在讀取第 81 頁
# ======================
#
# 月薪
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# ======================
# 現在正在讀取第 82 頁
# ======================
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
#
# 時薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# ======================
# 現在正在讀取第 83 頁
# ======================
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# ======================
# 現在正在讀取第 84 頁
# ======================
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# ======================
# 現在正在讀取第 85 頁
# ======================
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# ======================
# 現在正在讀取第 86 頁
# ======================
#
# 時薪
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# ======================
# 現在正在讀取第 87 頁
# ======================
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
#
# 年薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
#
# 年薪
# 待遇面議
#
# 月薪
# ======================
# 現在正在讀取第 88 頁
# ======================
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# ======================
# 現在正在讀取第 89 頁
# ======================
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 時薪
#
# 月薪
# ======================
# 現在正在讀取第 90 頁
# ======================
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
# ======================
# 現在正在讀取第 91 頁
# ======================
# 待遇面議
# 待遇面議
# 待遇面議
#
# 時薪
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
#
# 時薪
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
#
# 論件
# 待遇面議
# ======================
# 現在正在讀取第 92 頁
# ======================
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# ======================
# 現在正在讀取第 93 頁
# ======================
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
#
# 時薪
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
#
# 年薪
# ======================
# 現在正在讀取第 94 頁
# ======================
# 待遇面議
# 待遇面議
#
# 月薪
#
# 時薪
#
# 年薪
# 待遇面議
# 待遇面議
# 待遇面議
#
# 年薪
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 年薪
# 待遇面議
#
# 月薪
# ======================
# 現在正在讀取第 95 頁
# ======================
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 時薪
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
#
# 論件
# 待遇面議
# ======================
# 現在正在讀取第 96 頁
# ======================
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
#
# 時薪
# 待遇面議
# 待遇面議
# 待遇面議
# ======================
# 現在正在讀取第 97 頁
# ======================
# 待遇面議
#
# 時薪
#
# 時薪
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
#
# 時薪
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
#
# 時薪
#
# 月薪
# 待遇面議
# ======================
# 現在正在讀取第 98 頁
# ======================
# 待遇面議
#
# 年薪
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
#
# 年薪
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
# ======================
# 現在正在讀取第 99 頁
# ======================
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
#
# 時薪
#
# 論件
#
# 月薪
#
# 時薪
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# ======================
# 現在正在讀取第 100 頁
# ======================
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
#
# 年薪
#
# 月薪
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
# ======================
# 現在正在讀取第 101 頁
# ======================
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
#
# 年薪
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
#
# 日薪
# 待遇面議
# 待遇面議
# ======================
# 現在正在讀取第 102 頁
# ======================
# 待遇面議
#
# 年薪
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
#
# 論件
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# ======================
# 現在正在讀取第 103 頁
# ======================
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
#
# 論件
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# ======================
# 現在正在讀取第 104 頁
# ======================
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# ======================
# 現在正在讀取第 105 頁
# ======================
# 待遇面議
#
# 時薪
#
# 月薪
#
# 月薪
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 時薪
# 待遇面議
# 待遇面議
#
# 月薪
#
# 時薪
# ======================
# 現在正在讀取第 106 頁
# ======================
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# ======================
# 現在正在讀取第 107 頁
# ======================
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
# 待遇面議
#
# 月薪
#
# 月薪
# 待遇面議
# ======================
# 現在正在讀取第 108 頁
# ======================
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
#
# 月薪
#
# 月薪
#
# 月薪
# 待遇面議
#
# 論件
# 待遇面議
#
# 月薪
# 待遇面議
#
# 月薪

# %%
import requests
from bs4 import BeautifulSoup
from time import sleep
import openpyxl
import datetime

url = "https://www.104.com.tw/jobs/search/?keyword=%E5%A4%A7%E6%95%B8%E6%93%9A&order=1&jobsource=2018indexpoc&ro=0"
res = requests.get(url)
soup = BeautifulSoup(res.text,"lxml")
wb = openpyxl.Workbook()
ws = wb.active

ws["A1"]="刊登日期"
ws["B1"]="工作名稱"
ws["C1"]="職缺連結"
ws["D1"]="公司名稱"
ws["E1"]="工作地區"
ws["F1"]="薪資待遇"
ws["G1"]="薪資模式"
ws["H1"]="最低下限"
ws["I1"]="最高上限"
ws["J1"]="應徵人數"
ws["K1"]="最低人數"
ws["L1"]="最高人數"

# print(html1[0])
# for soup in 
# print(html1[0]("a")[0]["href"])
# print(soup.find_all('article')[0],"a")
# for 自訂統稱 in 每一物件 :
# meger = [workname,internet,company,area,bouns]
# meger = []
page = 1
while page < 5:
# while soup.find_all("article",class_="b-block--top-bord job-list-item b-clearfix js-job-item")!=[]:
    print("======================")
    print("現在正在讀取第",page,"頁")
    print("======================")
    meger = []
    for job in soup.find_all("article",class_="b-block--top-bord job-list-item b-clearfix js-job-item"):
        date = job.h2.span.text
        workname = job.a.text        
        internet = "http:"+job.a['href']        
        company = job.ul.a.text.strip()        
        location = job.select("ul")[1].li.text
        human = job.find("a",class_="b-link--gray gtm-list-apply").text
        people = ""
        for char_human in human:
            if char_human =="~" or char_human.isdigit():
                people += char_human
        print(human)        
        if "~" in people:
            low_people = people[:people.find("~")]
            high_people = people[people.find("~")+1:]
        else :
            low_people = people
            high_people = people
        low_people =int(low_people)
        high_people= int(high_people)
        
        
        if job.find('div',class_="job-list-tag b-content").select("span")!=[] and job.find('div',class_="job-list-tag b-content").span.text=="待遇面議":
            salary = job.find('div',class_="job-list-tag b-content").span.text
            print(salary)
            bouns = ""
            low_price = ""
            high_price = ""
        else :
            salary = job.find('div',class_="job-list-tag b-content").a.text
#             print(salary)

            bouns = salary[:2]
            salary1 = ""
            for char in salary:
                if char == "~" or char.isdigit():
                    salary1 += char 
            print (bouns)
            if "~" in salary1:
                low_price = salary1[:salary1.find("~")]
                high_price = salary1[salary1.find("~")+1:]
            else :
                low_price = salary1
                high_price = salary1
            low_price =int(low_price)
            high_price= int(high_price)

        print(date)    
        print(workname)
        print(internet)
        print(company)
        print(location)
        print(human)
        print("--------------------------------------------------------------------")
        ws.append([date,workname,internet,company,location,salary,bouns,low_price,high_price,human,low_people,high_people])
        
    page += 1 
    url = "https://www.104.com.tw/jobs/search/?ro=0&kwop=7&keyword=%E5%A4%A7%E6%95%B8%E6%93%9A&expansionType=area%2Cspec%2Ccom%2Cjob%2Cwf%2Cwktm&order=14&asc=0&page="+str(page)+"&mode=s&jobsource=2018indexpoc&langFlag=0&langStatus=0&recommendJob=1&hotJob=1"
    res = requests.get(url)
    soup = BeautifulSoup(res.text,"lxml")
    sleep(2)
    wb.save("104人力銀行"+str(datetime.date.today())+"1.xlsx")
# Out:
# ======================
# 現在正在讀取第 1 頁
# ======================
# 6~10人應徵
# 月薪
# 8/02
# 研究員、大數據應用專員
# http://www.104.com.tw/job/7pvry?jobsource=jolist_b_relevance
# 卓越國際大數據股份有限公司
# 台北市中山區
# 6~10人應徵
# --------------------------------------------------------------------
# 0~5人應徵
# 待遇面議
# 7/14
# 大數據產品實施/系統工程師
# http://www.104.com.tw/job/6sw4i?jobsource=jolist_b_relevance
# 台北神策諮詢顧問有限公司
# 台北市中山區
# 0~5人應徵
# --------------------------------------------------------------------
# 11~30人應徵
# 待遇面議
# 7/21
# 大數據分析
# http://www.104.com.tw/job/7qr2q?jobsource=jolist_b_relevance
# 杏豐實業股份有限公司
# 新北市三重區
# 11~30人應徵
# --------------------------------------------------------------------
# 6~10人應徵
# 月薪
# 6/30
# 大數據分析人員
# http://www.104.com.tw/job/6zvlo?jobsource=jolist_b_relevance
# 博揚機械有限公司
# 新北市樹林區
# 6~10人應徵
# --------------------------------------------------------------------
# 11~30人應徵
# 月薪
# 7/25
# 大數據部門數據工程師
# http://www.104.com.tw/job/7763m?jobsource=jolist_b_relevance
# 典通股份有限公司
# 台北市中正區
# 11~30人應徵
# --------------------------------------------------------------------
# 6~10人應徵
# 月薪
# 8/02
# [DI] 大數據 工程師
# http://www.104.com.tw/job/4jnp8?jobsource=jolist_b_relevance
# 動力安全資訊股份有限公司
# 台北市內湖區
# 6~10人應徵
# --------------------------------------------------------------------
# 11~30人應徵
# 月薪
# 7/25
# 大數據部門商業分析師
# http://www.104.com.tw/job/7k72g?jobsource=jolist_b_relevance
# 典通股份有限公司
# 台北市中正區
# 11~30人應徵
# --------------------------------------------------------------------
# 0~5人應徵
# 月薪
# 7/05
# 專任研究助理(熟SAS健保/大數據分析)
# http://www.104.com.tw/job/7p3ir?jobsource=jolist_b_relevance
# 國立台灣大學醫學院附設醫院新竹台大分院新竹醫院_急診醫學部
# 新竹市
# 0~5人應徵
# --------------------------------------------------------------------
# 0~5人應徵
# 待遇面議
# 8/07
# 【智慧製造發展中心】大數據平台開發工程師/顧問 (南科育成中心)
# http://www.104.com.tw/job/7ycnq?jobsource=jolist_b_relevance
# 台灣恩悌悌數據股份有限公司
# 台南市新市區
# 0~5人應徵
# --------------------------------------------------------------------
# 11~30人應徵
# 月薪
# 7/25
# 大數據部門研究員
# http://www.104.com.tw/job/7k69c?jobsource=jolist_b_relevance
# 典通股份有限公司
# 台北市中正區
# 11~30人應徵
# --------------------------------------------------------------------
# 11~30人應徵
# 月薪
# 8/02
# 【研究發展處】大數據資料處理工程師
# http://www.104.com.tw/job/7bdre?jobsource=jolist_b_relevance
# 現觀科技股份有限公司
# 台北市中山區
# 11~30人應徵
# --------------------------------------------------------------------
# 6~10人應徵
# 待遇面議
# 8/01
# 大數據工程師(23053101)
# http://www.104.com.tw/job/80fuf?jobsource=jolist_b_relevance
# 叡揚資訊股份有限公司
# 台北市中山區
# 6~10人應徵
# --------------------------------------------------------------------
# 0~5人應徵
# 待遇面議
# 8/07
# 【智慧製造發展中心】大數據平台開發工程師/顧問 (高雄)
# http://www.104.com.tw/job/7ycnv?jobsource=jolist_b_relevance
# 台灣恩悌悌數據股份有限公司
# 高雄市鼓山區
# 0~5人應徵
# --------------------------------------------------------------------
# 0~5人應徵
# 月薪
# 8/01
# 人工智慧及大數據工程師
# http://www.104.com.tw/job/5qcze?jobsource=jolist_b_relevance
# 髮拉儷皮膚科診所
# 台北市信義區
# 0~5人應徵
# --------------------------------------------------------------------
# 0~5人應徵
# 待遇面議
# 5/27
# 大數據產品交付諮詢顧問
# http://www.104.com.tw/job/6sxgk?jobsource=jolist_b_relevance
# 台北神策諮詢顧問有限公司
# 台北市中山區
# 0~5人應徵
# --------------------------------------------------------------------
# 11~30人應徵
# 待遇面議
# 6/10
# 大數據產品AI演算法工程師
# http://www.104.com.tw/job/80ek5?jobsource=jolist_b_relevance
# 台北神策諮詢顧問有限公司
# 台北市中山區
# 11~30人應徵
# --------------------------------------------------------------------
# 0~5人應徵
# 待遇面議
# 8/02
# 大數據架構師
# http://www.104.com.tw/job/80ohc?jobsource=jolist_b_relevance
# 奕特資訊有限公司
# 台北市內湖區
# 0~5人應徵
# --------------------------------------------------------------------
# 6~10人應徵
# 時薪
# 8/01
# 大數據分析實習生 (Healthcare Data Analyst Intern)
# http://www.104.com.tw/job/7x939?jobsource=jolist_b_relevance
# 群健科技股份有限公司
# 台北市中山區
# 6~10人應徵
# --------------------------------------------------------------------
# 6~10人應徵
# 月薪
# 7/31
# (大數據)零售研究員/資深研究員
# http://www.104.com.tw/job/3o5cn?jobsource=jolist_b_relevance
# 東方線上股份有限公司
# 台北市大安區
# 6~10人應徵
# --------------------------------------------------------------------
# 6~10人應徵
# 待遇面議
# 7/28
# 產品管理師
# http://www.104.com.tw/job/7jcix?jobsource=jolist_b_relevance
# 大數據股份有限公司
# 台北市中山區
# 6~10人應徵
# --------------------------------------------------------------------
# ======================
# 現在正在讀取第 2 頁
# ======================
# 11~30人應徵
# 年薪
# 8/04
# 量化與金融大數據工程師
# http://www.104.com.tw/job/6vt43?jobsource=jolist_d_relevance
# 大拇哥證券投資顧問股份有限公司
# 台北市大安區
# 11~30人應徵
# --------------------------------------------------------------------
# 11~30人應徵
# 時薪
# 7/28
# 數據分析工讀生 / Data Analysis Intern
# http://www.104.com.tw/job/636rg?jobsource=jolist_d_relevance
# 大數據股份有限公司
# 台北市中山區
# 11~30人應徵
# --------------------------------------------------------------------
# 0~5人應徵
# 待遇面議
# 7/08
# PLC / SCADA / 大數據及AI應用  規劃工程師 & 儲備主管 (待派，中區或雲嘉地區)
# http://www.104.com.tw/job/6o4gl?jobsource=jolist_d_relevance
# 穎杰科技股份有限公司
# 雲林縣虎尾鎮
# 0~5人應徵
# --------------------------------------------------------------------
# 0~5人應徵
# 月薪
# 7/25
# 健康大數據部門 客戶成功管理師
# http://www.104.com.tw/job/7o0dh?jobsource=jolist_d_relevance
# 典通股份有限公司
# 台北市中正區
# 0~5人應徵
# --------------------------------------------------------------------
# 6~10人應徵
# 月薪
# 7/25
# 大數據部門數據應用規劃師
# http://www.104.com.tw/job/75p77?jobsource=jolist_d_relevance
# 典通股份有限公司
# 台北市中正區
# 6~10人應徵
# --------------------------------------------------------------------
# 11~30人應徵
# 待遇面議
# 8/01
# I3911 大數據分析師/資料科學家
# http://www.104.com.tw/job/7rkal?jobsource=jolist_d_relevance
# 遠傳電信股份有限公司
# 台北市內湖區
# 11~30人應徵
# --------------------------------------------------------------------
# 0~5人應徵
# 月薪
# 8/01
# I193 大數據分析工程師(可遠端工作)
# http://www.104.com.tw/job/7ndix?jobsource=jolist_d_relevance
# 台灣大哥大股份有限公司
# 台北市大安區
# 0~5人應徵
# --------------------------------------------------------------------
# 0~5人應徵
# 待遇面議
# 8/07
# 10R0-大數據中心 系統工程師
# http://www.104.com.tw/job/7ancv?jobsource=jolist_d_relevance
# 中國醫藥大學附設醫院
# 台中市北區
# 0~5人應徵
# --------------------------------------------------------------------
# 6~10人應徵
# 待遇面議
# 8/07
# 資訊類-BI大數據分析主管
# http://www.104.com.tw/job/7l1e6?jobsource=jolist_d_relevance
# 威剛科技股份有限公司
# 新北市中和區
# 6~10人應徵
# --------------------------------------------------------------------
# 11~30人應徵
# 待遇面議
# 8/04
# 【資訊】大數據分析人員
# http://www.104.com.tw/job/6la7u?jobsource=jolist_d_relevance
# 群益金鼎證券股份有限公司
# 台北市松山區
# 11~30人應徵
# --------------------------------------------------------------------
# 0~5人應徵
# 待遇面議
# 8/01
# 【資訊工程類】大數據架構工程師 (山鶯廠區)
# http://www.104.com.tw/job/82km8?jobsource=jolist_d_relevance
# 欣興電子股份有限公司
# 桃園市龜山區
# 0~5人應徵
# --------------------------------------------------------------------
# 0~5人應徵
# 月薪
# 7/31
# 國衛院「生醫大數據資料分析」研究助理
# http://www.104.com.tw/job/6zkvc?jobsource=jolist_d_relevance
# 財團法人國家衛生研究院
# 苗栗縣竹南鎮
# 0~5人應徵
# --------------------------------------------------------------------
# 0~5人應徵
# 待遇面議
# 8/02
# 資訊安全分析師 (大數據平台 Splunk 應用 )
# http://www.104.com.tw/job/6iubm?jobsource=jolist_d_relevance
# 數聯資安股份有限公司
# 台北市內湖區
# 0~5人應徵
# --------------------------------------------------------------------
# 0~5人應徵
# 月薪
# 8/07
# 10R0-大數據中心 程式設計師
# http://www.104.com.tw/job/7x2qr?jobsource=jolist_d_relevance
# 中國醫藥大學附設醫院
# 台中市北區
# 0~5人應徵
# --------------------------------------------------------------------
# 0~5人應徵
# 待遇面議
# 8/01
# [TW AD] Full Stack Engineer(Advertising)
# http://www.104.com.tw/job/810pg?jobsource=jolist_d_relevance
# 威朋大數據股份有限公司
# 台北市松山區
# 0~5人應徵
# --------------------------------------------------------------------
# 0~5人應徵
# 月薪
# 8/02
# 口碑大數據研發助理
# http://www.104.com.tw/job/791i2?jobsource=jolist_d_relevance
# 亞洲指標數位行銷顧問股份有限公司
# 台北市松山區
# 0~5人應徵
# --------------------------------------------------------------------
# 0~5人應徵
# 待遇面議
# 8/01
# 大數據專案管理師(大園廠)
# http://www.104.com.tw/job/7stw6?jobsource=jolist_d_relevance
# 成運汽車製造股份有限公司
# 桃園市大園區
# 0~5人應徵
# --------------------------------------------------------------------
# 11~30人應徵
# 待遇面議
# 7/28
# 後端工程師 / Back-End Developer
# http://www.104.com.tw/job/7gfvm?jobsource=jolist_d_relevance
# 大數據股份有限公司
# 台北市中山區
# 11~30人應徵
# --------------------------------------------------------------------
# 11~30人應徵
# 待遇面議
# 7/28
# 前端工程師 / Front-End Developer
# http://www.104.com.tw/job/7g9dq?jobsource=jolist_d_relevance
# 大數據股份有限公司
# 台北市中山區
# 11~30人應徵
# --------------------------------------------------------------------
# 6~10人應徵
# 月薪
# 8/02
# 大數據丶AI軟體工程師
# http://www.104.com.tw/job/4gi8f?jobsource=jolist_d_relevance
# 新夥伴科技股份有限公司
# 台中市西區
# 6~10人應徵
# --------------------------------------------------------------------
# ======================
# 現在正在讀取第 3 頁
# ======================
# 0~5人應徵
# 時薪
# 7/28
# 業務部行銷實習生
# http://www.104.com.tw/job/6nspq?jobsource=jolist_d_relevance
# 大數據股份有限公司
# 台北市中山區
# 0~5人應徵
# --------------------------------------------------------------------
# 11~30人應徵
# 待遇面議
# 8/04
# 大數據分析師
# http://www.104.com.tw/job/337bp?jobsource=jolist_d_relevance
# TutorABC_麥奇數位股份有限公司
# 台北市中正區
# 11~30人應徵
# --------------------------------------------------------------------
# 0~5人應徵
# 待遇面議
# 8/03
# 大數據及雲端處級主管
# http://www.104.com.tw/job/7zqxf?jobsource=jolist_d_relevance
# 長佳智能股份有限公司
# 台中市西區
# 0~5人應徵
# --------------------------------------------------------------------
# 0~5人應徵
# 待遇面議
# 8/03
# 【大數據】生資研發研究員/副研究員
# http://www.104.com.tw/job/7y37u?jobsource=jolist_d_relevance
# 華聯生物科技股份有限公司
# 新竹縣竹北市
# 0~5人應徵
# --------------------------------------------------------------------
# 11~30人應徵
# 待遇面議
# 8/07
# 大數據分析師
# http://www.104.com.tw/job/7ykod?jobsource=jolist_d_relevance
# 中嘉數位股份有限公司
# 台北市內湖區
# 11~30人應徵
# --------------------------------------------------------------------
# 6~10人應徵
# 待遇面議
# 8/01
# 風險管理處-大數據應用分析人員
# http://www.104.com.tw/job/74xku?jobsource=jolist_d_relevance
# 永豐商業銀行股份有限公司
# 台北市中山區
# 6~10人應徵
# --------------------------------------------------------------------
# 0~5人應徵
# 月薪
# 8/07
# 儀科中心-生醫平台與育成組-誠徵計畫專任人員碩士級1名(健康大數據)(聘期至113年04月30日)
# http://www.104.com.tw/job/7ztd9?jobsource=jolist_d_relevance
# 財團法人國家實驗研究院
# 新竹縣竹北市
# 0~5人應徵
# --------------------------------------------------------------------
# 0~5人應徵
# 待遇面議
# 8/02
# 資安工程師 (SOC L3大數據資料分析師)
# http://www.104.com.tw/job/7mlzl?jobsource=jolist_d_relevance
# 數聯資安股份有限公司
# 台北市內湖區
# 0~5人應徵
# --------------------------------------------------------------------
# 0~5人應徵
# 月薪
# 7/31
# 博士學位高薪實習計畫:大數據與系統模擬工業應整合研發人才(台中辦公室)
# http://www.104.com.tw/job/6riew?jobsource=jolist_d_relevance
# 皮托科技股份有限公司
# 台中市南屯區
# 0~5人應徵
# --------------------------------------------------------------------
# 6~10人應徵
# 月薪
# 8/01
# MyGo 國際地產 -中部土地開發/海外房地產業務(保障底薪+高抽成+提供大數據找地！)(台中擴編)
# http://www.104.com.tw/job/7rqfa?jobsource=jolist_d_relevance
# MyGo商學苑_平安房屋仲介股份有限公司
# 台中市南屯區
# 6~10人應徵
# --------------------------------------------------------------------
# 11~30人應徵
# 待遇面議
# 8/02
# 量化策略與金融大數據工程師
# http://www.104.com.tw/job/7mnu3?jobsource=jolist_d_relevance
# 沛然資訊有限公司
# 台北市內湖區
# 11~30人應徵
# --------------------------------------------------------------------
# 11~30人應徵
# 月薪
# 8/07
# 【工業4.0／智慧製造】智能大數據整合工程師 (Python)
# http://www.104.com.tw/job/77jj5?jobsource=jolist_d_relevance
# 欣興電子股份有限公司
# 桃園市龜山區
# 11~30人應徵
# --------------------------------------------------------------------
# 0~5人應徵
# 月薪
# 7/28
# 數位廣告優化師
# http://www.104.com.tw/job/809rx?jobsource=jolist_d_relevance
# 大數據股份有限公司
# 台北市中山區
# 0~5人應徵
# --------------------------------------------------------------------
# 0~5人應徵
# 月薪
# 8/03
# 大數據工程師
# http://www.104.com.tw/job/7ss2l?jobsource=jolist_d_relevance
# フューテック株式会社
# 日本
# 0~5人應徵
# --------------------------------------------------------------------
# 0~5人應徵
# 待遇面議
# 7/31
# 【資訊類】大數據資料平台工程師 (桃園廠)
# http://www.104.com.tw/job/82jtv?jobsource=jolist_d_relevance
# 景碩科技股份有限公司
# 桃園市新屋區
# 0~5人應徵
# --------------------------------------------------------------------
# 0~5人應徵
# 月薪
# 8/04
# 投資大數據產品業務助理
# http://www.104.com.tw/job/82fq2?jobsource=jolist_d_relevance
# 沛然資訊有限公司
# 台北市內湖區
# 0~5人應徵
# --------------------------------------------------------------------
# 11~30人應徵
# 年薪
# 8/07
# AI大數據分析師
# http://www.104.com.tw/job/6nnhm?jobsource=jolist_d_relevance
# 網際威信股份有限公司
# 台北市內湖區
# 11~30人應徵
# --------------------------------------------------------------------
# 0~5人應徵
# 月薪
# 8/07
# 10R0-大數據中心 生物統計師(biostatistician)
# http://www.104.com.tw/job/4lwfh?jobsource=jolist_d_relevance
# 中國醫藥大學附設醫院
# 台中市北區
# 0~5人應徵
# --------------------------------------------------------------------
# 6~10人應徵
# 待遇面議
# 7/28
# AI策略發展及商務主管
# http://www.104.com.tw/job/809rl?jobsource=jolist_d_relevance
# 大數據股份有限公司
# 台北市中山區
# 6~10人應徵
# --------------------------------------------------------------------
# 6~10人應徵
# 月薪
# 8/04
# 【大數據分析工程師】分析萬事萬物！加入台中矽谷
# http://www.104.com.tw/job/5a5et?jobsource=jolist_d_relevance
# 皮克網路有限公司
# 台中市豐原區
# 6~10人應徵
# --------------------------------------------------------------------
# ======================
# 現在正在讀取第 4 頁
# ======================
# 11~30人應徵
# 月薪
# 5/03
# 大數據分析暨人工智慧開發工程師-智慧交通領域(IAD20)
# http://www.104.com.tw/job/79we1?jobsource=jolist_a_relevance
# 資拓宏宇國際股份有限公司
# 新北市板橋區
# 11~30人應徵
# --------------------------------------------------------------------
# 6~10人應徵
# 時薪
# 8/06
# 【學生實習】大數據分析/量化分析實習生
# http://www.104.com.tw/job/7teta?jobsource=jolist_a_relevance
# 台灣經濟新報文化事業股份有限公司
# 台北市信義區
# 6~10人應徵
# --------------------------------------------------------------------
# 6~10人應徵
# 時薪
# 7/28
# 視覺設計實習/工讀生
# http://www.104.com.tw/job/827gi?jobsource=jolist_a_relevance
# 大數據股份有限公司
# 台北市中山區
# 6~10人應徵
# --------------------------------------------------------------------
# 11~30人應徵
# 月薪
# 8/04
# 【大數據科技教育產業】教育顧問(台北)
# http://www.104.com.tw/job/6cncs?jobsource=jolist_a_relevance
# TutorABC_麥奇數位股份有限公司
# 台北市中正區
# 11~30人應徵
# --------------------------------------------------------------------
# 11~30人應徵
# 待遇面議
# 8/02
# 新聞部大數據中心數據分析師
# http://www.104.com.tw/job/7zdou?jobsource=jolist_a_relevance
# 中天電視股份有限公司
# 台北市內湖區
# 11~30人應徵
# --------------------------------------------------------------------
# 11~30人應徵
# 月薪
# 8/04
# 電商網拍包貨員 包貨理貨出貨員 包裝員
# http://www.104.com.tw/job/7ihqc?jobsource=jolist_a_relevance
# 台米大數據有限公司
# 桃園市八德區
# 11~30人應徵
# --------------------------------------------------------------------
# 0~5人應徵
# 月薪
# 7/31
# 國衛院「精準健康大數據」計畫博士後研究員
# http://www.104.com.tw/job/740bm?jobsource=jolist_a_relevance
# 財團法人國家衛生研究院
# 苗栗縣竹南鎮
# 0~5人應徵
# --------------------------------------------------------------------
# 大於30人應徵
# 月薪
# 7/27
# 大數據分析人員
# http://www.104.com.tw/job/7vw84?jobsource=jolist_a_relevance
# 華南商業銀行股份有限公司
# 台北市信義區
# 大於30人應徵
# --------------------------------------------------------------------
# 6~10人應徵
# 月薪
# 8/01
# MyGo 國際地產 -土地開發/海外房地產業務(保障底薪+高抽成+提供大數據找地！)(高雄擴編)
# http://www.104.com.tw/job/815z5?jobsource=jolist_a_relevance
# MyGo商學苑_平安房屋仲介股份有限公司
# 高雄市三民區
# 6~10人應徵
# --------------------------------------------------------------------
# 0~5人應徵
# 待遇面議
# 8/04
# 商業智慧顧問 （消費大數據分析）
# http://www.104.com.tw/job/7p7dj?jobsource=jolist_a_relevance
# 歐易亞科技股份有限公司
# 台北市中正區
# 0~5人應徵
# --------------------------------------------------------------------
# 11~30人應徵
# 月薪
# 8/01
# 數據師、大數據分析師(臺北市信義區)
# http://www.104.com.tw/job/7cfoj?jobsource=jolist_a_relevance
# 鼎漢國際工程顧問股份有限公司
# 台北市信義區
# 11~30人應徵
# --------------------------------------------------------------------
# 6~10人應徵
# 待遇面議
# 5/23
# 大數據架構(K8s/Kubernetes)工程師0609
# http://www.104.com.tw/job/7lmsn?jobsource=jolist_a_relevance
# Phison Electronics Corp_群聯電子股份有限公司
# 苗栗縣竹南鎮
# 6~10人應徵
# --------------------------------------------------------------------
# 0~5人應徵
# 待遇面議
# 8/02
# 雲端工程師(大數據平台Splunk析)
# http://www.104.com.tw/job/7t3ig?jobsource=jolist_a_relevance
# 數聯資安股份有限公司
# 台北市內湖區
# 0~5人應徵
# --------------------------------------------------------------------
# 6~10人應徵
# 時薪
# 7/28
# 影音剪輯工讀生 (長期工讀)
# http://www.104.com.tw/job/6uu0k?jobsource=jolist_a_relevance
# 大數據股份有限公司
# 台北市中山區
# 6~10人應徵
# --------------------------------------------------------------------
# 6~10人應徵
# 時薪
# 8/06
# 【學生實習】大數據分析/資料科學分析實習生
# http://www.104.com.tw/job/7qacf?jobsource=jolist_a_relevance
# 台灣經濟新報文化事業股份有限公司
# 台北市信義區
# 6~10人應徵
# --------------------------------------------------------------------
# 0~5人應徵
# 月薪
# 7/31
# [大數據股市掘金系統] 專案工程師/助理工程師
# http://www.104.com.tw/job/7512l?jobsource=jolist_a_relevance
# 全富數位有限公司
# 台中市北區
# 0~5人應徵
# --------------------------------------------------------------------
# 6~10人應徵
# 月薪
# 7/31
# 資料工程師
# http://www.104.com.tw/job/747q3?jobsource=jolist_a_relevance
# 紫式大數據決策股份有限公司
# 新竹市
# 6~10人應徵
# --------------------------------------------------------------------
# 0~5人應徵
# 月薪
# 7/31
# 國家衛生研究院健康大數據永續平台計畫(TCOG派駐台北榮總)臨床研究護理師(Study Coordinator, SC)
# http://www.104.com.tw/job/7xdk4?jobsource=jolist_a_relevance
# 財團法人國家衛生研究院
# 台北市北投區
# 0~5人應徵
# --------------------------------------------------------------------
# 0~5人應徵
# 待遇面議
# 7/28
# 健康大數據部門 客戶成功經理
# http://www.104.com.tw/job/7vvlv?jobsource=jolist_a_relevance
# 典通股份有限公司
# 台北市中正區
# 0~5人應徵
# --------------------------------------------------------------------
# 0~5人應徵
# 待遇面議
# 8/01
# 大數據平台應用工程師(.net)
# http://www.104.com.tw/job/7vqwm?jobsource=jolist_a_relevance
# 華新麗華股份有限公司
# 台北市信義區
# 0~5人應徵
# --------------------------------------------------------------------
