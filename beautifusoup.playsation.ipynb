# %%
# 目的分析從舊遊戲到新遊戲的銷售情況分析出大眾玩家在購買的時間區間,購買的價格,
# 購買的種類類型,判斷就遊戲在退流行時候的定價,以及剛上市的定價會不會因為遊戲的ＧＢ容量大小影響
# 回傳年份(點進去可以看到他的發行日),回傳價格(定價),回傳購買人氣（最暢銷亦或是下載最多次數),
# 回傳遊戲種類(冒險類還是戰略類型),回傳購買年齡(如果有就用沒有就算了),回傳需要的最建議遊戲配備（ps4 or ps5)
# https://store.playstation.com/zh-hant-tw/category/05a2d027-cedc-4ac0-abeb-8fc26fec7180/1?ACTION=productGenres&ADVENTURE=productGenres&ROLE_PLAYING_GAMES=productGenres

# %%
from bs4 import BeautifulSoup
import requests  #引入外部

url = "https://store.playstation.com/zh-hant-tw/pages/browse"

res = requests.get(url)
# soup = BeautifulSoup(f.read(),"html")
soup = BeautifulSoup(res.text,"lxml")
# soup
class_1="psw-l-w-1/2@mobile-s psw-l-w-1/2@mobile-l psw-l-w-1/6@tablet-l psw-l-w-1/4@tablet-s psw-l-w-1/6@laptop psw-l-w-1/8@desktop psw-l-w-1/8@max"
jobs = soup.find_all("li",class_=class_1)
# ("span")[3].text
for job in jobs :
    print(job("span")[3].text)
# print(jobs)

# games()

# %%
from bs4 import BeautifulSoup
import requests  #引入外部
import json

base_url = "https://store.playstation.com/zh-hant-tw/category/5f3aa730-1c8e-4a18-84da-030bb91558c0/2"
page_numbers=list(range(1,11))
for page_number in page_numbers:
    url = base_url+str(page_number)
    res = requests.get(url)
    # soup = BeautifulSoup(f.read(),"html")
    soup = BeautifulSoup(res.text,"lxml")
    # soup
    class_1="psw-l-w-1/2@mobile-s psw-l-w-1/2@mobile-l psw-l-w-1/6@tablet-l psw-l-w-1/4@tablet-s psw-l-w-1/6@laptop psw-l-w-1/8@desktop psw-l-w-1/8@max"
    jobs = soup.find_all("li",class_=class_1)
    # print(jobs)
    for job in jobs:
        if jobs != []:
            data_telemetry_meta = job.find("a").get("data-telemetry-meta")
            meta_data = json.loads(data_telemetry_meta)
        #     print(data_telemetry_meta)
    #         print(meta_data)
            product_name = meta_data['name']
            product_price = meta_data['price']
            print("Product Name:", product_name)
            print("Product Price:", product_price)
            print("----------------------------------------------------------------------------")
        else:
            print("end")
# Out:
# Product Name: Under the Jolly Roger - Deluxe DLC Bundle (簡體中文, 英文, 日文)
# Product Price: NT$590
# ----------------------------------------------------------------------------
# Product Name: Arcade Archives DON DOKO DON (英文, 日文)
# Product Price: NT$277
# ----------------------------------------------------------------------------
# Product Name: 歧路旅人 II PS4＆PS5 (簡體中文, 韓文, 英文, 繁體中文, 日文)
# Product Price: NT$1,342
# ----------------------------------------------------------------------------
# Product Name: Under the Jolly Roger - DLC Bundle (追加內容)
# Product Price: NT$490
# ----------------------------------------------------------------------------
# Product Name: CANNON ARMY (英文)
# Product Price: NT$60
# ----------------------------------------------------------------------------
# Product Name: 《聖騎士》賽季 6 PlayStation®Plus 同捆包 (英文)
# Product Price: NT$0
# ----------------------------------------------------------------------------
# Product Name: Blood Bowl 3 - Deluxe Black Orcs Edition (簡體中文, 韓文, 英文, 繁體中文, 日文)
# Product Price: NT$1,390
# ----------------------------------------------------------------------------
# Product Name: Blood Bowl 3 - Brutal Edition (簡體中文, 韓文, 英文, 繁體中文, 日文)
# Product Price: NT$1,490
# ----------------------------------------------------------------------------
# Product Name: Blood Bowl 3 - Deluxe Imperial Nobility (簡體中文, 韓文, 英文, 繁體中文, 日文)
# Product Price: NT$1,390
# ----------------------------------------------------------------------------
# Product Name: Chef Life - Al Forno Edition (簡體中文, 韓文, 英文, 繁體中文, 日文)
# Product Price: NT$1,043
# ----------------------------------------------------------------------------
# Product Name: Raiden III × MIKADO MANIAX (英文, 日文)
# Product Price: NT$890
# ----------------------------------------------------------------------------
# Product Name: Raiden IV × MIKADO remix (英文, 日文)
# Product Price: NT$890
# ----------------------------------------------------------------------------
# Product Name: Ship Graveyard Simulator (簡體中文, 韓文, 英文, 繁體中文, 日文)
# Product Price: NT$490
# ----------------------------------------------------------------------------
# Product Name: Chef Life - A Restaurant Simulator (簡體中文, 韓文, 英文, 繁體中文, 日文)
# Product Price: NT$1,190
# ----------------------------------------------------------------------------
# Product Name: 少女魔淨 (簡體中文, 韓文, 英文, 繁體中文, 日文)
# Product Price: NT$930
# ----------------------------------------------------------------------------
# Product Name: Naught (簡體中文, 韓文, 英文, 繁體中文, 日文)
# Product Price: NT$490
# ----------------------------------------------------------------------------
# Product Name: Pizza Tycoon (簡體中文, 英文, 繁體中文, 日文)
# Product Price: NT$490
# ----------------------------------------------------------------------------
# Product Name: Akka Arrh (英文)
# Product Price: NT$590
# ----------------------------------------------------------------------------
# Product Name: Cave Digger 2 : Dig Harder (簡體中文, 韓文, 英文, 繁體中文, 日文)
# Product Price: NT$790
# ----------------------------------------------------------------------------
# Product Name: Pocket Academy ZERO (簡體中文, 韓文, 英文, 繁體中文, 日文)
# Product Price: NT$315
# ----------------------------------------------------------------------------
# Product Name: 拼圖巡遊 (韓文, 英文, 日文)
# Product Price: NT$590
# ----------------------------------------------------------------------------
# Product Name: Startenders: 星際酒保 (韓文, 英文, 日文)
# Product Price: NT$343
# ----------------------------------------------------------------------------
# Product Name: The Tale of Onogoro (簡體中文, 韓文, 英文, 日文)
# Product Price: NT$872
# ----------------------------------------------------------------------------
# Product Name: The Tale of Onogoro Soundtrack Edition (簡體中文, 韓文, 英文, 日文)
# Product Price: NT$1,190
# ----------------------------------------------------------------------------
# Product Name: Twice Reborn: A Vampire Visual Novel PS4™ & PS5™ (簡體中文, 韓文, 英文)
# Product Price: NT$490
# ----------------------------------------------------------------------------
# Product Name: Vacation Simulator PS4 & PS5 (韓文, 英文, 日文)
# Product Price: NT$890
# ----------------------------------------------------------------------------
# Product Name: 人中之龍 維新！ 極　PS4 & PS5 (簡體中文, 韓文, 英文, 繁體中文, 日文)
# Product Price: NT$1,590
# ----------------------------------------------------------------------------
# Product Name: After the Fall® - Deluxe Edition (簡體中文, 韓文, 英文, 日文)
# Product Price: NT$1,190
# ----------------------------------------------------------------------------
# Product Name: Kizuna AI - Touch the Beat! (簡體中文, 韓文, 英文, 繁體中文, 日文)
# Product Price: NT$1,090
# ----------------------------------------------------------------------------
# Product Name: Job Simulator PS4 & PS5 (英文)
# Product Price: NT$590
# ----------------------------------------------------------------------------
# Product Name: Thumper PS4 & PS5 (簡體中文, 韓文, 英文, 繁體中文, 日文)
# Product Price: NT$590
# ----------------------------------------------------------------------------
# Product Name: Remoteness (簡體中文, 韓文, 英文, 繁體中文, 日文)
# Product Price: NT$790
# ----------------------------------------------------------------------------
# Product Name: Wild Arms 2 (英文)
# Product Price: NT$300
# ----------------------------------------------------------------------------
# Product Name: The Legend of Dragoon (英文)
# Product Price: NT$300
# ----------------------------------------------------------------------------
# Product Name: Blood Bowl 3 (簡體中文, 韓文, 英文, 繁體中文, 日文)
# Product Price: NT$1,190
# ----------------------------------------------------------------------------
# Product Name: After the Fall® - Complete Edition (簡體中文, 韓文, 英文, 日文)
# Product Price: NT$890
# ----------------------------------------------------------------------------
# Product Name: Atomic Heart (PS4 & PS5) (簡體中文, 韓文, 英文, 繁體中文, 日文)
# Product Price: NT$2,090
# ----------------------------------------------------------------------------
# Product Name: Atomic Heart - Gold Edition (PS4 & PS5) (簡體中文, 韓文, 英文, 繁體中文, 日文)
# Product Price: NT$2,990
# ----------------------------------------------------------------------------
# Product Name: Atomic Heart - Premium Edition (PS4 & PS5) (簡體中文, 韓文, 英文, 繁體中文, 日文)
# Product Price: NT$3,290
# ----------------------------------------------------------------------------
# Product Name: 牧場物語 ～ハーベストムーン (日文)
# Product Price: NT$222
# ----------------------------------------------------------------------------
# Product Name: Seven Doors (簡體中文, 韓文, 英文, 繁體中文, 日文)
# Product Price: NT$150
# ----------------------------------------------------------------------------
# Product Name: 人中之龍 維新！ 極 數位豪華版　PS4 & PS5 (簡體中文, 韓文, 英文, 繁體中文, 日文)
# Product Price: NT$1,890
# ----------------------------------------------------------------------------
# Product Name: 多合一包　PS4 & PS5 (追加內容)
# Product Price: NT$390
# ----------------------------------------------------------------------------
# Product Name: Sudoku Master (英文)
# Product Price: NT$150
# ----------------------------------------------------------------------------
# Product Name: Shadow Warrior 3: Definitive Edition | PS4 & PS5 (簡體中文, 韓文, 英文, 繁體中文, 日文)
# Product Price: NT$476
# ----------------------------------------------------------------------------
# Product Name: Monster Hunter Rise DLC Pack 3 (追加內容)
# Product Price: NT$700
# ----------------------------------------------------------------------------
# Product Name: W.A.R.P. (英文, 日文)
# Product Price: NT$90
# ----------------------------------------------------------------------------
# Product Name: ONE PIECE 時光旅詩 珠寶禮盒 (追加內容)
# Product Price: NT$90
# ----------------------------------------------------------------------------
# Product Name: Arcade Archives GROBDA (英文, 日文)
# Product Price: NT$277
# ----------------------------------------------------------------------------
# Product Name: Heirs of the Kings (英文, 日文)
# Product Price: NT$474
# ----------------------------------------------------------------------------
# Product Name: THEATRHYTHM FINAL BAR LINE (簡體中文, 韓文, 英文, 繁體中文, 日文)
# Product Price: NT$1,490
# ----------------------------------------------------------------------------
# Product Name: THEATRHYTHM FINAL BAR LINE Digital Deluxe Edition (簡體中文, 韓文, 英文, 繁體中文, 日文)
# Product Price: NT$2,390
# ----------------------------------------------------------------------------
# Product Name: THEATRHYTHM FINAL BAR LINE Premium Digital Deluxe Edition (簡體中文, 韓文, 英文, 繁體中文, 日文)
# Product Price: NT$2,989
# ----------------------------------------------------------------------------
# Product Name: THEATRHYTHM FINAL BAR LINE Digital Deluxe Upgrade (遊戲)
# Product Price: NT$900
# ----------------------------------------------------------------------------
# Product Name: 交響傳奇 Remastered (韓文, 繁體中文)
# Product Price: NT$1,190
# ----------------------------------------------------------------------------
# Product Name: Cities: Skylines - Remastered (簡體中文, 韓文, 英文)
# Product Price: NT$1,190
# ----------------------------------------------------------------------------
# Product Name: Cities: Skylines - PlayStation®4 Edition (韓文, 英文)
# Product Price: 內含
# ----------------------------------------------------------------------------
# Product Name: Mermaidio 3 (英文)
# Product Price: NT$42
# ----------------------------------------------------------------------------
# Product Name: Pocket Witch PS4 & PS5 (簡體中文, 韓文, 英文, 繁體中文, 日文)
# Product Price: NT$150
# ----------------------------------------------------------------------------
# Product Name: 《狂野星球之旅》：最佳員工版 (簡體中文, 韓文, 英文, 繁體中文)
# Product Price: NT$987
# ----------------------------------------------------------------------------
# Product Name: Rocketio 3 (英文)
# Product Price: NT$42
# ----------------------------------------------------------------------------
# Product Name: 《霍格華茲的傳承》PS5 版 (簡體中文, 韓文, 英文, 繁體中文, 日文)
# Product Price: NT$1,672
# ----------------------------------------------------------------------------
# Product Name: DreadOut 2 (簡體中文, 英文, 繁體中文, 日文)
# Product Price: NT$590
# ----------------------------------------------------------------------------
# Product Name: 霍格華茲的傳承：數位豪華版 (簡體中文, 韓文, 英文, 繁體中文, 日文)
# Product Price: NT$2,510
# ----------------------------------------------------------------------------
# Product Name: WBSC eBASEBALL™: POWER PROS (英文, 日文)
# Product Price: NT$32
# ----------------------------------------------------------------------------
# Product Name: Arcade Archives MAGICAL SPEED (英文, 日文)
# Product Price: NT$277
# ----------------------------------------------------------------------------
# Product Name: Dungeon Village 2 (簡體中文, 韓文, 英文, 泰文, 繁體中文, 日文)
# Product Price: NT$473
# ----------------------------------------------------------------------------
# Product Name: Forest Camp Story (簡體中文, 韓文, 英文, 泰文, 繁體中文, 日文)
# Product Price: NT$473
# ----------------------------------------------------------------------------
# Product Name: Pocket Arcade Story (簡體中文, 韓文, 英文, 繁體中文, 日文)
# Product Price: NT$473
# ----------------------------------------------------------------------------
# Product Name: Through the Darkest of Times (簡體中文, 英文, 日文)
# Product Price: NT$490
# ----------------------------------------------------------------------------
# Product Name: 「SD GUNDAM 激鬥同盟」新手衝刺＆「SD鋼彈世界 三國創傑傳」包 (追加內容)
# Product Price: NT$180
# ----------------------------------------------------------------------------
# Product Name: Aces of the Luftwaffe - Squadron (日英文版)
# Product Price: NT$490
# ----------------------------------------------------------------------------
# Product Name: Aces of the Luftwaffe - Squadron Extended Edition (遊戲)
# Product Price: NT$790
# ----------------------------------------------------------------------------
# Product Name: El Hijo - A Wild West Tale (簡體中文, 韓文, 英文, 泰文, 繁體中文, 日文)
# Product Price: NT$590
# ----------------------------------------------------------------------------
# Product Name: Potion Permit (簡體中文, 韓文, 英文, 日文)
# Product Price: NT$590
# ----------------------------------------------------------------------------
# Product Name: Potion Permit DELUXE EDITION (簡體中文, 韓文, 英文, 日文)
# Product Price: NT$890
# ----------------------------------------------------------------------------
# Product Name: Potion Permit 冒險家禮包 (追加內容)
# Product Price: NT$150
# ----------------------------------------------------------------------------
# Product Name: Potion Permit 蒸汽朋克禮包 (追加內容)
# Product Price: NT$150
# ----------------------------------------------------------------------------
# Product Name: Rad Rodgers (中日英韓文版)
# Product Price: NT$590
# ----------------------------------------------------------------------------
# Product Name: Townsmen - A Kingdom Rebuilt (中日英文版)
# Product Price: NT$890
# ----------------------------------------------------------------------------
# Product Name: The Redress of Mira PS4 & PS5 (英文)
# Product Price: NT$300
# ----------------------------------------------------------------------------
# Product Name: SokoBunny (英文, 日文)
# Product Price: NT$150
# ----------------------------------------------------------------------------
# Product Name: Prison Tycoon™: Under New Management (英文)
# Product Price: NT$553
# ----------------------------------------------------------------------------
# Product Name: Cario 2 (英文)
# Product Price: NT$42
# ----------------------------------------------------------------------------
# Product Name: Void Bastards (簡體中文, 韓文, 英文, 日文)
# Product Price: NT$490
# ----------------------------------------------------------------------------
# Product Name: Void Bastards: DeLUXe Bundle (簡體中文, 韓文, 英文, 日文)
# Product Price: NT$790
# ----------------------------------------------------------------------------
# Product Name: 盜版代碼：管理員版 (簡體中文, 英文, 繁體中文, 日文)
# Product Price: NT$392
# ----------------------------------------------------------------------------
# Product Name: Resident Evil 7 Gold Edition & Village Gold Edition PS4 & PS5 (簡體中文, 韓文, 英文, 泰文, 繁體中文, 日文)
# Product Price: NT$1,230
# ----------------------------------------------------------------------------
# Product Name: Monster Hunter Rise DLC Pack 2 (追加內容)
# Product Price: NT$840
# ----------------------------------------------------------------------------
# Product Name: 新手支援組合包！（月光捲軸×10、忍術×10） (追加內容)
# Product Price: NT$150
# ----------------------------------------------------------------------------
# Product Name: Offroad Moto Bike (英文)
# Product Price: NT$60
# ----------------------------------------------------------------------------
# Product Name: 火星孤征 PS4 & PS5 (簡體中文, 韓文, 英文, 繁體中文, 日文)
# Product Price: NT$890
# ----------------------------------------------------------------------------
# Product Name: Arcade Archives PHELIOS (英文, 日文)
# Product Price: NT$277
# ----------------------------------------------------------------------------
# Product Name: Rhythm Sprout (簡體中文, 韓文, 英文, 日文)
# Product Price: NT$490
# ----------------------------------------------------------------------------
# Product Name: Rubber Bandits (簡體中文, 韓文, 英文, 繁體中文, 日文)
# Product Price: NT$300
# ----------------------------------------------------------------------------
# Product Name: Rubber Bandits: Animal Bandits Bundle (簡體中文, 韓文, 英文, 繁體中文, 日文)
# Product Price: NT$294
# ----------------------------------------------------------------------------
# Product Name: Rubber Bandits: Starter Bundle (簡體中文, 韓文, 英文, 繁體中文, 日文)
# Product Price: NT$180
# ----------------------------------------------------------------------------
# Product Name: Rubber Bandits: Supporter Bundle (簡體中文, 韓文, 英文, 繁體中文, 日文)
# Product Price: NT$474
# ----------------------------------------------------------------------------
# Product Name: Wonder Boy Anniversary Collection (英文, 日文)
# Product Price: NT$1,490
# ----------------------------------------------------------------------------
# Product Name: Puzzle Bobble™2X/BUST-A-MOVE™2 Arcade Edition & Puzzle Bobble™3/BUST-A-MOVE™3 S-Tribute (韓文, 英文, 繁體中文, 日文)
# Product Price: NT$490
# ----------------------------------------------------------------------------
# Product Name: Beveron (英文)
# Product Price: NT$42
# ----------------------------------------------------------------------------
# Product Name: SEASON: A letter to the future PS4 & PS5 (簡體中文, 英文, 繁體中文, 日文)
# Product Price: NT$890
# ----------------------------------------------------------------------------
# Product Name: Albacete Warrior PS4 & PS5 (英文)
# Product Price: NT$180
# ----------------------------------------------------------------------------
# Product Name: 海綿寶寶 : The Cosmic Shake (簡體中文, 韓文, 英文, 繁體中文, 日文)
# Product Price: NT$1,190
# ----------------------------------------------------------------------------
# Product Name: We Were Here Forever (簡體中文, 韓文, 英文, 泰文, 繁體中文, 日文)
# Product Price: NT$490
# ----------------------------------------------------------------------------
# Product Name: We Were Here Series Bundle (簡體中文, 韓文, 英文, 泰文, 繁體中文, 日文)
# Product Price: NT$890
# ----------------------------------------------------------------------------
# Product Name: Mermaidio 2 (英文)
# Product Price: NT$42
# ----------------------------------------------------------------------------
# Product Name: PowerWash Simulator (簡體中文, 韓文, 英文, 繁體中文, 日文)
# Product Price: NT$790
# ----------------------------------------------------------------------------
# Product Name: 撫摸蜘蛛 (英文)
# Product Price: NT$150
# ----------------------------------------------------------------------------
# Product Name: Astro & Suzy 去海邊 (英文)
# Product Price: NT$30
# ----------------------------------------------------------------------------
# Product Name: Bunny Factory (英文, 日文)
# Product Price: NT$300
# ----------------------------------------------------------------------------
# Product Name: Rocketio 2 (英文)
# Product Price: NT$42
# ----------------------------------------------------------------------------
# Product Name: Egg Runner (英文)
# Product Price: NT$60
# ----------------------------------------------------------------------------
# Product Name: HITMAN World of Assassination (簡體中文, 英文, 繁體中文)
# Product Price: NT$2,090
# ----------------------------------------------------------------------------
# Product Name: HITMAN World of Assassination (簡體中文, 英文, 繁體中文)
# Product Price: NT$2,090
# ----------------------------------------------------------------------------
# Product Name: Hyper Shapes (英文)
# Product Price: NT$150
# ----------------------------------------------------------------------------
# Product Name: Arcade Archives THE NEWZEALAND STORY (英文, 日文)
# Product Price: NT$277
# ----------------------------------------------------------------------------
# Product Name: Miracle Snack Shop (簡體中文, 韓文, 英文, 繁體中文, 日文)
# Product Price: NT$590
# ----------------------------------------------------------------------------
# Product Name: 《怪怪躲避球》 (簡體中文, 韓文, 英文, 繁體中文, 日文)
# Product Price: NT$600
# ----------------------------------------------------------------------------
# Product Name: The Dino R (英文)
# Product Price: NT$60
# ----------------------------------------------------------------------------
# Product Name: Ping Pong Peg (英文)
# Product Price: NT$300
# ----------------------------------------------------------------------------
# Product Name: Frogo 3 (英文)
# Product Price: NT$42
# ----------------------------------------------------------------------------
# Product Name: Risen (英文)
# Product Price: NT$890
# ----------------------------------------------------------------------------
# Product Name: Sissa's Path PS4 & PS5 (英文)
# Product Price: NT$150
# ----------------------------------------------------------------------------
# Product Name: 數碼寶貝 絕境求生 Extra Support Equipment Pack (追加內容)
# Product Price: NT$120
# ----------------------------------------------------------------------------
# Product Name: 數碼寶貝 絕境求生 Month 1 Bonus Pack (追加內容)
# Product Price: NT$120
# ----------------------------------------------------------------------------
# Product Name: Clunky Hero (簡體中文, 韓文, 英文, 繁體中文, 日文)
# Product Price: NT$490
# ----------------------------------------------------------------------------
# Product Name: The Zebra Z (英文)
# Product Price: NT$60
# ----------------------------------------------------------------------------
# Product Name: UNO® (簡體中文, 英文, 繁體中文)
# Product Price: 免費
# ----------------------------------------------------------------------------
# Product Name: Monster Hunter Rise PS4 & PS5 (簡體中文, 韓文, 英文, 繁體中文, 日文)
# Product Price: NT$1,120
# ----------------------------------------------------------------------------
# Product Name: Monster Hunter Rise Deluxe Edition PS4 & PS5 (簡體中文, 韓文, 英文, 繁體中文, 日文)
# Product Price: NT$1,400
# ----------------------------------------------------------------------------
# Product Name: Monster Hunter Rise Deluxe Kit (追加內容)
# Product Price: NT$420
# ----------------------------------------------------------------------------
# Product Name: Monster Hunter Rise DLC Pack 1 (追加內容)
# Product Price: NT$560
# ----------------------------------------------------------------------------
# Product Name: Monster Hunter Rise Extra DLC Pack (追加內容)
# Product Price: NT$560
# ----------------------------------------------------------------------------
# Product Name: 拿破崙少女 Episode.1 字典裏沒有不可能三個字的少女 (簡體中文, 英文, 繁體中文, 日文)
# Product Price: NT$590
# ----------------------------------------------------------------------------
# Product Name: 撫馬 (英文)
# Product Price: NT$150
# ----------------------------------------------------------------------------
# Product Name: The Dog Quiz (英文)
# Product Price: NT$60
# ----------------------------------------------------------------------------
# Product Name: A Matter of Principle (英文)
# Product Price: NT$150
# ----------------------------------------------------------------------------
# Product Name: There is a Genie in my Szechuan Sauce Remastered (英文)
# Product Price: NT$150
# ----------------------------------------------------------------------------
# Product Name: A Space for the Unbound (簡體中文, 韓文, 英文, 繁體中文, 日文)
# Product Price: NT$590
# ----------------------------------------------------------------------------
# Product Name: Arcade Archives TANK FORCE (英文, 日文)
# Product Price: NT$277
# ----------------------------------------------------------------------------
# Product Name: 女神異聞錄３ 攜帶版 (簡體中文, 韓文, 英文, 繁體中文, 日文)
# Product Price: NT$590
# ----------------------------------------------------------------------------
# Product Name: 女神異聞錄3 攜帶版&女神異聞錄4 黃金版 同捆包 (簡體中文, 韓文, 英文, 繁體中文, 日文)
# Product Price: NT$1,156
# ----------------------------------------------------------------------------
# Product Name: 女神異聞錄４ 黃金版 (簡體中文, 韓文, 英文, 繁體中文, 日文)
# Product Price: NT$590
# ----------------------------------------------------------------------------
# Product Name: 武器套組 (追加內容)
# Product Price: NT$172
# ----------------------------------------------------------------------------
# Product Name: 聖塔神記 TRINITY TRIGGER 終極版 (韓文, 繁體中文, 日文)
# Product Price: NT$3,015
# ----------------------------------------------------------------------------
# Product Name: 聖塔神記 TRINITY TRIGGER 豪華版 (韓文, 繁體中文, 日文)
# Product Price: NT$1,998
# ----------------------------------------------------------------------------
# Product Name: 追加劇情套組 (追加內容)
# Product Price: NT$518
# ----------------------------------------------------------------------------
# Product Name: NeverAwake (簡體中文, 英文, 繁體中文, 日文)
# Product Price: NT$790
# ----------------------------------------------------------------------------
# Product Name: 碎片、道具、材料全套組合 (追加內容)
# Product Price: NT$1,109
# ----------------------------------------------------------------------------
# Product Name: 聖塔神記 TRINITY TRIGGER (韓文, 繁體中文, 日文)
# Product Price: NT$1,509
# ----------------------------------------------------------------------------
# Product Name: Graze Counter GM (簡體中文, 韓文, 英文, 泰文, 繁體中文, 日文)
# Product Price: NT$392
# ----------------------------------------------------------------------------
# Product Name: A Plague Tale Bundle (簡體中文, 韓文, 英文, 繁體中文, 日文)
# Product Price: NT$1,673
# ----------------------------------------------------------------------------
# Product Name: 廖添丁 - 稀代兇賊の最期 (簡體中文, 韓文, 英文, 繁體中文, 日文)
# Product Price: NT$590
# ----------------------------------------------------------------------------
# Product Name: Wings of Bluestar PS4 & PS5 (英文, 日文)
# Product Price: NT$294
# ----------------------------------------------------------------------------
# Product Name: Hot Shots Golf 2 (Everybody's Golf 2) (英文)
# Product Price: NT$300
# ----------------------------------------------------------------------------
# Product Name: Syphon Filter 3 (英文)
# Product Price: NT$300
# ----------------------------------------------------------------------------
# Product Name: Life is Strange Complete Season (英文)
# Product Price: NT$463
# ----------------------------------------------------------------------------
# Product Name: 《SMITE》10 週年豪華版 (簡體中文, 英文)
# Product Price: NT$1,790
# ----------------------------------------------------------------------------
# Product Name: 《SMITE》10 週年通行證 (簡體中文, 英文)
# Product Price: NT$1,190
# ----------------------------------------------------------------------------
# Product Name: Ultimate ADOM - Caverns of Chaos (英文)
# Product Price: NT$590
# ----------------------------------------------------------------------------
# Product Name: US Navy Sea Conflict (英文)
# Product Price: NT$150
# ----------------------------------------------------------------------------
# Product Name: 餐癮地城 (簡體中文, 韓文, 英文, 繁體中文, 日文)
# Product Price: NT$490
# ----------------------------------------------------------------------------
# Product Name: TWO JONG CELL!! (日文)
# Product Price: NT$500
# ----------------------------------------------------------------------------
# Product Name: Kick it, Bunny! (英文, 日文)
# Product Price: NT$300
# ----------------------------------------------------------------------------
# Product Name: 月亮騎士: 逆襲 (Vengeful Guardian: Moonrider) (簡體中文, 韓文, 英文, 繁體中文, 日文)
# Product Price: NT$529
# ----------------------------------------------------------------------------
# Product Name: Arcade Archives SENJYO (英文, 日文)
# Product Price: NT$277
# ----------------------------------------------------------------------------
# Product Name: Burrow of the Fallen Bear: A Gay Furry Visual Novel PS4 & PS5 (英文)
# Product Price: NT$590
# ----------------------------------------------------------------------------
# Product Name: 七龍珠Z 卡卡洛特　季票 (追加內容)
# Product Price: NT$690
# ----------------------------------------------------------------------------
# Product Name: 七龍珠Z 卡卡洛特 PS4&PS5 (簡體中文, 韓文, 泰文, 繁體中文)
# Product Price: NT$1,490
# ----------------------------------------------------------------------------
# Product Name: 七龍珠Z 卡卡洛特　季票 2 (追加內容)
# Product Price: NT$889
# ----------------------------------------------------------------------------
# Product Name: 七龍珠Z 卡卡洛特 數位豪華版 PS4&PS5 (簡體中文, 韓文, 泰文, 繁體中文)
# Product Price: NT$1,790
# ----------------------------------------------------------------------------
# Product Name: ONE PIECE 時光旅詩 擴充內容套組+100,000貝里 (追加內容)
# Product Price: NT$791
# ----------------------------------------------------------------------------
# Product Name: ONE PIECE 時光旅詩 數位豪華版 PS4 & PS5 (簡體中文, 韓文, 繁體中文)
# Product Price: NT$2,490
# ----------------------------------------------------------------------------
# Product Name: ONE PIECE 時光旅詩 PS4 & PS5 (簡體中文, 韓文, 繁體中文)
# Product Price: NT$1,790
# ----------------------------------------------------------------------------
# Product Name: The Bat Quiz (英文)
# Product Price: NT$60
# ----------------------------------------------------------------------------
# Product Name: 七龍珠Z 卡卡洛特 新篇章「新覺醒」 (追加內容)
# Product Price: NT$290
# ----------------------------------------------------------------------------
# Product Name: 鋼鐵之鬪: 無限戰士 (簡體中文, 英文, 繁體中文, 日文)
# Product Price: NT$490
# ----------------------------------------------------------------------------
# Product Name: 七龍珠Z 卡卡洛特 數位傳奇版 PS4&PS5 (簡體中文, 韓文, 泰文, 繁體中文)
# Product Price: NT$1,195
# ----------------------------------------------------------------------------
# Product Name: 動物之鬪: 競技場 (簡體中文, 韓文, 英文, 繁體中文, 日文)
# Product Price: NT$490
# ----------------------------------------------------------------------------
# Product Name: Portal Dungeon: Goblin Escape (簡體中文, 韓文, 英文, 日文)
# Product Price: NT$300
# ----------------------------------------------------------------------------
# Product Name: The Monkey P (英文)
# Product Price: NT$60
# ----------------------------------------------------------------------------
# Product Name: Alphadia Neo (英文)
# Product Price: NT$355
# ----------------------------------------------------------------------------
# Product Name: Arcade Archives GALAGA (英文, 日文)
# Product Price: NT$277
# ----------------------------------------------------------------------------
# Product Name: KAWAII SLIME ARENA PS4 & PS5 (簡體中文, 韓文, 英文, 繁體中文, 日文)
# Product Price: NT$180
# ----------------------------------------------------------------------------
# Product Name: The Cricket C (英文)
# Product Price: NT$60
# ----------------------------------------------------------------------------
# Product Name: Truck Journey: Nitro (英文)
# Product Price: NT$60
# ----------------------------------------------------------------------------
# Product Name: The Football Quiz (英文)
# Product Price: NT$60
# ----------------------------------------------------------------------------
# Product Name: The Spidy Quiz (英文)
# Product Price: NT$60
# ----------------------------------------------------------------------------
# Product Name: 狐狸在等我 The Fox Awaits Me (簡體中文, 韓文, 英文, 繁體中文, 日文)
# Product Price: NT$1,390
# ----------------------------------------------------------------------------
# Product Name: Tractor Journey (英文)
# Product Price: NT$60
# ----------------------------------------------------------------------------
# Product Name: Truck Journey (英文)
# Product Price: NT$60
# ----------------------------------------------------------------------------
# Product Name: Neon Abyss (簡體中文, 英文, 繁體中文, 日文)
# Product Price: NT$790
# ----------------------------------------------------------------------------
# Product Name: Mermaidio (英文)
# Product Price: NT$42
# ----------------------------------------------------------------------------
# Product Name: Humongous Classic Collection (英文)
# Product Price: NT$1,790
# ----------------------------------------------------------------------------
# Product Name: Speed Journey: Nitro (英文)
# Product Price: NT$60
# ----------------------------------------------------------------------------
# Product Name: The Snowman Story (英文)
# Product Price: NT$60
# ----------------------------------------------------------------------------
# Product Name: Extreme Wrestling (英文)
# Product Price: NT$150
# ----------------------------------------------------------------------------
# Product Name: Cubic Light (英文)
# Product Price: NT$150
# ----------------------------------------------------------------------------
# Product Name: The Burger Quiz (英文)
# Product Price: NT$60
# ----------------------------------------------------------------------------
# Product Name: emoji Kart™ Racer (簡體中文, 英文, 繁體中文, 日文)
# Product Price: NT$790
# ----------------------------------------------------------------------------
# Product Name: HAKOSAN (英文)
# Product Price: NT$30
# ----------------------------------------------------------------------------
# Product Name: Arcade Archives Metal Hawk (英文, 日文)
# Product Price: NT$277
# ----------------------------------------------------------------------------
# Product Name: 殘月之鎖宮 (韓文, 繁體中文, 日文)
# Product Price: NT$444
# ----------------------------------------------------------------------------
# Product Name: Otoko Cross: Pretty Boys Klondike Solitaire PS4 & PS5 (英文, 日文)
# Product Price: NT$210
# ----------------------------------------------------------------------------
# Product Name: The Golf G (英文)
# Product Price: NT$60
# ----------------------------------------------------------------------------
# Product Name: VALKYRIE PROFILE: LENNETH (英文)
# Product Price: NT$590
# ----------------------------------------------------------------------------
# Product Name: VALKYRIE PROFILE: LENNETH (英文)
# Product Price: NT$590
# ----------------------------------------------------------------------------
# Product Name: AI：夢境檔案　雙享包 (簡體中文, 繁體中文, 日文)
# Product Price: NT$2,505
# ----------------------------------------------------------------------------
# Product Name: 青梅竹馬是人魚姫!? Refine My Girlfriend is a Mermaid!? (韓文, 英文, 繁體中文, 日文)
# Product Price: NT$1,390
# ----------------------------------------------------------------------------
# Product Name: 《SOL CRESTA》傳奇名機DLC組合包 (追加內容)
# Product Price: NT$150
# ----------------------------------------------------------------------------
# Product Name: Divine Knockout（DKO）- 新手版 (簡體中文, 英文, 日文)
# Product Price: NT$300
# ----------------------------------------------------------------------------
# Product Name: Speed Journey (英文)
# Product Price: NT$60
# ----------------------------------------------------------------------------
# Product Name: Pretty Bird 6 (英文)
# Product Price: NT$42
# ----------------------------------------------------------------------------
# Product Name: Middle-earth™: Shadow of Mordor™ (中英韓文版)
# Product Price: 內含
# ----------------------------------------------------------------------------
# Product Name: Pinball Heroes (英文)
# Product Price: NT$300
# ----------------------------------------------------------------------------
# Product Name: Monopoly Plus (英文)
# Product Price: NT$395
# ----------------------------------------------------------------------------
# Product Name: MXGP3 - Credits Multiplier (英文版)
# Product Price: NT$150
# ----------------------------------------------------------------------------
# Product Name: MXGP3 - The Official Motocross Videogame (英文)
# Product Price: NT$590
# ----------------------------------------------------------------------------
# Product Name: Arcade Archives THUNDER CROSS (日文版)
# Product Price: NT$264
# ----------------------------------------------------------------------------
# Product Name: Laser Disco Defenders (英文版)
# Product Price: NT$326
# ----------------------------------------------------------------------------
# Product Name: Little Nightmares Complete Edition (中韓文版)
# Product Price: NT$999
# ----------------------------------------------------------------------------
# Product Name: The Town of Light (英文版)
# Product Price: NT$652
# ----------------------------------------------------------------------------
# Product Name: Little Nightmares Secrets of The Maw Expansion Pass (中韓文版)
# Product Price: NT$329
# ----------------------------------------------------------------------------
# Product Name: Victor Vran: Overkill Edition (簡體中文, 韓文, 英文)
# Product Price: NT$1,304
# ----------------------------------------------------------------------------
# Product Name: AdVenture Capitalist (英文)
# Product Price: 免費
# ----------------------------------------------------------------------------
# Product Name: WipEout™ Omega Collection (中英韓文版)
# Product Price: NT$316
# ----------------------------------------------------------------------------
# Product Name: ACA NEOGEO METAL SLUG 2 (日英文版)
# Product Price: NT$264
# ----------------------------------------------------------------------------
# Product Name: 討鬼傳２ 共鬥版 (英文版)
# Product Price: 免費
# ----------------------------------------------------------------------------
# Product Name: 鐵拳7 (韓文, 繁體中文)
# Product Price: NT$1,390
# ----------------------------------------------------------------------------
# Product Name: Star Trek: Bridge Crew - Digital Standard (英文)
# Product Price: NT$675
# ----------------------------------------------------------------------------
# Product Name: 《火線獵殺：野境》魅影墜落 (中英韓文版)
# Product Price: NT$459
# ----------------------------------------------------------------------------
# Product Name: ACA NEOGEO WORLD HEROES 2 (日英文版)
# Product Price: NT$264
# ----------------------------------------------------------------------------
# Product Name: GUILTY GEAR Xrd REV 2 (中韓文版)
# Product Price: NT$1,290
# ----------------------------------------------------------------------------
# Product Name: GUILTY GEAR Xrd REV 2 (英文版)
# Product Price: NT$1,290
# ----------------------------------------------------------------------------
# Product Name: 魔女與百騎兵２ (中文版)
# Product Price: NT$1,690
# ----------------------------------------------------------------------------
# Product Name: 伊蘇VIII -丹娜的隕涕日- 豪華典藏版 (中文版)
# Product Price: NT$2,090
# ----------------------------------------------------------------------------
# Product Name: 伊蘇VIII -丹娜的隕涕日- 一般版 (中文版)
# Product Price: NT$1,790
# ----------------------------------------------------------------------------
# Product Name: Puzzle Showdown 4K (英文版)
# Product Price: NT$326
# ----------------------------------------------------------------------------
# Product Name: 戰國無雙 ～真田丸～ (英文版)
# Product Price: NT$1,630
# ----------------------------------------------------------------------------

# %%
from bs4 import BeautifulSoup
import requests
import json

url = "https://store.playstation.com/zh-hant-tw/category/5f3aa730-1c8e-4a18-84da-030bb91558c0/1"

res = requests.get(url)
soup = BeautifulSoup(res.text, "lxml")

class_1 = "psw-l-w-1/2@mobile-s psw-l-w-1/2@mobile-l psw-l-w-1/6@tablet-l psw-l-w-1/4@tablet-s psw-l-w-1/6@laptop psw-l-w-1/8@desktop psw-l-w-1/8@max"
jobs = soup.find_all("li", class_=class_1)

for job in jobs:
    data_telemetry_meta = job.find("a").get("data-telemetry-meta")
    meta_data = json.loads(data_telemetry_meta)

    product_name = meta_data['name']
    product_price = meta_data['price']

    print("Product Name:", product_name)
    print("Product Price:", product_price)
    print("---")
