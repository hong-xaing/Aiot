# %%
粉專
貼文
留言
回覆

簡單
分步驟
動手做

feed?message=貼文測試
get 取得資料
post 回覆資料
delete 刪除貼文一樣刪除ＩＤ
/feed?message=   貼文
/comments?messag=   留言
since= 時間搓際
#def 一個對一個（舉例是絞肉機）輸入要是一樣數量。輸出不一定要一樣數量

ngrok
1.打開輸入ngrok http 3000
2.貼上下面的代碼

user{}
jd["data"][0]['id']
in 有。      not in 沒有

user['data'][0]#這邊的0是因為儲存在user裡面的dic所以抓message
==   #這邊是兩個抓取出來的資料做比對
jd['data'][0]['message']  #

#比對出來有一致的話就pass,沒有一致的話就not in

# %%
import requests  #引入外部
import json
import time
import jieba
# curl -i -X GET \
#  "https://graph.facebook.com/v17.0/me?access_token="
host = "https://graph.facebook.com/v17.0/"
page_id = "115447678275957"
token = "EAATaH0MNoVYBAJjWu0EnihjZCl2uPKthtec79YUiIoKF5GWFOAgXj99i9rodtBB6MQ9aTdd69my7Fcg0WN4ZAfJJyLORjscRexKr4pbz8VgZBB0dQZCfIdT5hSRa2Vw8TiBN3UgQxRvoJhmebe30II85i2ugRUPrQ8RZBrF4Y61Nh9tBBBgLCD1D2ZAyJZCPQf6ltvrC31Opoh1x9npZBVS8"
# token=input("請輸入token：")
res = requests.get(host+page_id+"/posts?access_token="+token)
#得到的代碼  https://developers.facebook.com/tools/explorer/?method=GET&path=me%3Ffields%3Dposts&version=v17.0
jd = json.loads(res.text)
print(jd)
# jds = jd["data"][0]
# print(jd["data"][0]["from"]["id"])
# Out:
# {'data': [{'created_time': '2023-07-12T15:13:39+0000', 'message': '遊戲開始,答案是:49,請輸入1到100的數字:', 'id': '115447678275957_100872226418927'}, {'created_time': '2023-07-12T15:11:10+0000', 'message': '遊戲開始,答案是:52,請輸入1到100的數字:', 'id': '115447678275957_100870246419125'}, {'created_time': '2023-07-12T15:10:12+0000', 'message': '遊戲開始,答案是:79,請輸入1到100的數字:', 'id': '115447678275957_100869546419195'}, {'created_time': '2023-07-12T15:08:59+0000', 'message': '遊戲開始,答案是:100,請輸入1到100的數字:', 'id': '115447678275957_100868816419268'}, {'created_time': '2023-07-12T15:05:45+0000', 'message': '遊戲開始,答案是:22,請輸入1到100的數字:', 'id': '115447678275957_100867213086095'}, {'created_time': '2023-07-12T15:04:10+0000', 'message': '遊戲開始,答案是:32,請輸入1到100的數字:', 'id': '115447678275957_100866209752862'}, {'created_time': '2023-07-12T15:02:29+0000', 'message': '遊戲開始,答案是:48,請輸入1到100的數字:', 'id': '115447678275957_100865529752930'}, {'created_time': '2023-07-12T05:48:11+0000', 'message': '遊戲開始,答案是29,請輸入1到100的數字', 'id': '115447678275957_100505893122227'}, {'created_time': '2023-07-12T05:45:26+0000', 'message': '遊戲開始,答案是:5,請輸入1到100的數字:', 'id': '115447678275957_100504879788995'}, {'created_time': '2023-07-12T05:44:57+0000', 'message': '遊戲開始,答案是:50,請輸入1到100的數字:', 'id': '115447678275957_100504746455675'}, {'created_time': '2023-07-12T05:43:29+0000', 'message': '遊戲開始,答案是:28,請輸入1到100的數字:', 'id': '115447678275957_100504326455717'}, {'created_time': '2023-07-12T05:41:52+0000', 'message': '遊戲開始,答案是:78,請輸入1到100的數字:', 'id': '115447678275957_100503709789112'}, {'created_time': '2023-07-12T05:41:28+0000', 'message': '遊戲開始,答案是:66,請輸入1到100的數字:', 'id': '115447678275957_100503626455787'}, {'created_time': '2023-07-12T05:41:04+0000', 'message': '遊戲開始,答案是:99,請輸入1到100的數字:', 'id': '115447678275957_100503466455803'}, {'created_time': '2023-07-12T05:40:54+0000', 'message': '遊戲開始,答案是:68,請輸入1到100的數字:', 'id': '115447678275957_100503419789141'}, {'created_time': '2023-07-12T05:37:34+0000', 'message': '遊戲開始,答案是:80,請輸入1到100的數字:', 'id': '115447678275957_100502336455916'}, {'created_time': '2023-07-12T05:37:03+0000', 'message': '遊戲開始,答案是:81,請輸入1到100的數字:', 'id': '115447678275957_100501816455968'}, {'created_time': '2023-07-12T05:36:33+0000', 'message': '遊戲開始,答案是:66,請輸入1到100的數字:', 'id': '115447678275957_100501489789334'}, {'created_time': '2023-07-12T05:35:41+0000', 'message': '遊戲開始,答案是:67,請輸入1到100的數字:', 'id': '115447678275957_100501183122698'}, {'created_time': '2023-07-12T05:35:27+0000', 'message': '遊戲開始,答案是:96,請輸入1到100的數字:', 'id': '115447678275957_100501149789368'}, {'created_time': '2023-07-12T05:21:18+0000', 'message': '遊戲開始,答案是:85,請輸入1到100的數字:', 'id': '115447678275957_100496483123168'}, {'created_time': '2023-07-12T05:15:30+0000', 'message': '遊戲開始,答案是:99,請輸入1到100的數字:', 'id': '115447678275957_100494469790036'}, {'created_time': '2023-07-12T05:15:18+0000', 'message': '遊戲開始,答案是:61,請輸入1到100的數字:', 'id': '115447678275957_100494429790040'}, {'created_time': '2023-07-12T05:14:59+0000', 'message': '遊戲開始,答案是:57,請輸入1到100的數字:', 'id': '115447678275957_100494359790047'}, {'created_time': '2023-07-12T03:56:16+0000', 'message': '遊戲開始,答案是:41,請輸入1到100的數字:', 'id': '115447678275957_100458326460317'}], 'paging': {'cursors': {'before': '...', 'after': '...'}, 'next': 'https://graph.facebook.com/v17.0/115447678275957/posts?access_token=EAATaH0MNoVYBAJjWu0EnihjZCl2uPKthtec79YUiIoKF5GWFOAgXj99i9rodtBB6MQ9aTdd69my7Fcg0WN4ZAfJJyLORjscRexKr4pbz8VgZBB0dQZCfIdT5hSRa2Vw8TiBN3UgQxRvoJhmebe30II85i2ugRUPrQ8RZBrF4Y61Nh9tBBBgLCD1D2ZAyJZCPQf6ltvrC31Opoh1x9npZBVS8&limit=25&after=...'}}

# %%
post_id = "115447678275957_100400489799434"
res = requests.get(host+post_id+"/comments?access_token="+token)
#得到的代碼  https://developers.facebook.com/tools/explorer/?method=GET&path=me%3Ffields%3Dposts&version=v17.0
jd = json.loads(res.text)
jd

# %%
com_id = "100400489799434_1015170022811572"
res = requests.get(host+com_id+"/comments?access_token="+token)
#得到的代碼  https://developers.facebook.com/tools/explorer/?method=GET&path=me%3Ffields%3Dposts&version=v17.0
jd = json.loads(res.text)
jd

# %%
jd["data"][0]["message"]

# %%
import random
num_max = 100
num_min = 1
ans = random.randint(num_min,num_max)
print(ans)
print("請輸入%d到%d的數字:"%(num_min,num_max))
while True:
    guess = int(input())
    if ans == guess:
        print("恭喜答對了")
        break
    elif ans > guess :
        num_min = guess
        print("請輸入%d到%d的數字:"%(num_min,num_max))
    else:
        num_max = guess
        print("請輸入%d到%d的數字:"%(num_min,num_max))

# %%
#自己的
import random
import time 
num_max = 100
num_min = 1
ans = random.randint(num_min,num_max)
res = requests.post(host+page_id+"/feed?message=遊戲開始,答案是:%d,請輸入%d到%d的數字:&access_token="%(ans,num_min,num_max)+token)
    #得到的代碼  https://developers.facebook.com/tools/explorer/?method=GET&path=me%3Ffields%3Dposts&version=v17.0
jd = json.loads(res.text)
print(jd["id"])

post_id = jd["id"]
print(post_id)
# print("答案是:%d"%(ans))
# print("請輸入%d到%d的數字:"%(num_min,num_max))
# post_id = "115447678275957_100400489799434"
while True:
    res = requests.get(host+post_id+"/comments?access_token="+token)
    jd=json.loads(res.text)
    if len(jd["data"]) > 0:
        guess = jd["data"][0]["message"]
        if ans == guess:
            res = requests.post(host+jd["data"][0]["id"]+"/comments?message=恭喜答對了！！&access_token="+token)
        elif ans > guess :
            num_min = guess
            print("請輸入%d到%d的數字:"%(num_min,num_max))
            res = requests.post(host+jd["data"][0]["id"]+"/comments?message=請輸入%d到%d的數字&access_token="+token)
        else :
            num_max = guess
            print("請輸入%d到%d的數字:"%(num_min,num_max))
            res = requests.post(host+jd["data"][0]["id"]+"/comments?message=請輸入%d到%d的數字&access_token="+token)
        time.sleep(5)
#     else:
#         print("end")

#     res = requests.post(host+jd["data"][0]["id"]+"/comments?message=恭喜答對了！！&access_token="+token)
#     print(res)
#     #得到的代碼  https://developers.facebook.com/tools/explorer/?method=GET&path=me%3Ffields%3Dposts&version=v17.0
#     jd = json.loads(res.text)
    
#     guess = jd["data"][0]["message"]
#     if ans == guess:
#         print("恭喜答對了")
#         break
#     elif ans > guess :
#         num_min = guess
#         print("請輸入%d到%d的數字:"%(num_min,num_max))
#     else:
#         num_max = guess
#         print("請輸入%d到%d的數字:"%(num_min,num_max))
#     time.sleep(1)

# %%
#老師的
import random
import time
import requests
import json
host="https://graph.facebook.com/v17.0/"
page_id="115447678275957"
token="EAATaH0MNoVYBAIgg26W2bRKW3EsSrBw8vHHkbhtQ82cWAGrZARoTQ5JAWS6bm6MJokiGZCG9b845KkgEpdeElos1r2isqcGsN3P8SZAuOUfU9R4KVZCPcp7dgBXihcITGgROGuh2QaH75PI6XhJ66Jf6PTEOITsLvtYPpnIbaYUNy3eSnttrcku2y6JSsH08lz0sFExYBqdchHRbH432"
num_max=100
num_min=1
ans=random.randint(num_min,num_max)
res=requests.post(host+page_id+"/feed?message=遊戲開始,答案是%d,請輸入%d到%d的數字&access_token="%(ans,num_min,num_max)+token)
# res=requests.post(host+page_id+"/feed?message=遊戲開始,答案是"+str(ans)+
#     ",請輸入"+str(num_min)+"到"+str(num_max)+"的數字&access_token="+token)
jd=json.loads(res.text)
print(jd)
post_id=jd['id']
time.sleep(5)
while True:
    res=requests.get(host+post_id+"/comments?access_token="+token)
    jd=json.loads(res.text)
    if len(jd['data'])>0:
        guess=int(jd['data'][0]['message'])
        if ans==guess:
            print("恭喜猜對")
            res=requests.post(host+jd['data'][0]['id']+"/comments?message=恭喜猜對&access_token="+token)
            break
        elif ans>guess:
            num_min=guess
            print("請輸入%d到%d的數字"%(num_min,num_max))
            res=requests.post(host+jd['data'][0]['id']+"/comments?message=請輸入%d到%d的數字"%(num_min,num_max)+"&access_token="+token)
        else:
            num_max=guess
            print("請輸入%d到%d的數字"%(num_min,num_max))
            res=requests.post(host+jd['data'][0]['id']+"/comments?message=請輸入%d到%d的數字"%(num_min,num_max)+"&access_token="+token)
    time.sleep(20)

# %%
#自己的
import requests  #引入外部
import json
import random
import time 
host = "https://graph.facebook.com/v17.0/"
page_id = "115447678275957"
token = "EAATaH0MNoVYBAJjWu0EnihjZCl2uPKthtec79YUiIoKF5GWFOAgXj99i9rodtBB6MQ9aTdd69my7Fcg0WN4ZAfJJyLORjscRexKr4pbz8VgZBB0dQZCfIdT5hSRa2Vw8TiBN3UgQxRvoJhmebe30II85i2ugRUPrQ8RZBrF4Y61Nh9tBBBgLCD1D2ZAyJZCPQf6ltvrC31Opoh1x9npZBVS8"
# token=input("請輸入token：")
res = requests.get(host+page_id+"/posts?access_token="+token)
#得到的代碼  https://developers.facebook.com/tools/explorer/?method=GET&path=me%3Ffields%3Dposts&version=v17.0
jd = json.loads(res.text)
# print(jd)
# jds = jd["data"][0]
# print(jd["data"][0]["from"]["id"])

num_max = 100
num_min = 1
ans = random.randint(num_min,num_max)
res = requests.post(host+page_id+"/feed?message=遊戲開始,答案是:%d,請輸入%d到%d的數字:&access_token="%(ans,num_min,num_max)+token)
    #得到的代碼  https://developers.facebook.com/tools/explorer/?method=GET&path=me%3Ffields%3Dposts&version=v17.0
jd = json.loads(res.text)
# print(jd["id"])
user={}
post_id = jd["id"]
print(post_id)
# print("答案是:%d"%(ans))
# print("請輸入%d到%d的數字:"%(num_min,num_max))
# post_id = "115447678275957_100400489799434"
while True:
    #讀取貼文的留言
    res = requests.get(host+post_id+"/comments?access_token="+token)
    jd=json.loads(res.text)
    
    if len(jd["data"]) > 0:
        guess = int(jd["data"][0]["message"])
        user[jd["data"][0]["id"]]=[jd["data"][0]["message"]]
        if ans == guess:
            res = requests.post(host+jd["data"][0]["id"]+"/comments?message=恭喜答對了！！&access_token="+token)
        elif ans > guess :
            num_min = guess
            print("請輸入%d到%d的數字:"%(num_min,num_max))
            res = requests.post(host+jd["data"][0]["id"]+"/comments?message=請輸入%d到%d的數字&access_token="%(num_min,num_max)+token)
        else :
            num_max = guess
            print("請輸入%d到%d的數字:"%(num_min,num_max))
            res = requests.post(host+jd["data"][0]["id"]+"/comments?message=請輸入%d到%d的數字&access_token="%(num_min,num_max)+token)
        jd2 = json.loads(res.text)
#         print(jd2)
#         print(user[jd["data"][0]["id"]])
        if len(user[jd["data"][0]["id"]])==1:
            user[jd["data"][0]["id"]].append(jd2["id"])
#             print(user[jd["data"][0]["id"]].append(jd2["id"]))
        else:
            user[jd["data"][0]["id"]]=jd2["id"]
            print(user[jd["data"][0]["id"]])
        time.sleep(3)
#     else:
#         print("end")

#     res = requests.post(host+jd["data"][0]["id"]+"/comments?message=恭喜答對了！！&access_token="+token)
#     print(res)
#     #得到的代碼  https://developers.facebook.com/tools/explorer/?method=GET&path=me%3Ffields%3Dposts&version=v17.0
#     jd = json.loads(res.text)
    
#     guess = jd["data"][0]["message"]
#     if ans == guess:
#         print("恭喜答對了")
#         break
#     elif ans > guess :
#         num_min = guess
#         print("請輸入%d到%d的數字:"%(num_min,num_max))
#     else:
#         num_max = guess
#         print("請輸入%d到%d的數字:"%(num_min,num_max))
#     time.sleep(1)
# Out:
# 115447678275957_100877753085041
# 請輸入10到100的數字:
# 請輸入10到100的數字:
# 請輸入10到100的數字:
# 請輸入10到100的數字:
# 請輸入10到100的數字:
# 請輸入10到100的數字:
# 請輸入10到100的數字:
# 請輸入10到100的數字:
# 請輸入10到100的數字:
# 請輸入10到100的數字:
# 請輸入10到100的數字:
# 請輸入10到100的數字:
# 請輸入10到100的數字:
# 請輸入10到100的數字:
# 請輸入10到100的數字:
# 請輸入10到100的數字:
# 請輸入10到100的數字:
# 請輸入10到100的數字:
# 請輸入10到100的數字:
# 請輸入10到100的數字:
# 請輸入10到100的數字:
# 請輸入10到100的數字:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 43
#      41     num_min = guess
#      42     print("請輸入%d到%d的數字:"%(num_min,num_max))
# ---> 43     res = requests.post(host+jd["data"][0]["id"]+"/comments?message=請輸入%d到%d的數字&access_token="%(num_min,num_max)+token)
#      44 else :
#      45     num_max = guess
#
# File ~/anaconda3/lib/python3.10/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/anaconda3/lib/python3.10/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/anaconda3/lib/python3.10/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File ~/anaconda3/lib/python3.10/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File ~/anaconda3/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/anaconda3/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/anaconda3/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~/anaconda3/lib/python3.10/ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File ~/anaconda3/lib/python3.10/ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
#老師做的
import random
import time
import requests
import json
host="https://graph.facebook.com/v17.0/"
page_id="115447678275957"
token="EAATaH0MNoVYBAJjWu0EnihjZCl2uPKthtec79YUiIoKF5GWFOAgXj99i9rodtBB6MQ9aTdd69my7Fcg0WN4ZAfJJyLORjscRexKr4pbz8VgZBB0dQZCfIdT5hSRa2Vw8TiBN3UgQxRvoJhmebe30II85i2ugRUPrQ8RZBrF4Y61Nh9tBBBgLCD1D2ZAyJZCPQf6ltvrC31Opoh1x9npZBVS8"
num_max=100
num_min=1
ans=random.randint(num_min,num_max)
user={}
res=requests.post(host+page_id+"/feed?message=遊戲開始,答案是%d,請輸入%d到%d的數字&access_token="%(ans,num_min,num_max)+token)
# res=requests.post(host+page_id+"/feed?message=遊戲開始,答案是"+str(ans)+
#     ",請輸入"+str(num_min)+"到"+str(num_max)+"的數字&access_token="+token)
jd=json.loads(res.text)
print(jd)
post_id=jd['id']
time.sleep(5)
while True:
    #讀取貼文的留言
    res=requests.get(host+post_id+"/comments?access_token="+token)
    jd=json.loads(res.text)    
    if len(jd['data'])>0:#判斷是否有新留言
        guess=int(jd['data'][0]['message'])#存猜測的答案
        user[jd['data'][0]['id']]=[jd['data'][0]['message']]#開始記錄user={"留言ID":[留言內容,回覆ID]}
        if ans==guess:
            print("恭喜猜對")
            res=requests.post(host+jd['data'][0]['id']+"/comments?message=恭喜猜對&access_token="+token)
            break
        elif ans>guess:
            num_min=guess
            print("請輸入%d到%d的數字"%(num_min,num_max))
            res=requests.post(host+jd['data'][0]['id']+"/comments?message=請輸入%d到%d的數字"%(num_min,num_max)+"&access_token="+token)
        else:
            num_max=guess
            print("請輸入%d到%d的數字"%(num_min,num_max))
            res=requests.post(host+jd['data'][0]['id']+"/comments?message=請輸入%d到%d的數字"%(num_min,num_max)+"&access_token="+token)
        #留下回覆的紀錄
        jd2=json.loads(res.text)
        if len(user[jd['data'][0]['id']])==1:#判斷是否已回覆過
            user[jd['data'][0]['id']].append(jd2['id'])
            print(user[jd['data'][0]['id']].append(jd2['id']))
        else:
            user[jd['data'][0]['id']][1]=jd2['id']
    time.sleep(5)
# Out:
# {'id': '115447678275957_100879849751498'}
# 請輸入10到100的數字
# None
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 22
#      19 time.sleep(5)
#      20 while True:
#      21     #讀取貼文的留言
# ---> 22     res=requests.get(host+post_id+"/comments?access_token="+token)
#      23     jd=json.loads(res.text)
#      24     if len(jd['data'])>0:#判斷是否有新留言
#
# File ~/anaconda3/lib/python3.10/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/anaconda3/lib/python3.10/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/anaconda3/lib/python3.10/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     384 # Trigger any extra validation we need to do.
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#     389     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/connectionpool.py:1042, in HTTPSConnectionPool._validate_conn(self, conn)
#    1040 # Force connect early to allow us to validate the connection.
#    1041 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042     conn.connect()
#    1044 if not conn.is_verified:
#    1045     warnings.warn(
#    1046         (
#    1047             "Unverified HTTPS request is being made to host '%s'. "
#    (...)
#    1052         InsecureRequestWarning,
#    1053     )
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/connection.py:414, in HTTPSConnection.connect(self)
#     405 if (
#     406     not self.ca_certs
#     407     and not self.ca_cert_dir
#    (...)
#     410     and hasattr(context, "load_default_certs")
#     411 ):
#     412     context.load_default_certs()
# --> 414 self.sock = ssl_wrap_socket(
#     415     sock=conn,
#     416     keyfile=self.key_file,
#     417     certfile=self.cert_file,
#     418     key_password=self.key_password,
#     419     ca_certs=self.ca_certs,
#     420     ca_cert_dir=self.ca_cert_dir,
#     421     ca_cert_data=self.ca_cert_data,
#     422     server_hostname=server_hostname,
#     423     ssl_context=context,
#     424     tls_in_tls=tls_in_tls,
#     425 )
#     427 # If we're using all defaults and the connection
#     428 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     429 # for the host.
#     430 if (
#     431     default_ssl_context
#     432     and self.ssl_version is None
#     433     and hasattr(self.sock, "version")
#     434     and self.sock.version() in {"TLSv1", "TLSv1.1"}
#     435 ):
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/util/ssl_.py:449, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     437     warnings.warn(
#     438         "An HTTPS request has been made, but the SNI (Server Name "
#     439         "Indication) extension to TLS is not available on this platform. "
#    (...)
#     445         SNIMissingWarning,
#     446     )
#     448 if send_sni:
# --> 449     ssl_sock = _ssl_wrap_socket_impl(
#     450         sock, context, tls_in_tls, server_hostname=server_hostname
#     451     )
#     452 else:
#     453     ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls)
#
# File ~/anaconda3/lib/python3.10/site-packages/urllib3/util/ssl_.py:493, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     490     return SSLTransport(sock, ssl_context, server_hostname)
#     492 if server_hostname:
# --> 493     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494 else:
#     495     return ssl_context.wrap_socket(sock)
#
# File ~/anaconda3/lib/python3.10/ssl.py:513, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     507 def wrap_socket(self, sock, server_side=False,
#     508                 do_handshake_on_connect=True,
#     509                 suppress_ragged_eofs=True,
#     510                 server_hostname=None, session=None):
#     511     # SSLSocket class handles server_hostname encoding before it calls
#     512     # ctx._wrap_socket()
# --> 513     return self.sslsocket_class._create(
#     514         sock=sock,
#     515         server_side=server_side,
#     516         do_handshake_on_connect=do_handshake_on_connect,
#     517         suppress_ragged_eofs=suppress_ragged_eofs,
#     518         server_hostname=server_hostname,
#     519         context=self,
#     520         session=session
#     521     )
#
# File ~/anaconda3/lib/python3.10/ssl.py:1071, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1068         if timeout == 0.0:
#    1069             # non-blocking
#    1070             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1071         self.do_handshake()
#    1072 except (OSError, ValueError):
#    1073     self.close()
#
# File ~/anaconda3/lib/python3.10/ssl.py:1342, in SSLSocket.do_handshake(self, block)
#    1340     if timeout == 0.0 and block:
#    1341         self.settimeout(None)
# -> 1342     self._sslobj.do_handshake()
#    1343 finally:
#    1344     self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
#刪除資料。since 時間搓
res=requests.get(host+page_id+"/posts?since=1689114981&access_token="+token)
jd=json.loads(res.text)
for post in jd['data']:
    requests.delete(host+post['id']+"?access_token="+token)

# %%
#自己做的
import random
import time
import requests
import json
host="https://graph.facebook.com/v17.0/"
page_id="115447678275957"
token="EAATaH0MNoVYBAIgg26W2bRKW3EsSrBw8vHHkbhtQ82cWAGrZARoTQ5JAWS6bm6MJokiGZCG9b845KkgEpdeElos1r2isqcGsN3P8SZAuOUfU9R4KVZCPcp7dgBXihcITGgROGuh2QaH75PI6XhJ66Jf6PTEOITsLvtYPpnIbaYUNy3eSnttrcku2y6JSsH08lz0sFExYBqdchHRbH432"
num_max=100
num_min=1
ans=random.randint(num_min,num_max)
user={}
res=requests.post(host+page_id+"/feed?message=遊戲開始,答案是%d,請輸入%d到%d的數字&access_token="%(ans,num_min,num_max)+token)
# res=requests.post(host+page_id+"/feed?message=遊戲開始,答案是"+str(ans)+
#     ",請輸入"+str(num_min)+"到"+str(num_max)+"的數字&access_token="+token)
jd=json.loads(res.text)
print(jd)
post_id=jd['id']
time.sleep(5)
while True:
    #讀取貼文的留言
    res=requests.get(host+post_id+"/comments?access_token="+token)
    jd=json.loads(res.text)    
    if len(jd['data'])>0:#判斷是否有新留言
        guess=int(jd['data'][0]['message'])#存猜測的答案
        if jd["data"][0]["id"] not in user:
            user[jd['data'][0]['id']]=[jd['data'][0]['message']]#開始記錄user={"留言ID":[留言內容,回覆ID]}
            if ans==guess:
                print("恭喜猜對")
                res=requests.post(host+jd['data'][0]['id']+"/comments?message=恭喜猜對&access_token="+token)
                break
            elif ans>guess:
                num_min=guess
                print("請輸入%d到%d的數字"%(num_min,num_max))
                res=requests.post(host+jd['data'][0]['id']+"/comments?message=請輸入%d到%d的數字"%(num_min,num_max)+"&access_token="+token)
            else:
                num_max=guess
                print("請輸入%d到%d的數字"%(num_min,num_max))
                res=requests.post(host+jd['data'][0]['id']+"/comments?message=請輸入%d到%d的數字"%(num_min,num_max)+"&access_token="+token)
            #留下回覆的紀錄
            jd2=json.loads(res.text)
            if len(user[jd['data'][0]['id']])==1:#判斷是否已回覆過
                user[jd['data'][0]['id']].append(jd2['id'])
            else:
                user[jd['data'][0]['id']][1]=jd2['id']
    time.sleep(10)

# %%
def aaa()

# %%
import random
import time
import requests
import json
host="https://graph.facebook.com/v17.0/"
page_id="115447678275957"
token="EAATaH0MNoVYBAH263HP1GNGyteEsZCczoa6MvawW15c6ZCsBgk3PW9Af6px6D6ZAVOtmPrkxMANVZB4C6aO4455qon4ZC0lWFEJY4S3XERntU0hZB5XSCj6NEZC74CXwlBl8ZB0HpLbPrMEJzPVB1cfnYW8vL3oEsvyStCWnfDtbZB1z0Eu7AzrowrdbLM6J8giZCOUI6c3XkSIBpAmO1LBZBZBM"
num_max=100
num_min=1
ans=random.randint(num_min,num_max)
user={}
res=requests.post(host+page_id+"/feed?message=遊戲開始,答案是%d,請輸入%d到%d的數字&access_token="%(ans,num_min,num_max)+token)
# res=requests.post(host+page_id+"/feed?message=遊戲開始,答案是"+str(ans)+
#     ",請輸入"+str(num_min)+"到"+str(num_max)+"的數字&access_token="+token)
jd=json.loads(res.text)
# print(jd)
post_id=jd['id']
time.sleep(5)
while True:
    #讀取貼文的留言
    res=requests.get(host+post_id+"/comments?access_token="+token)
    jd=json.loads(res.text)    
    if len(jd['data'])>0:#判斷是否有新留言
        guess=int(jd['data'][0]['message'])#存猜測的答案
        if jd['data'][0]['id'] not in user: #判斷是否有被回覆過（沒存過）
            user[jd['data'][0]['id']]=[jd['data'][0]['message']]#開始記錄user={"留言ID":[留言內容,回覆ID]}
            if ans==guess:
                print("恭喜猜對")
                res=requests.post(host+jd['data'][0]['id']+"/comments?message=恭喜猜對&access_token="+token)
                break
            elif ans>guess:
                num_min=guess
                print("請輸入%d到%d的數字"%(num_min,num_max))
                res=requests.post(host+jd['data'][0]['id']+"/comments?message=請輸入%d到%d的數字"%(num_min,num_max)+"&access_token="+token)
            else:
                num_max=guess
                print("請輸入%d到%d的數字"%(num_min,num_max))
                res=requests.post(host+jd['data'][0]['id']+"/comments?message=請輸入%d到%d的數字"%(num_min,num_max)+"&access_token="+token)
            #留下回覆的紀錄
            jd2=json.loads(res.text)
            print(jd2)
            if len(user[jd['data'][0]['id']])==1:#判斷是否已回覆過
                user[jd['data'][0]['id']].append(jd2['id'])
            else:
                user[jd['data'][0]['id']][1]=jd2['id']
        else: #（已存過）
            if user[jd['data'][0]['id']][0]!=jd['data'][0]['message']:#判斷留言是否有變化
                user[jd['data'][0]['id']][0]=jd['data'][0]['message']#開始記錄user={"留言ID":[留言內容,回覆ID]}
                if ans==guess:
                    print("恭喜猜對")
                    res=requests.post(host+jd['data'][0]['id']+"/comments?message=恭喜猜對&access_token="+token)
                    break
                elif ans>guess:
                    num_min=guess
                    print("請輸入%d到%d的數字"%(num_min,num_max))
                    res=requests.post(host+jd['data'][0]['id']+"/comments?message=請輸入%d到%d的數字"%(num_min,num_max)+"&access_token="+token)
                else:
                    num_max=guess
                    print("請輸入%d到%d的數字"%(num_min,num_max))
                    res=requests.post(host+jd['data'][0]['id']+"/comments?message=請輸入%d到%d的數字"%(num_min,num_max)+"&access_token="+token)
                #留下回覆的紀錄
                jd2=json.loads(res.text)
                print(jd2)
                user[jd['data'][0]['id']][1]=jd2['id']
    time.sleep(20)

# %%
res=requests.get(host+page_id+"/posts?since=1689141030&access_token="+token)
jd=json.loads(res.text)
# print(jd)
for post in jd['data']:
    requests.delete(host+post['id']+"?access_token="+token)

# %%
#老師寫的
def comp(user,jd,ans,guess,num_min,num_max):#函數(子程式)
    user[jd['data'][0]['id']]=[jd['data'][0]['message']]#開始記錄user={"留言ID":[留言內容,回覆ID]}
    if ans==guess:
        print("恭喜猜對")
        res=requests.post(host+jd['data'][0]['id']+"/comments?message=恭喜猜對&access_token="+token)
        jd2=json.loads(res.text)
        return user,jd,ans,guess,num_min,num_max,1,jd2
    elif ans>guess:
        num_min=guess
        print("請輸入%d到%d的數字"%(num_min,num_max))
        res=requests.post(host+jd['data'][0]['id']+"/comments?message=請輸入%d到%d的數字"%(num_min,num_max)+"&access_token="+token)
    else:
        num_max=guess
        print("請輸入%d到%d的數字"%(num_min,num_max))
        res=requests.post(host+jd['data'][0]['id']+"/comments?message=請輸入%d到%d的數字"%(num_min,num_max)+"&access_token="+token)
    #留下回覆的紀錄
    jd2=json.loads(res.text)
    return user,jd,ans,guess,num_min,num_max,0,jd2

# %%
import random
import time
import requests
import json
host="https://graph.facebook.com/v17.0/"
page_id="105967285098749"
token="EAAKi2n8FFgYBADq53XyC2wZAYAWzYUJdQIMmDT6ceYoD2ShMwy4c4ZCyhg31ZC7qePzZBF2m3YjJcwzZA9fhD4GI9MYQFgNA0Y9OVehPbcKpc7GzanxZBhLa7TEEdoyHhp4jnL9KR0PdjpTVCT4VsjEf5vkPZBWkQrnAf5ES94HD6xOYv3McsZBsBR4JZARZCaGAZBvjWlahjcXKAgLzTgndtDd"
num_max=100
num_min=1
ans=random.randint(num_min,num_max)
user={}
check=0
res=requests.post(host+page_id+"/feed?message=遊戲開始,答案是%d,請輸入%d到%d的數字&access_token="%(ans,num_min,num_max)+token)
# res=requests.post(host+page_id+"/feed?message=遊戲開始,答案是"+str(ans)+
#     ",請輸入"+str(num_min)+"到"+str(num_max)+"的數字&access_token="+token)
jd=json.loads(res.text)
jd2=""
print(jd)
post_id=jd['id']
time.sleep(5)
while check==0:
    #讀取貼文的留言
    res=requests.get(host+post_id+"/comments?access_token="+token)
    jd=json.loads(res.text)    
    if len(jd['data'])>0:#判斷是否有新留言
        guess=int(jd['data'][0]['message'])#存猜測的答案
        if jd['data'][0]['id'] not in user:#判斷是否存檔過(沒存過)
            user,jd,ans,guess,num_min,num_max,check,jd2=comp(user,jd,ans,guess,num_min,num_max)
            print(jd2)
            user[jd['data'][0]['id']].append(jd2['id'])
        else: #存過
            if user[jd['data'][0]['id']][0]!=jd['data'][0]['message']:#判斷留言是否有變化
                user,jd,ans,guess,num_min,num_max,check,jd2=comp(user,jd,ans,guess,num_min,num_max)
                print(jd2)
                user[jd['data'][0]['id']][1]=jd2['id']
    time.sleep(20)
